# %% [markdown]
# # Complete-Profile Evaluation
#
# Split out from `results_latex_table.ipynb` (which keeps the main per-process/per-mode process-modelling quality table). This notebook covers ONLY whole-case curve ("complete profile") evaluation: Complete-Curve Evaluation (per-case, shift-tolerant Wasserstein), the Schedule Profile Evaluation (Direct Method vs. Stochastic generators vs. the Proposed Process-Simulation Approach), and the Population-Level (unpaired) Distributional Evaluation (shape + magnitude). No process-modelling-quality metrics (Fitness/Precision/Edge F1/Duration error) or process-quality-vs-energy-quality comparisons are included here -- see `results_latex_table.ipynb` for those.

# %% [markdown]
# ## Setup (minimal -- config, run_dir, process list; no process-quality table)

# %%
# ── Config ────────────────────────────────────────────────────────────────────
# Set the experiment number to load (picks the latest run automatically)
EXPERIMENT = 960
# Which evaluation split to display: 'train' or 'test'
# Both live in the same row — train_* vs test_* column prefixes.
SPLIT = 'test'

# %%
import pandas as pd
from pathlib import Path

results_root = Path('..') / 'results'

# Find the latest run folder for the given experiment
prefix = f'experiment_{EXPERIMENT}_'
runs = sorted([d for d in results_root.iterdir() if d.is_dir() and d.name.startswith(prefix)])
assert runs, f'No runs found for experiment {EXPERIMENT}'
run_dir = runs[-1]
print(f'Loading: {run_dir.name}')

df = pd.read_parquet(run_dir / 'process_eval_results.parquet')
# The 'split' column marks the training set used (always 'TRAIN' or 'ALL DATA').
# Train vs test evaluation results are distinguished by column prefix: train_* vs test_*.
# Check the requested prefix exists.
split_prefix = SPLIT.lower() + '_'
available_prefixes = set()
for c in df.columns:
    for p in ('train_', 'test_'):
        if c.startswith(p):
            available_prefixes.add(p.rstrip('_'))
print(f'Available column prefixes: {sorted(available_prefixes)}')
assert split_prefix.rstrip('_') in available_prefixes, \
    f'No columns with prefix "{split_prefix}" found. Available: {sorted(available_prefixes)}'

print(f'Split prefix: {split_prefix} | {len(df)} rows | processes: {sorted(df["process"].unique())}')
# Out:
# Loading: experiment_960_20260721_163605
# Available column prefixes: ['test', 'train']
# Split prefix: test_ | 78 rows | processes: ['process_1', 'process_2', 'process_3', 'process_4_1', 'process_4_2', 'process_5']

# %%
# ── Mode display labels (mirrors modelling.py _display_mode) ─────────────────
def display_mode(m):
    m = str(m)
    if not m.startswith('petri_net_'):
        return m
    rest = m[len('petri_net_'):]
    if rest.endswith('_ml_plus_global'):
        return rest[:-len('_ml_plus_global')] + ' / ml_global'
    if rest.endswith('_ml_plus_per_act'):
        return rest[:-len('_ml_plus_per_act')] + ' / ml_local'
    return rest + ' / baseline'

df['mode_label'] = df['mode'].map(display_mode)

# %%
# -- Process list (only thing needed from the main results table build) --
processes = sorted(df['process'].unique())
print(f'Processes: {processes}')
# Out:
# Processes: ['process_1', 'process_2', 'process_3', 'process_4_1', 'process_4_2', 'process_5']

# %%
import numpy as np

def shorten_sensor(name, max_len=40):
    name = str(name).replace('_energy_to_model', '').replace('_to_model', '')
    return name if len(name) <= max_len else name[:max_len - 1] + '…'

# %% [markdown]
# # Complete-Curve Evaluation (per-case, shift-tolerant Wasserstein)
#
# New, additional evaluation -- does not replace anything above. For every real test case, matched to its same-`case_id` counterpart in each simulated log, this:
#
# 1. Concatenates the case's real per-activity sensor curves (in real time order) into one complete real profile.
# 2. Predicts each of that case's activities' curves with the trained `baseline` (median/barycenter per activity) and `ml_exog_prev_activity` ("DTW + Ext. Factors + Prev Act", the strongest curve-fitting approach) pipelines, using the simulated log's own activities/durations, and concatenates them into one complete simulated profile for the same case.
# 3. Compares the two complete profiles with two Wasserstein (Earth Mover's) distances along orthogonal axes, instead of a single mean/total summary stat (which a trivial "predict the mean everywhere" model could win without getting anything useful right):
#    - **W1 (time)** -- curve values as weights, case-relative time as the transport axis. Answers "is the timing/shape right." Order-sensitive; blind to overall magnitude (a right-shaped-but-30%-too-high curve still scores well here, since W1 normalises each curve to the same total mass before comparing).
#    - **W1 (value)** -- raw curve values as the transport axis, unweighted. Answers "is the distribution of magnitudes right" -- catches scale *and* spread/variance errors. Order-blind (doesn't know *when* a value occurred), so it's exactly complementary to W1 (time). Works uniformly for intensive sensors (temperature, concentration) and extensive ones (power, flow), since nothing is summed or averaged before comparing.
#
# A model can't fool both at once: winning W1 (value) by predicting a flat mean loses badly on W1 (time), since all its mass then sits in the wrong place in time.
#
# Source: `complete_curve_eval_results/<process>/<mode>/complete_curve_summary[_ml_exog_prev_activity].csv`, populated per (process, mode, approach) when the pipeline runs with `run_energy_modelling=True`. If it's missing, re-run the pipeline after this modelling.py update.

# %%
# -- Load complete-curve evaluation results (per-case, shift-tolerant Wasserstein) --
# Discovers every approach that has a complete_curve_summary*.csv in a mode folder
# (complete-curve eval runs against every trained non-seq2seq approach, not just
# baseline + ml_exog_prev_activity -- see modelling.py's COMPLETE-CURVE EVAL block),
# rather than assuming a fixed pair.
#
# Two Wasserstein distances along two orthogonal axes, not a mean/total summary
# stat: wasserstein_time (values as weights, time as the transport axis -- is the
# timing/shape right) and wasserstein_value (raw values as the transport axis,
# unweighted -- is the distribution of magnitudes right). Neither can be gamed by
# a trivial "predict the mean everywhere" model: that scores badly on
# wasserstein_time (all its mass sits in the wrong place in time) and on
# wasserstein_value (zero variance vs. the real curve's actual spread). Works
# uniformly for intensive (temperature) and extensive (power, flow) sensors alike,
# since nothing is summed or averaged before comparing.
complete_curve_dir = run_dir / 'complete_curve_eval_results'

if not complete_curve_dir.exists():
    print(f'Not found: {complete_curve_dir}\n(run the pipeline with run_energy_modelling=True to generate it)')
    df_complete_curve = pd.DataFrame()
else:
    rows = []
    for proc_dir in sorted(complete_curve_dir.iterdir()):
        if not proc_dir.is_dir():
            continue
        for mode_dir in sorted(proc_dir.iterdir()):
            if not mode_dir.is_dir():
                continue
            for summary_path in sorted(mode_dir.glob('complete_curve_summary*.csv')):
                # 'complete_curve_summary.csv' -> baseline; '..._<approach>.csv' -> <approach>
                _stem = summary_path.stem  # 'complete_curve_summary' or 'complete_curve_summary_<approach>'
                _suffix = _stem[len('complete_curve_summary'):]
                approach = _suffix[1:] if _suffix.startswith('_') else 'baseline'

                summ = pd.read_csv(summary_path)
                if summ.empty:
                    continue
                mode_name = summ['mode'].iloc[0] if 'mode' in summ.columns else mode_dir.name
                for _, r in summ.iterrows():
                    rows.append({
                        'process':                   proc_dir.name,
                        'mode':                      mode_name,
                        'approach':                  approach,
                        'sensor':                    r['sensor'],
                        'wasserstein_time_median':   r['wasserstein_time_median'],
                        'wasserstein_value_median':  r.get('wasserstein_value_median'),
                        'n_cases':                   r['n_cases'],
                    })
    df_complete_curve = pd.DataFrame(rows)

print(f'{len(df_complete_curve)} (process, mode, approach, sensor) rows loaded')
if not df_complete_curve.empty:
    print(f'Approaches found: {sorted(df_complete_curve["approach"].unique())}')
df_complete_curve.head(20)
# Out:
# 8177 (process, mode, approach, sensor) rows loaded
# Approaches found: ['baseline', 'ml_dtw', 'ml_exog', 'ml_exog_prev_activity', 'ml_prev_activity', 'seq2seq', 'seq2seq_exog']
#       process             mode               approach  \
# 0   process_1  petri_net_alpha               baseline
# 1   process_1  petri_net_alpha               baseline
# 2   process_1  petri_net_alpha               baseline
# 3   process_1  petri_net_alpha               baseline
# 4   process_1  petri_net_alpha               baseline
# 5   process_1  petri_net_alpha                 ml_dtw
# 6   process_1  petri_net_alpha                 ml_dtw
# 7   process_1  petri_net_alpha                 ml_dtw
# 8   process_1  petri_net_alpha                 ml_dtw
# 9   process_1  petri_net_alpha                 ml_dtw
# 10  process_1  petri_net_alpha                 ml_dtw
# 11  process_1  petri_net_alpha                ml_exog
# 12  process_1  petri_net_alpha                ml_exog
# 13  process_1  petri_net_alpha                ml_exog
# 14  process_1  petri_net_alpha                ml_exog
# 15  process_1  petri_net_alpha                ml_exog
# 16  process_1  petri_net_alpha                ml_exog
# 17  process_1  petri_net_alpha  ml_exog_prev_activity
# 18  process_1  petri_net_alpha  ml_exog_prev_activity
# 19  process_1  petri_net_alpha  ml_exog_prev_activity
#
#                                                sensor  \
# 0   autoclave_cooling_water_demand_kW_energy_to_model
# 1           autoclave_steam_demand_kW_energy_to_model
# 2      destillation_cooling_demand_kW_energy_to_model
# 3        destillation_steam_demand_kW_energy_to_model
# 4       individual_packaging_power_kW_energy_to_model
# 5   autoclave_cooling_water_demand_kW_energy_to_model
# 6           autoclave_steam_demand_kW_energy_to_model
# 7                   bottling_power_kW_energy_to_model
# 8      destillation_cooling_demand_kW_energy_to_model
# 9        destillation_steam_demand_kW_energy_to_model
# 10      individual_packaging_power_kW_energy_to_model
# 11  autoclave_cooling_water_demand_kW_energy_to_model
# 12          autoclave_steam_demand_kW_energy_to_model
# 13                  bottling_power_kW_energy_to_model
# 14     destillation_cooling_demand_kW_energy_to_model
# 15       destillation_steam_demand_kW_energy_to_model
# 16      individual_packaging_power_kW_energy_to_model
# 17  autoclave_cooling_water_demand_kW_energy_to_model
# 18          autoclave_steam_demand_kW_energy_to_model
# 19                  bottling_power_kW_energy_to_model
#
#     wasserstein_time_median  wasserstein_value_median  n_cases
# 0                 27.597310                100.550281       90
# 1                 23.345415                552.395703       90
# 2                  6.562040                690.011993       90
# 3                  5.955266                643.604105       90
# 4                 32.636229                  0.811544       48
# 5                 27.518074                106.073624       90
# 6                 23.236485                478.267121       90
# 7                 12.721239                  0.182238       90
# 8                  6.605604                690.579927       90
# 9                  5.945962                644.050670       90
# 10                49.395138                  1.165837       79
# 11                27.809123                 94.025882       90
# 12                22.962176                535.129442       90
# 13                12.782772                  0.183539       48
# 14                 6.576320                695.193345       90
# 15                 5.926011                638.947698       90
# 16                33.888049                  1.167013       79
# 17                27.694813                 95.583571       90
# 18                22.881969                482.160673       90
# 19                12.619896                  0.197799       90

# %%
# -- Scale-free versions of the two complete-curve Wasserstein metrics --
# wasserstein_time_median is in minutes and wasserstein_value_median is in the
# sensor's own raw units -- neither is comparable across sensors of different
# scale (a kg/h sensor vs. a kW sensor, a short-cycle process vs. a long one),
# so aggregating them across sensors (as the combined table below does) lets
# whichever sensor has the largest units/duration dominate the median. Fix,
# mirroring the relative_wasserstein trick used for the pooled energy-
# distribution metric above: divide each by a real, model-independent scale
# reference for that (process, sensor) --
#   relative_wasserstein_time  = wasserstein_time_median  / real median case duration (minutes)
#   relative_wasserstein_value = wasserstein_value_median / real per-case-mean median (same raw units)
# Note: the pooled *instantaneous* value median (per_sensor_pooled_values.csv)
# is often exactly 0 for intermittent sensors (idle most of the time), which
# would blow up the ratio -- per_case_sensor_mean.csv's real_median (median of
# each case's own mean value) stays a well-behaved nonzero denominator.
if not df_complete_curve.empty:
    case_duration_min = {}
    for proc in df_complete_curve['process'].unique():
        log_path = run_dir / 'predicted_logs' / f'{proc}_test_set.parquet'
        if not log_path.exists():
            continue
        log_df = pd.read_parquet(log_path, columns=['case_id', 'timestamp_start', 'timestamp_end'])
        case_ends = log_df.groupby('case_id')['timestamp_end'].max()
        case_starts = log_df.groupby('case_id')['timestamp_start'].min()
        durations = (case_ends - case_starts).dt.total_seconds() / 60.0
        case_duration_min[proc] = durations.median()

    real_val_median = {}
    for proc_dir in sorted((run_dir / 'energy_distribution_results').iterdir()):
        if not proc_dir.is_dir():
            continue
        for mode_dir in sorted(proc_dir.iterdir()):
            csv_path = mode_dir / 'per_case_sensor_mean.csv'
            if not csv_path.exists():
                continue
            pooled_df = pd.read_csv(csv_path)
            for _, r in pooled_df.iterrows():
                real_val_median.setdefault((proc_dir.name, r['sensor']), r['real_median'])

    df_complete_curve['case_duration_median_min'] = df_complete_curve['process'].map(case_duration_min)
    df_complete_curve['real_value_median'] = df_complete_curve.apply(
        lambda r: real_val_median.get((r['process'], r['sensor'])), axis=1
    )
    df_complete_curve['relative_wasserstein_time'] = (
        df_complete_curve['wasserstein_time_median']
        / df_complete_curve['case_duration_median_min'].replace(0, float('nan'))
    )
    df_complete_curve['relative_wasserstein_value'] = (
        df_complete_curve['wasserstein_value_median']
        / df_complete_curve['real_value_median'].abs().replace(0, float('nan'))
    )

    print('Relative (scale-free) complete-curve metrics added.')
    display(df_complete_curve[['process', 'mode', 'approach', 'sensor',
                               'wasserstein_time_median', 'relative_wasserstein_time',
                               'wasserstein_value_median', 'relative_wasserstein_value']].head(20))
else:
    print('Nothing to show -- df_complete_curve is empty.')
# Out:
# Relative (scale-free) complete-curve metrics added.
#       process             mode               approach  \
# 0   process_1  petri_net_alpha               baseline
# 1   process_1  petri_net_alpha               baseline
# 2   process_1  petri_net_alpha               baseline
# 3   process_1  petri_net_alpha               baseline
# 4   process_1  petri_net_alpha               baseline
# 5   process_1  petri_net_alpha                 ml_dtw
# 6   process_1  petri_net_alpha                 ml_dtw
# 7   process_1  petri_net_alpha                 ml_dtw
# 8   process_1  petri_net_alpha                 ml_dtw
# 9   process_1  petri_net_alpha                 ml_dtw
# 10  process_1  petri_net_alpha                 ml_dtw
# 11  process_1  petri_net_alpha                ml_exog
# 12  process_1  petri_net_alpha                ml_exog
# 13  process_1  petri_net_alpha                ml_exog
# 14  process_1  petri_net_alpha                ml_exog
# 15  process_1  petri_net_alpha                ml_exog
# 16  process_1  petri_net_alpha                ml_exog
# 17  process_1  petri_net_alpha  ml_exog_prev_activity
# 18  process_1  petri_net_alpha  ml_exog_prev_activity
# 19  process_1  petri_net_alpha  ml_exog_prev_activity
#
#                                                sensor  \
# 0   autoclave_cooling_water_demand_kW_energy_to_model
# 1           autoclave_steam_demand_kW_energy_to_model
# 2      destillation_cooling_demand_kW_energy_to_model
# 3        destillation_steam_demand_kW_energy_to_model
# 4       individual_packaging_power_kW_energy_to_model
# 5   autoclave_cooling_water_demand_kW_energy_to_model
# 6           autoclave_steam_demand_kW_energy_to_model
# 7                   bottling_power_kW_energy_to_model
# 8      destillation_cooling_demand_kW_energy_to_model
# 9        destillation_steam_demand_kW_energy_to_model
# 10      individual_packaging_power_kW_energy_to_model
# 11  autoclave_cooling_water_demand_kW_energy_to_model
# 12          autoclave_steam_demand_kW_energy_to_model
# 13                  bottling_power_kW_energy_to_model
# 14     destillation_cooling_demand_kW_energy_to_model
# 15       destillation_steam_demand_kW_energy_to_model
# 16      individual_packaging_power_kW_energy_to_model
# 17  autoclave_cooling_water_demand_kW_energy_to_model
# 18          autoclave_steam_demand_kW_energy_to_model
# 19                  bottling_power_kW_energy_to_model
#
#     wasserstein_time_median  relative_wasserstein_time  \
# 0                 27.597310                   0.211103
# 1                 23.345415                   0.178579
# 2                  6.562040                   0.050196
# 3                  5.955266                   0.045554
# 4                 32.636229                   0.249648
# 5                 27.518074                   0.210497
# 6                 23.236485                   0.177745
# 7                 12.721239                   0.097310
# 8                  6.605604                   0.050529
# 9                  5.945962                   0.045483
# 10                49.395138                   0.377844
# 11                27.809123                   0.212723
# 12                22.962176                   0.175647
# 13                12.782772                   0.097781
# 14                 6.576320                   0.050305
# 15                 5.926011                   0.045330
# 16                33.888049                   0.259223
# 17                27.694813                   0.211849
# 18                22.881969                   0.175034
# 19                12.619896                   0.096535
#
#     wasserstein_value_median  relative_wasserstein_value
# 0                 100.550281                    0.536520
# 1                 552.395703                    2.074927
# 2                 690.011993                    3.947537
# 3                 643.604105                    5.201686
# 4                   0.811544                    0.352143
# 5                 106.073624                    0.565992
# 6                 478.267121                    1.796483
# 7                   0.182238                    0.104968
# 8                 690.579927                    3.950786
# 9                 644.050670                    5.205296
# 10                  1.165837                    0.505877
# 11                 94.025882                    0.501707
# 12                535.129442                    2.010071
# 13                  0.183539                    0.105718
# 14                695.193345                    3.977179
# 15                638.947698                    5.164053
# 16                  1.167013                    0.506388
# 17                 95.583571                    0.510019
# 18                482.160673                    1.811108
# 19                  0.197799                    0.113932

# %% [markdown]
# ## Per-sensor breakdown (complete-profile W1 time / W1 shape)
#
# The combined table above already medians `relative_wasserstein_time`/`relative_wasserstein_value`
# across sensors before combining with the process-quality columns. This section shows the
# same two scale-free metrics **per sensor** instead, mirroring the Energy-Distribution
# section's per-sensor tables above -- rows = sensor, columns = mode x curve approach
# (Baseline / Best = DTW + Ext. Factors + Prev. Activity). `relative_wasserstein_time`
# ("W1 timing") is `wasserstein_time_median` divided by the real median case duration;
# `relative_wasserstein_value` ("W1 shape") is `wasserstein_value_median` divided by the
# real per-case-mean median for that sensor -- both scale-free, so a kg/h sensor and a °C
# sensor can be compared fairly. Lower is better for both.

# %%
# -- Per-sensor breakdown: complete-profile W1 (time) / W1 (value), relative --
# rows = sensor, columns = mode x approach (Baseline / Best)
_cc_approach_labels = {'baseline': 'Baseline', 'ml_exog_prev_activity': 'Best'}

def _cc_per_sensor_table(metric_col, metric_label, metric_desc):
    if df_complete_curve.empty:
        print('Nothing to show -- df_complete_curve is empty.')
        return
    dfc = df_complete_curve[df_complete_curve['approach'].isin(_cc_approach_labels)].copy()
    dfc['mode_label'] = dfc['mode'].map(display_mode)
    dfc['sensor_short'] = dfc['sensor'].map(shorten_sensor)
    dfc['approach_label'] = dfc['approach'].map(_cc_approach_labels)

    for proc in sorted(dfc['process'].unique()):
        sub = dfc[dfc['process'] == proc]
        pivot = sub.pivot_table(index='sensor_short', columns=['mode_label', 'approach_label'],
                                values=metric_col, aggfunc='first')
        pivot = pivot.reindex(columns=sorted(pivot.columns, key=lambda c: (c[0], c[1] != 'Best')))

        str_table = pd.DataFrame(index=pivot.index, columns=pivot.columns, dtype=object)
        for idx in pivot.index:
            vals = pivot.loc[idx].dropna()
            if vals.empty:
                str_table.loc[idx] = ''
                continue
            best_val = vals.min()
            for col in pivot.columns:
                val = pivot.loc[idx, col]
                if pd.isna(val):
                    str_table.loc[idx, col] = ''
                    continue
                fmt = f'{val:.3f}'
                str_table.loc[idx, col] = (r'\textbf{' + fmt + r'}') if abs(val - best_val) < 1e-6 else fmt

        str_table.columns = [f'{m} ({a})' for m, a in str_table.columns]
        n_cols = len(str_table.columns)
        col_format = 'l|' + '|'.join(['c'] * n_cols)
        latex = str_table.to_latex(
            escape=False, column_format=col_format,
            caption=(
                f'Complete-profile evaluation for {proc}, experiment {EXPERIMENT} ({SPLIT} evaluation). '
                f'{metric_desc} '
                r'Lower is better. \textbf{Bold} = best mode/approach per sensor.'
            ),
            label=f'tab:complete_profile_{metric_col}_{EXPERIMENT}_{SPLIT}_{proc}',
            position='H',
        )
        print(f'% === {proc}: {pivot.shape[0]} sensors x {pivot.shape[1]} mode/approach cols -- {metric_label} ===')
        print(latex.replace('_', r'\_'))
        print()

    display(
        dfc.pivot_table(index=['process', 'sensor_short'], columns=['mode_label', 'approach_label'],
                        values=metric_col, aggfunc='first').round(3)
    )

_cc_per_sensor_table(
    'relative_wasserstein_time', 'W1 (time)',
    r"W1 (time), scale-free (relative to real median case duration) --- is the timing/shape right, "
    r"as a fraction of a typical case."
)
# Out:
# % === process_1: 6 sensors x 26 mode/approach cols -- W1 (time) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_1, experiment 960 (test evaluation). W1 (time), scale-free (relative to real median case duration) --- is the timing/shape right, as a fraction of a typical case. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_time\_960\_test\_process\_1}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# autoclave\_cooling\_water\_demand\_kW & 0.212 & 0.211 & 0.199 & 0.199 & 0.182 & 0.184 & 0.115 & 0.114 & 0.071 & \textbf{0.069} & 0.078 & 0.078 & 0.139 & 0.136 & 0.081 & 0.081 & 0.081 & 0.080 & 0.177 & 0.174 & 0.081 & 0.081 & 0.084 & 0.083 & 0.167 & 0.168 \\
# autoclave\_steam\_demand\_kW & 0.175 & 0.179 & 0.169 & 0.165 & 0.142 & 0.140 & 0.123 & 0.123 & 0.056 & 0.057 & 0.026 & \textbf{0.025} & 0.135 & 0.136 & 0.059 & 0.060 & 0.033 & 0.032 & 0.104 & 0.105 & 0.059 & 0.060 & 0.037 & 0.036 & 0.155 & 0.157 \\
# bottling\_power\_kW & 0.097 &  & 0.045 &  & \textbf{0.016} &  & 0.087 &  & 0.045 &  & \textbf{0.016} &  & 0.092 &  & 0.045 &  & \textbf{0.016} &  & 0.065 &  & 0.045 &  & 0.020 &  & 0.084 &  \\
# destillation\_cooling\_demand\_kW & 0.050 & 0.050 & 0.024 & 0.024 & \textbf{0.012} & 0.014 & 0.050 & 0.049 & 0.024 & 0.024 & \textbf{0.012} & 0.014 & 0.048 & 0.047 & 0.024 & 0.024 & \textbf{0.012} & 0.014 & 0.033 & 0.032 & 0.024 & 0.024 & 0.017 & 0.018 & 0.042 & 0.042 \\
# destillation\_steam\_demand\_kW & 0.046 & 0.046 & 0.021 & 0.021 & \textbf{0.013} & 0.014 & 0.047 & 0.046 & 0.021 & 0.021 & \textbf{0.013} & 0.014 & 0.047 & 0.047 & 0.021 & 0.021 & \textbf{0.013} & 0.014 & 0.032 & 0.032 & 0.021 & 0.021 & 0.017 & 0.018 & 0.042 & 0.042 \\
# individual\_packaging\_power\_kW & 0.259 & 0.250 & 0.277 & 0.175 & 0.289 & 0.135 & 0.378 & 0.196 & 0.294 & \textbf{0.111} & 0.401 & 0.120 & 0.195 & 0.179 & 0.166 & 0.140 & 0.168 & 0.141 & 0.261 & 0.243 & 0.166 & 0.140 & 0.163 & 0.135 & 0.336 & 0.209 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_2: 5 sensors x 26 mode/approach cols -- W1 (time) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_2, experiment 960 (test evaluation). W1 (time), scale-free (relative to real median case duration) --- is the timing/shape right, as a fraction of a typical case. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_time\_960\_test\_process\_2}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# dampfmenge\_kg/h\_nmb+cip & 0.279 & 0.274 & 0.235 & 0.216 & 0.216 & 0.235 & 0.177 & 0.210 & \textbf{0.139} & 0.141 & 0.184 & 0.170 & 0.229 & 0.294 & 0.358 & 0.297 & 0.283 & 0.285 & 1.548 & 1.324 & 1.915 & 1.686 & 1.945 & 1.641 & 0.439 & 0.431 \\
# medium\_power\_kW & 0.277 & 0.274 & 0.235 & 0.216 & 0.217 & 0.235 & 0.176 & 0.210 & 0.142 & \textbf{0.141} & 0.185 & 0.170 & 0.231 & 0.294 & 0.359 & 0.297 & 0.284 & 0.285 & 1.536 & 1.324 & 1.908 & 1.686 & 1.933 & 1.641 & 0.440 & 0.431 \\
# pro\_menge\_kg & 0.236 & 0.236 & 0.250 & 0.253 & 0.285 & 0.284 & 0.190 & 0.183 & 0.135 & \textbf{0.134} & 0.190 & 0.198 & 0.217 & 0.217 & 0.267 & 0.268 & 0.255 & 0.257 & 1.238 & 1.226 & 1.452 & 1.452 & 1.361 & 1.361 & 0.370 & 0.412 \\
# pro\_power\_kW & 0.273 & 0.274 & 0.192 & \textbf{0.169} & 0.252 & 0.236 & 0.264 & 0.303 & 0.180 & 0.181 & 0.282 & 0.316 & 0.289 & 0.287 & 0.368 & 0.355 & 0.332 & 0.332 & 1.184 & 1.193 & 1.457 & 1.474 & 1.748 & 1.758 & 0.411 & 0.426 \\
# pro\_volstrom\_l/h & 0.277 & 0.278 & 0.201 & \textbf{0.162} & 0.251 & 0.234 & 0.250 & 0.308 & 0.171 & 0.188 & 0.255 & 0.331 & 0.288 & 0.297 & 0.397 & 0.365 & 0.331 & 0.332 & 1.191 & 1.235 & 1.458 & 1.517 & 1.806 & 1.818 & 0.419 & 0.426 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_3: 5 sensors x 26 mode/approach cols -- W1 (time) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_3, experiment 960 (test evaluation). W1 (time), scale-free (relative to real median case duration) --- is the timing/shape right, as a fraction of a typical case. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_time\_960\_test\_process\_3}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# dampfmenge\_kg/h\_nmb+cip & 0.338 & 0.313 & 0.495 & 0.447 & 0.318 & 0.230 & 0.177 & 0.175 & 0.163 & 0.138 & 0.147 & \textbf{0.130} & 0.295 & 0.273 & 0.573 & 0.546 & 0.334 & 0.267 & 0.293 & 0.307 & 0.432 & 0.409 & 0.295 & 0.253 & 0.490 & 0.484 \\
# medium\_power\_kW & 0.348 & 0.313 & 0.501 & 0.447 & 0.324 & 0.230 & 0.178 & 0.175 & 0.170 & 0.138 & 0.142 & \textbf{0.130} & 0.298 & 0.273 & 0.549 & 0.546 & 0.367 & 0.267 & 0.306 & 0.307 & 0.424 & 0.409 & 0.300 & 0.253 & 0.489 & 0.484 \\
# pro\_menge\_kg & 0.535 & 0.537 & 0.596 & 0.712 & 0.281 & 0.314 & 0.218 & 0.218 & \textbf{0.145} & 0.145 & 0.156 & 0.169 & 0.268 & 0.219 & 0.304 & 0.282 & 0.282 & 0.258 & 0.286 & 0.263 & 0.304 & 0.282 & 0.273 & 0.235 & 0.348 & 0.357 \\
\\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_4_2: 23 sensors x 26 mode/approach cols -- W1 (time) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_4\_2, experiment 960 (test evaluation). W1 (time), scale-free (relative to real median case duration) --- is the timing/shape right, as a fraction of a typical case. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_time\_960\_test\_process\_4\_2}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# (10)\_abluft\_temp\_c & 0.326 & 0.327 & 0.232 & 0.231 & 0.217 & 0.217 & 0.135 & 0.137 & 0.075 & 0.074 & \textbf{0.070} & 0.073 & 0.270 & 0.270 & 0.222 & 0.222 & 0.222 & 0.221 & 0.219 & 0.220 & 0.202 & 0.203 & 0.222 & 0.221 & 0.328 & 0.327 \\
# (12)\_mpt\_fb(mpt?)\_kg/h & 0.323 & 0.323 & 0.234 & 0.234 & 0.233 & 0.233 & 0.134 & 0.134 & 0.078 & 0.079 & \textbf{0.078} & 0.079 & 0.268 & 0.268 & 0.217 & 0.218 & 0.219 & 0.219 & 0.243 & 0.244 & 0.206 & 0.205 & 0.224 & 0.224 & 0.303 & 0.303 \\
# (13)\_lanzen\_mas\_kg/h & 0.325 & 0.325 & 0.234 & 0.234 & 0.233 & 0.233 & 0.136 & 0.136 & \textbf{0.078} & 0.078 & 0.079 & 0.079 & 0.269 & 0.269 & 0.223 & 0.223 & 0.217 & 0.217 & 0.244 & 0.244 & 0.203 & 0.203 & 0.226 & 0.227 & 0.303 & 0.303 \\
# (14)\_filter\_mas\_kg/h & 0.324 & 0.323 & 0.234 & 0.233 & 0.232 & 0.234 & 0.137 & 0.136 & \textbf{0.076} & 0.078 & 0.078 & 0.079 & 0.267 & 0.268 & 0.224 & 0.224 & 0.218 & 0.218 & 0.243 & 0.243 & 0.205 & 0.203 & 0.224 & 0.224 & 0.305 & 0.304 \\
# (16)\_konditionierung\_mas\_kg/h & 0.312 & 0.312 & 0.233 & 0.233 & 0.233 & 0.234 & 0.130 & 0.130 & \textbf{0.077} & 0.078 & 0.079 & 0.080 & 0.267 & 0.267 & 0.223 & 0.223 & 0.218 & 0.218 & 0.244 & 0.244 & 0.204 & 0.203 & 0.226 & 0.226 & 0.304 & 0.304 \\
# (17)\_leistung\_turmF\_luftentfeuchter\_kw & 0.334 & 0.334 & 0.226 & 0.227 & 0.218 & 0.218 & 0.136 & 0.136 & 0.078 & 0.078 & \textbf{0.071} & 0.072 & 0.266 & 0.265 & 0.221 & 0.220 & 0.221 & 0.220 & 0.243 & 0.242 & 0.203 & 0.203 & 0.221 & 0.220 & 0.328 & 0.328 \\
# (2)\_zuluft\_vor\_entfeuchter\_kon\_g/kg & 0.215 & 0.310 & 0.205 & 0.228 & 0.202 & 0.221 & 0.131 & 0.135 & \textbf{0.079} & 0.080 & 0.086 & 0.080 & 0.284 & 0.282 & 0.223 & 0.223 & 0.221 & 0.220 & 0.216 & 0.222 & 0.205 & 0.203 & 0.223 & 0.222 & 0.304 & 0.303 \\
# temp\_nach\_WR2\_(WT2)\_5s & 0.395 & 0.397 & 0.243 & 0.243 & 0.372 & 0.373 & 0.096 & 0.094 & 0.062 & \textbf{0.062} & 0.066 & 0.066 & 0.440 & 0.443 & 0.342 & 0.340 & 0.225 & 0.224 & 0.426 & 0.427 & 0.342 & 0.340 & 0.225 & 0.224 & 0.493 & 0.493 \\
# temp\_vor\_Vorwärmer\_(WT\_2)\_1h & 0.389 & 0.389 & 0.243 & 0.242 & 0.372 & 0.371 & 0.094 & 0.094 & \textbf{0.058} & 0.058 & 0.061 & 0.061 & 0.434 & 0.434 & 0.335 & 0.335 & 0.225 & 0.225 & 0.433 & 0.433 & 0.335 & 0.335 & 0.225 & 0.225 & 0.498 & 0.498 \\
# vor\_Vorwärmer\_(WT\_2)\_5s & 0.388 & 0.388 & 0.244 & 0.242 & 0.370 & 0.370 & 0.094 & 0.094 & \textbf{0.059} & 0.060 & 0.063 & 0.063 & 0.431 & 0.433 & 0.336 & 0.334 & 0.225 & 0.224 & 0.433 & 0.434 & 0.336 & 0.334 & 0.225 & 0.224 & 0.497 & 0.497 \\
# \bottomrule
# \end{tabular}
# \end{table}
# mode_label                                         alpha / baseline         \
# approach_label                                             Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                   0.211  0.212
#           autoclave_steam_demand_kW                           0.179  0.175
#           bottling_power_kW                                     NaN  0.097
#           destillation_cooling_demand_kW                      0.050  0.050
#           destillation_steam_demand_kW                        0.046  0.046
# ...                                                             ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                 0.391  0.391
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…            0.388  0.388
#           temp_nach_WR2_(WT2)_5s                              0.397  0.395
#           temp_vor_Vorwärmer_(WT_2)_1h                        0.389  0.389
#           vor_Vorwärmer_(WT_2)_5s                             0.388  0.388
#
# mode_label                                         alpha / ml_global         \
# approach_label                                              Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                    0.199  0.199
#           autoclave_steam_demand_kW                            0.165  0.169
#           bottling_power_kW                                      NaN  0.045
#           destillation_cooling_demand_kW                       0.024  0.024
#           destillation_steam_demand_kW                         0.021  0.021
# ...                                                              ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                  0.243  0.244
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…             0.242  0.242
#           temp_nach_WR2_(WT2)_5s                               0.243  0.243
#           temp_vor_Vorwärmer_(WT_2)_1h                         0.242  0.243
#           vor_Vorwärmer_(WT_2)_5s                              0.242  0.244
#
# mode_label                                         alpha / ml_local         \
# approach_label                                             Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                   0.184  0.182
#           autoclave_steam_demand_kW                           0.140  0.142
#           bottling_power_kW                                     NaN  0.016
#           destillation_cooling_demand_kW                      0.014  0.012
#           destillation_steam_demand_kW                        0.014  0.013
# ...                                                             ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                 0.373  0.374
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…            0.372  0.372
#           temp_nach_WR2_(WT2)_5s                              0.373  0.372
#           temp_vor_Vorwärmer_(WT_2)_1h                        0.371  0.372
#           vor_Vorwärmer_(WT_2)_5s                             0.370  0.370
#
# mode_label                                         budget / baseline         \
# approach_label                                              Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                    0.114  0.115
#           autoclave_steam_demand_kW                            0.123  0.123
#           bottling_power_kW                                      NaN  0.087
#           destillation_cooling_demand_kW                       0.049  0.050
#           destillation_steam_demand_kW                         0.046  0.047
# ...                                                              ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                  0.094  0.095
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…             0.094  0.094
#           temp_nach_WR2_(WT2)_5s                               0.094  0.096
#           temp_vor_Vorwärmer_(WT_2)_1h                         0.094  0.094
#           vor_Vorwärmer_(WT_2)_5s                              0.094  0.094
#
# mode_label                                         budget / ml_global         \
# approach_label                                               Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                     0.069  0.071
#           autoclave_steam_demand_kW                             0.057  0.056
#           bottling_power_kW                                       NaN  0.045
#           destillation_cooling_demand_kW                        0.024  0.024
#           destillation_steam_demand_kW                          0.021  0.021
# ...                                                               ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                   0.059  0.060
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…              0.056  0.056
#           temp_nach_WR2_(WT2)_5s                                0.062  0.062
#           temp_vor_Vorwärmer_(WT_2)_1h                          0.058  0.058
#           vor_Vorwärmer_(WT_2)_5s                               0.060  0.059
#
# mode_label                                          ... heuristic / ml_local  \
# approach_label                                      ...             Baseline
# process   sensor_short                              ...
# process_1 autoclave_cooling_water_demand_kW         ...                0.080
#           autoclave_steam_demand_kW                 ...                0.032
#           bottling_power_kW                         ...                  NaN
#           destillation_cooling_demand_kW            ...                0.014
#           destillation_steam_demand_kW              ...                0.014
# ...                                                 ...                  ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       ...                0.224
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  ...                0.226
#           temp_nach_WR2_(WT2)_5s                    ...                0.224
#           temp_vor_Vorwärmer_(WT_2)_1h              ...                0.225
#           vor_Vorwärmer_(WT_2)_5s                   ...                0.224
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.081
#           autoclave_steam_demand_kW                 0.033
#           bottling_power_kW                         0.016
#           destillation_cooling_demand_kW            0.012
#           destillation_steam_demand_kW              0.013
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.224
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.226
#           temp_nach_WR2_(WT2)_5s                    0.225
#           temp_vor_Vorwärmer_(WT_2)_1h              0.225
#           vor_Vorwärmer_(WT_2)_5s                   0.225
#
# mode_label                                         wip_aware / baseline  \
# approach_label                                                 Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                       0.174
#           autoclave_steam_demand_kW                               0.105
#           bottling_power_kW                                         NaN
#           destillation_cooling_demand_kW                          0.032
#           destillation_steam_demand_kW                            0.032
# ...                                                                 ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                     0.429
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                0.433
#           temp_nach_WR2_(WT2)_5s                                  0.427
#           temp_vor_Vorwärmer_(WT_2)_1h                            0.433
#           vor_Vorwärmer_(WT_2)_5s                                 0.434
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.177
#           autoclave_steam_demand_kW                 0.104
#           bottling_power_kW                         0.065
#           destillation_cooling_demand_kW            0.033
#           destillation_steam_demand_kW              0.032
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.428
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.433
#           temp_nach_WR2_(WT2)_5s                    0.426
#           temp_vor_Vorwärmer_(WT_2)_1h              0.433
#           vor_Vorwärmer_(WT_2)_5s                   0.433
#
# mode_label                                         wip_aware / ml_global  \
# approach_label                                                  Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                        0.081
#           autoclave_steam_demand_kW                                0.060
#           bottling_power_kW                                          NaN
#           destillation_cooling_demand_kW                           0.024
#           destillation_steam_demand_kW                             0.021
# ...                                                                  ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                      0.334
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                 0.336
#           temp_nach_WR2_(WT2)_5s                                   0.340
#           temp_vor_Vorwärmer_(WT_2)_1h                             0.335
#           vor_Vorwärmer_(WT_2)_5s                                  0.334
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.081
#           autoclave_steam_demand_kW                 0.059
#           bottling_power_kW                         0.045
#           destillation_cooling_demand_kW            0.024
#           destillation_steam_demand_kW              0.021
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.334
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.336
#           temp_nach_WR2_(WT2)_5s                    0.342
#           temp_vor_Vorwärmer_(WT_2)_1h              0.335
#           vor_Vorwärmer_(WT_2)_5s                   0.336
#
# mode_label                                         wip_aware / ml_local  \
# approach_label                                                 Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                       0.083
#           autoclave_steam_demand_kW                               0.036
#           bottling_power_kW                                         NaN
#           destillation_cooling_demand_kW                          0.018
#           destillation_steam_demand_kW                            0.018
# ...                                                                 ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                     0.224
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                0.226
#           temp_nach_WR2_(WT2)_5s                                  0.224
#           temp_vor_Vorwärmer_(WT_2)_1h                            0.225
#           vor_Vorwärmer_(WT_2)_5s                                 0.224
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.084
#           autoclave_steam_demand_kW                 0.037
#           bottling_power_kW                         0.020
#           destillation_cooling_demand_kW            0.017
#           destillation_steam_demand_kW              0.017
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.224
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.226
#           temp_nach_WR2_(WT2)_5s                    0.225
#           temp_vor_Vorwärmer_(WT_2)_1h              0.225
#           vor_Vorwärmer_(WT_2)_5s                   0.225
#
# mode_label                                         wip_branching_aware / baseline  \
# approach_label                                                           Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                                 0.168
#           autoclave_steam_demand_kW                                         0.157
#           bottling_power_kW                                                   NaN
#           destillation_cooling_demand_kW                                    0.042
#           destillation_steam_demand_kW                                      0.042
# ...                                                                           ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                               0.498
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                          0.500
#           temp_nach_WR2_(WT2)_5s                                            0.493
#           temp_vor_Vorwärmer_(WT_2)_1h                                      0.498
#           vor_Vorwärmer_(WT_2)_5s                                           0.497
#
# mode_label
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.167
#           autoclave_steam_demand_kW                 0.155
#           bottling_power_kW                         0.084
#           destillation_cooling_demand_kW            0.042
#           destillation_steam_demand_kW              0.042
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.498
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.500
#           temp_nach_WR2_(WT2)_5s                    0.493
#           temp_vor_Vorwärmer_(WT_2)_1h              0.498
#           vor_Vorwärmer_(WT_2)_5s                   0.497
#
# [90 rows x 26 columns]

# %%
_cc_per_sensor_table(
    'relative_wasserstein_value', 'W1 (value)',
    r"W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the "
    r"distribution of magnitudes right, as a fraction of the sensor's typical real scale."
)
# Out:
# % === process_1: 6 sensors x 26 mode/approach cols -- W1 (value) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_1, experiment 960 (test evaluation). W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the distribution of magnitudes right, as a fraction of the sensor's typical real scale. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_value\_960\_test\_process\_1}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# autoclave\_cooling\_water\_demand\_kW & 0.510 & 0.537 & \textbf{0.417} & 0.428 & 0.547 & 0.561 & 0.965 & 1.042 & 0.684 & 0.989 & 0.784 & 0.937 & 0.666 & 1.012 & 0.591 & 1.004 & 0.632 & 1.046 & 0.516 & 0.614 & 0.591 & 1.004 & 0.614 & 1.046 & 0.731 & 0.661 \\
# autoclave\_steam\_demand\_kW & 1.811 & 2.075 & 2.007 & 2.201 & 1.806 & 1.985 & 1.543 & 1.641 & 1.359 & 1.513 & 1.390 & 1.508 & \textbf{1.307} & 1.443 & 1.349 & 1.424 & 1.330 & 1.442 & 2.064 & 2.367 & 1.349 & 1.424 & 1.330 & 1.442 & 1.894 & 2.212 \\
# bottling\_power\_kW & 0.114 &  & 0.129 &  & 0.125 &  & \textbf{0.112} &  & 0.129 &  & 0.125 &  & 0.116 &  & 0.129 &  & 0.125 &  & 0.131 &  & 0.129 &  & 0.124 &  & 0.128 &  \\
# destillation\_cooling\_demand\_kW & 3.963 & 3.948 & 3.919 & 3.918 & 3.880 & 3.897 & 4.412 & 4.374 & 4.410 & 4.415 & 4.409 & 4.397 & 2.709 & 2.691 & 3.056 & 3.062 & 3.125 & 3.129 & 2.633 & \textbf{2.597} & 3.056 & 3.062 & 3.163 & 3.175 & 3.262 & 3.249 \\
# destillation\_steam\_demand\_kW & 5.279 & 5.202 & 5.331 & 5.336 & 5.239 & 5.240 & 6.119 & 6.076 & 6.049 & 6.048 & 5.956 & 5.939 & 3.600 & 3.553 & 4.168 & 4.158 & 4.200 & 4.216 & 3.441 & \textbf{3.411} & 4.168 & 4.158 & 4.276 & 4.298 & 4.159 & 4.219 \\
# individual\_packaging\_power\_kW & 0.506 & 0.352 & 0.504 & 0.380 & 0.506 & 0.358 & 0.568 & 0.343 & 0.554 & 0.278 & 0.592 & 0.548 & 0.438 & 0.384 & 0.441 & 0.418 & 0.460 & 0.429 & 0.461 & 0.416 & 0.441 & 0.418 & 0.459 & 0.424 & 0.505 & \textbf{0.275} \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_2: 5 sensors x 26 mode/approach cols -- W1 (value) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_2, experiment 960 (test evaluation). W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the distribution of magnitudes right, as a fraction of the sensor's typical real scale. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_value\_960\_test\_process\_2}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# dampfmenge\_kg/h\_nmb+cip & 0.248 & 0.418 & 0.240 & 0.407 & 0.280 & 0.422 & 0.272 & 0.395 & 0.233 & 0.350 & 0.264 & 0.406 & 0.217 & 0.306 & \textbf{0.206} & 0.320 & 0.227 & 0.393 & 0.368 & 0.351 & \textbf{0.206} & 0.320 & 0.245 & 0.394 & 0.592 & 0.598 \\
# medium\_power\_kW & 0.230 & 0.418 & 0.233 & 0.407 & 0.293 & 0.422 & 0.270 & 0.395 & 0.231 & 0.350 & 0.269 & 0.406 & \textbf{0.205} & 0.306 & 0.208 & 0.320 & 0.225 & 0.393 & 0.395 & 0.351 & 0.208 & 0.320 & 0.238 & 0.394 & 0.627 & 0.598 \\
# pro\_menge\_kg & 0.105 & 0.092 & 0.101 & 0.112 & 0.090 & 0.117 & 0.091 & 0.113 & 0.114 & 0.114 & 0.093 & 0.081 & 0.152 & 0.133 & 0.130 & 0.131 & 0.103 & 0.112 & 0.296 & 0.225 & 0.130 & 0.131 & 0.112 & \textbf{0.080} & 0.148 & 0.811 \\
# pro\_power\_kW & 0.164 & 0.174 & 0.105 & 0.123 & 0.201 & 0.202 & 0.242 & 0.248 & 0.122 & 0.154 & 0.184 & 0.241 & 0.232 & 0.184 & 0.081 & \textbf{0.073} & 0.134 & 0.108 & 0.463 & 0.607 & 0.081 & 0.073 & 0.137 & 0.115 & 0.496 & 0.960 \\
# pro\_volstrom\_l/h & 0.171 & 0.183 & 0.120 & 0.136 & 0.096 & 0.206 & 0.128 & 0.249 & 0.087 & 0.157 & 0.130 & 0.248 & 0.163 & 0.192 & \textbf{0.060} & 0.078 & 0.084 & 0.111 & 0.384 & 0.637 & \textbf{0.060} & 0.078 & 0.118 & 0.108 & 0.398 & 1.071 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_3: 5 sensors x 26 mode/approach cols -- W1 (value) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_3, experiment 960 (test evaluation). W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the distribution of magnitudes right, as a fraction of the sensor's typical real scale. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_value\_960\_test\_process\_3}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# dampfmenge\_kg/h\_nmb+cip & 0.335 & 0.426 & \textbf{0.256} & 0.388 & 0.407 & 0.368 & 0.278 & 0.366 & 0.274 & 0.420 & 0.327 & 0.408 & 0.391 & 0.361 & 0.261 & 0.331 & 0.307 & 0.316 & 0.302 & 0.339 & 0.261 & 0.331 & 0.307 & 0.316 & 0.618 & 0.434 \\
# medium\_power\_kW & 0.290 & 0.426 & 0.191 & 0.388 & 0.382 & 0.368 & 0.275 & 0.366 & 0.235 & 0.420 & 0.300 & 0.408 & 0.434 & 0.361 & \textbf{0.188} & 0.331 & 0.226 & 0.316 & 0.348 & 0.339 & \textbf{0.188} & 0.331 & 0.226 & 0.316 & 0.526 & 0.434 \\
# pro\_menge\_kg & 0.093 & 0.087 & 0.167 & 0.094 & 0.085 & 0.084 & 0.264 & 0.187 & 0.201 & 0.108 & 0.110 & 0.091 & 0.147 & 0.184 & 0.168 & 0.102 & 0.108 & \textbf{0.070} & 0.275 & 0.204 & 0.168 & 0.102 & 0.102 & \textbf{0.070} & 0.173 & 0.218 \\
# pro\_power\_kW & 0.202 & 0.198 & 0.195 & 0.154 & 0.249 & 0.238 & 0.153 & 0.173 & 0.153 & 0.162 & 0.331 & 0.460 & 0.320 & 0.420 & 0.177 & 0.174 & 0.134 & 0.183 & 0.123 & \textbf{0.110} & 0.177 & 0.174 & 0.134 & 0.183 & 0.223 & 0.553 \\
# pro\_volstrom\_l/h & 0.193 & 0.202 & 0.166 & 0.152 & 0.274 & 0.295 & 0.164 & 0.186 & 0.158 & 0.173 & 0.326 & 0.467 & 0.339 & 0.434 & 0.154 & 0.181 & 0.144 & 0.195 & 0.115 & \textbf{0.112} & 0.154 & 0.181 & 0.144 & 0.195 & 0.223 & 0.565 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_4_1: 23 sensors x 26 mode/approach cols -- W1 (value) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_4\_1, experiment 960 (test evaluation). W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the distribution of magnitudes right, as a fraction of the sensor's typical real scale. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_value\_960\_test\_process\_4\_1}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# dampf\_nassmischbereich & 0.967 & 1.077 & \textbf{0.959} & 1.078 & 0.962 & 1.078 & 0.964 & 1.078 & 0.965 & 1.078 & 0.963 & 1.078 & 0.969 & 1.079 & 0.969 & 1.078 & 0.969 & 1.078 & 0.978 & 1.072 & 0.968 & 1.078 & 0.972 & 1.078 & 0.967 & 1.078 \\
# f10\_speise\_den\_kg/m3 & 0.714 & 0.712 & 0.685 & 0.717 & 0.665 & 0.718 & 0.675 & 0.718 & 0.624 & 0.717 & \textbf{0.614} & 0.717 & 0.672 & 0.715 & 0.636 & 0.717 & 0.628 & 0.717 & 0.659 & 0.716 & 0.653 & 0.717 & 0.621 & 0.717 & 0.663 & 0.699 \\
# f10\_speise\_mas\_kg/h & 1.016 & 0.993 & 0.989 & 1.023 & 0.990 & 1.024 & \textbf{0.906} & 1.024 & 0.969 & 1.020 & 0.976 & 1.023 & 0.979 & 1.002 & 0.982 & 1.010 & 0.986 & 1.014 & 0.966 & 1.007 & 0.982 & 1.008 & 0.981 & 1.014 & 0.989 & 1.001 \\
# f10\_speise\_vol\_l/h & 1.033 & 0.988 & 0.981 & 1.005 & 0.995 & 1.005 & \textbf{0.886} & 1.006 & 0.952 & 1.002 & 0.979 & 1.004 & 0.979 & 0.994 & 0.961 & 1.006 & 0.978 & 1.006 & 0.966 & 0.999 & 0.953 & 1.005 & 0.980 & 1.006 & 1.000 & 0.987 \\
# f11\_speise\_mas\_kg/h & 0.675 & 0.715 & 0.666 & 0.753 & 0.691 & 0.754 & 0.715 & 0.760 & 0.670 & 0.751 & 0.710 & 0.751 & 0.712 & 0.750 & 0.741 & 0.764 & 0.753 & 0.764 & 0.708 & 0.728 & 0.740 & 0.763 & 0.742 & 0.763 & 0.687 & \textbf{0.653} \\
# f11\_speise\_vol\_l/h & 0.745 & 0.712 & 0.784 & 0.755 & 0.789 & 0.757 & 0.735 & 0.756 & 0.748 & 0.753 & 0.741 & 0.754 & 0.814 & 0.747 & 0.823 & 0.768 & 0.791 & 0.768 & 0.792 & 0.714 & 0.819 & 0.768 & 0.787 & 0.768 & 0.808 & \textbf{0.666} \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_4_2: 23 sensors x 26 mode/approach cols -- W1 (value) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_4\_2, experiment 960 (test evaluation). W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the distribution of magnitudes right, as a fraction of the sensor's typical real scale. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_value\_960\_test\_process\_4\_2}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# (10)\_abluft\_temp\_c & 0.090 & 0.032 & 0.088 & \textbf{0.032} & 0.088 & \textbf{0.032} & 0.092 & 0.039 & 0.097 & 0.039 & 0.095 & 0.039 & 0.099 & 0.038 & 0.098 & 0.039 & 0.097 & 0.039 & 0.096 & 0.038 & 0.099 & 0.039 & 0.096 & 0.039 & 0.089 & 0.038 \\
# (12)\_mpt\_fb(mpt?)\_kg/h & \textbf{0.037} & 0.075 & 0.038 & 0.070 & 0.038 & 0.070 & 0.052 & 0.070 & 0.048 & 0.069 & 0.047 & 0.069 & 0.043 & 0.071 & 0.052 & 0.072 & 0.052 & 0.072 & 0.044 & 0.073 & 0.052 & 0.072 & 0.052 & 0.072 & 0.063 & 0.082 \\
# f10\_speise\_den\_kg/m3 & 0.739 & 0.704 & 0.739 & 0.708 & 0.739 & 0.707 & 0.666 & 0.701 & \textbf{0.664} & 0.709 & 0.677 & 0.706 & 0.690 & 0.716 & 0.692 & 0.717 & 0.692 & 0.717 & 0.695 & 0.719 & 0.692 & 0.717 & 0.692 & 0.717 & 0.728 & 0.717 \\
# f10\_speise\_mas\_kg/h & 1.044 & 1.092 & 1.050 & 1.121 & 1.050 & 1.121 & 0.947 & 1.111 & 0.984 & 1.121 & 0.995 & 1.121 & 1.011 & 1.119 & 0.998 & 1.124 & 1.000 & 1.124 & \textbf{0.918} & 1.043 & 1.011 & 1.124 & 1.001 & 1.125 & 0.998 & 0.971 \\
# f10\_speise\_vol\_l/h & 1.030 & 1.047 & 0.946 & 1.080 & 0.946 & 1.079 & 0.966 & 1.066 & 0.924 & 1.078 & 0.935 & 1.079 & 0.925 & 1.073 & 0.933 & 1.075 & 0.917 & 1.075 & \textbf{0.875} & 0.989 & 0.930 & 1.074 & 0.914 & 1.075 & 0.908 & 0.939 \\
# f11\_speise\_mas\_kg/h & 0.981 & 0.764 & 0.835 & 0.772 & 0.835 & 0.771 & 0.848 & 0.766 & 0.842 & 0.768 & 0.841 & 0.768 & 0.891 & 0.768 & 0.859 & 0.772 & 0.835 & 0.772 & 0.866 & \textbf{0.690} & 0.838 & 0.772 & 0.835 & 0.772 & 0.875 & 0.825 \\
# f11\_speise\_vol\_l/h & 0.980 & 0.741 & 0.921 & 0.758 & 0.924 & 0.758 & 0.979 & 0.753 & 0.942 & 0.755 & 0.943 & 0.755 & 0.990 & 0.755 & 0.979 & 0.758 & 0.943 & 0.758 & 0.977 & \textbf{0.678} & 0.980 & 0.758 & 0.941 & 0.758 & 0.906 & 0.797 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % === process_5: 28 sensors x 26 mode/approach cols -- W1 (value) ===
# \begin{table}[H]
# \caption{Complete-profile evaluation for process\_5, experiment 960 (test evaluation). W1 (value), scale-free (relative to the sensor's real per-case-mean median) --- is the distribution of magnitudes right, as a fraction of the sensor's typical real scale. Lower is better. \textbf{Bold} = best mode/approach per sensor.}
# \label{tab:complete\_profile\_relative\_wasserstein\_value\_960\_test\_process\_5}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c}
# \toprule
#  & alpha / baseline (Best) & alpha / baseline (Baseline) & alpha / ml\_global (Best) & alpha / ml\_global (Baseline) & alpha / ml\_local (Best) & alpha / ml\_local (Baseline) & budget / baseline (Best) & budget / baseline (Baseline) & budget / ml\_global (Best) & budget / ml\_global (Baseline) & budget / ml\_local (Best) & budget / ml\_local (Baseline) & heuristic / baseline (Best) & heuristic / baseline (Baseline) & heuristic / ml\_global (Best) & heuristic / ml\_global (Baseline) & heuristic / ml\_local (Best) & heuristic / ml\_local (Baseline) & wip\_aware / baseline (Best) & wip\_aware / baseline (Baseline) & wip\_aware / ml\_global (Best) & wip\_aware / ml\_global (Baseline) & wip\_aware / ml\_local (Best) & wip\_aware / ml\_local (Baseline) & wip\_branching\_aware / baseline (Best) & wip\_branching\_aware / baseline (Baseline) \\
# sensor\_short &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# A016\_temp\_vor\_Vorwärmer\_30121TT001\_(WT\_… & \textbf{0.023} & 0.032 & 0.030 & 0.030 & 0.026 & 0.029 & 0.045 & 0.028 & 0.061 & 0.027 & 0.046 & 0.026 & 0.061 & 0.027 & 0.064 & 0.027 & 0.050 & 0.026 & 0.040 & 0.026 & 0.064 & 0.027 & 0.050 & 0.026 & 0.034 & 0.028 \\
# A047\_temp\_Produkt\_Einlauf\_30110TT001\_5s & 0.113 & 0.079 & 0.091 & 0.080 & 0.103 & \textbf{0.074} & 0.242 & 0.089 & 0.235 & 0.090 & 0.245 & 0.086 & 0.224 & 0.088 & 0.201 & 0.096 & 0.243 & 0.089 & 0.271 & 0.086 & 0.201 & 0.096 & 0.243 & 0.089 & 0.152 & 0.086 \\
# A054\_flow\_Vorlaufpumpe\_30110FT301\_5s & 0.116 & 0.139 & 0.133 & 0.130 & 0.144 & 0.155 & 0.107 & 0.115 & 0.102 & 0.116 & 0.101 & 0.123 & 0.104 & 0.125 & 0.104 & 0.103 & 0.114 & 0.115 & 0.089 & \textbf{0.089} & 0.104 & 0.103 & 0.114 & 0.115 & 0.122 & 0.165 \\
baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                   0.537  0.510
#           autoclave_steam_demand_kW                           2.075  1.811
#           bottling_power_kW                                     NaN  0.114
#           destillation_cooling_demand_kW                      3.948  3.963
#           destillation_steam_demand_kW                        5.202  5.279
# ...                                                             ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                 0.060  0.064
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…            0.006  0.007
#           temp_nach_WR2_(WT2)_5s                              0.067  0.060
#           temp_vor_Vorwärmer_(WT_2)_1h                        0.043  0.027
#           vor_Vorwärmer_(WT_2)_5s                             0.032  0.021
#
# mode_label                                         alpha / ml_global         \
# approach_label                                              Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                    0.428  0.417
#           autoclave_steam_demand_kW                            2.201  2.007
#           bottling_power_kW                                      NaN  0.129
#           destillation_cooling_demand_kW                       3.918  3.919
#           destillation_steam_demand_kW                         5.336  5.331
# ...                                                              ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                  0.063  0.063
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…             0.005  0.007
#           temp_nach_WR2_(WT2)_5s                               0.083  0.076
#           temp_vor_Vorwärmer_(WT_2)_1h                         0.043  0.026
#           vor_Vorwärmer_(WT_2)_5s                              0.030  0.027
#
# mode_label                                         alpha / ml_local         \
# approach_label                                             Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                   0.561  0.547
#           autoclave_steam_demand_kW                           1.985  1.806
#           bottling_power_kW                                     NaN  0.125
#           destillation_cooling_demand_kW                      3.897  3.880
#           destillation_steam_demand_kW                        5.240  5.239
# ...                                                             ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                 0.064  0.066
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…            0.005  0.007
#           temp_nach_WR2_(WT2)_5s                              0.081  0.078
#           temp_vor_Vorwärmer_(WT_2)_1h                        0.043  0.022
#           vor_Vorwärmer_(WT_2)_5s                             0.029  0.024
#
# mode_label                                         budget / baseline         \
# approach_label                                              Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                    1.042  0.965
#           autoclave_steam_demand_kW                            1.641  1.543
#           bottling_power_kW                                      NaN  0.112
#           destillation_cooling_demand_kW                       4.374  4.412
#           destillation_steam_demand_kW                         6.076  6.119
# ...                                                              ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                  0.060  0.055
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…             0.007  0.013
#           temp_nach_WR2_(WT2)_5s                               0.071  0.068
#           temp_vor_Vorwärmer_(WT_2)_1h                         0.036  0.037
#           vor_Vorwärmer_(WT_2)_5s                              0.028  0.045
#
# mode_label                                         budget / ml_global         \
# approach_label                                               Baseline   Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                     0.989  0.684
#           autoclave_steam_demand_kW                             1.513  1.359
#           bottling_power_kW                                       NaN  0.129
#           destillation_cooling_demand_kW                        4.415  4.410
#           destillation_steam_demand_kW                          6.048  6.049
# ...                                                               ...    ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                   0.064  0.062
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…              0.006  0.012
#           temp_nach_WR2_(WT2)_5s                                0.060  0.073
#           temp_vor_Vorwärmer_(WT_2)_1h                          0.037  0.035
#           vor_Vorwärmer_(WT_2)_5s                               0.027  0.061
#
# mode_label                                          ... heuristic / ml_local  \
# approach_label                                      ...             Baseline
# process   sensor_short                              ...
# process_1 autoclave_cooling_water_demand_kW         ...                1.046
#           autoclave_steam_demand_kW                 ...                1.442
#           bottling_power_kW                         ...                  NaN
#           destillation_cooling_demand_kW            ...                3.129
#           destillation_steam_demand_kW              ...                4.216
# ...                                                 ...                  ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       ...                0.050
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  ...                0.006
#           temp_nach_WR2_(WT2)_5s                    ...                0.069
#           temp_vor_Vorwärmer_(WT_2)_1h              ...                0.036
#           vor_Vorwärmer_(WT_2)_5s                   ...                0.026
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.632
#           autoclave_steam_demand_kW                 1.330
#           bottling_power_kW                         0.125
#           destillation_cooling_demand_kW            3.125
#           destillation_steam_demand_kW              4.200
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.057
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.013
#           temp_nach_WR2_(WT2)_5s                    0.077
#           temp_vor_Vorwärmer_(WT_2)_1h              0.031
#           vor_Vorwärmer_(WT_2)_5s                   0.051
#
# mode_label                                         wip_aware / baseline  \
# approach_label                                                 Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                       0.614
#           autoclave_steam_demand_kW                               2.367
#           bottling_power_kW                                         NaN
#           destillation_cooling_demand_kW                          2.597
#           destillation_steam_demand_kW                            3.411
# ...                                                                 ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                     0.056
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                0.006
#           temp_nach_WR2_(WT2)_5s                                  0.062
#           temp_vor_Vorwärmer_(WT_2)_1h                            0.037
#           vor_Vorwärmer_(WT_2)_5s                                 0.026
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.516
#           autoclave_steam_demand_kW                 2.064
#           bottling_power_kW                         0.131
#           destillation_cooling_demand_kW            2.633
#           destillation_steam_demand_kW              3.441
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.056
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.012
#           temp_nach_WR2_(WT2)_5s                    0.072
#           temp_vor_Vorwärmer_(WT_2)_1h              0.029
#           vor_Vorwärmer_(WT_2)_5s                   0.040
#
# mode_label                                         wip_aware / ml_global  \
# approach_label                                                  Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                        1.004
#           autoclave_steam_demand_kW                                1.424
#           bottling_power_kW                                          NaN
#           destillation_cooling_demand_kW                           3.062
#           destillation_steam_demand_kW                             4.158
# ...                                                                  ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                      0.064
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                 0.006
#           temp_nach_WR2_(WT2)_5s                                   0.073
#           temp_vor_Vorwärmer_(WT_2)_1h                             0.036
#           vor_Vorwärmer_(WT_2)_5s                                  0.027
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.591
#           autoclave_steam_demand_kW                 1.349
#           bottling_power_kW                         0.129
#           destillation_cooling_demand_kW            3.056
#           destillation_steam_demand_kW              4.168
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.061
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.013
#           temp_nach_WR2_(WT2)_5s                    0.077
#           temp_vor_Vorwärmer_(WT_2)_1h              0.032
#           vor_Vorwärmer_(WT_2)_5s                   0.064
#
# mode_label                                         wip_aware / ml_local  \
# approach_label                                                 Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                       1.046
#           autoclave_steam_demand_kW                               1.442
#           bottling_power_kW                                         NaN
#           destillation_cooling_demand_kW                          3.175
#           destillation_steam_demand_kW                            4.298
# ...                                                                 ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                     0.050
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                0.006
#           temp_nach_WR2_(WT2)_5s                                  0.069
#           temp_vor_Vorwärmer_(WT_2)_1h                            0.036
#           vor_Vorwärmer_(WT_2)_5s                                 0.026
#
# mode_label                                                 \
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.614
#           autoclave_steam_demand_kW                 1.330
#           bottling_power_kW                         0.124
#           destillation_cooling_demand_kW            3.163
#           destillation_steam_demand_kW              4.276
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.057
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.013
#           temp_nach_WR2_(WT2)_5s                    0.077
#           temp_vor_Vorwärmer_(WT_2)_1h              0.031
#           vor_Vorwärmer_(WT_2)_5s                   0.051
#
# mode_label                                         wip_branching_aware / baseline  \
# approach_label                                                           Baseline
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW                                 0.661
#           autoclave_steam_demand_kW                                         2.212
#           bottling_power_kW                                                   NaN
#           destillation_cooling_demand_kW                                    3.249
#           destillation_steam_demand_kW                                      4.219
# ...                                                                           ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s                               0.067
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…                          0.005
#           temp_nach_WR2_(WT2)_5s                                            0.083
#           temp_vor_Vorwärmer_(WT_2)_1h                                      0.037
#           vor_Vorwärmer_(WT_2)_5s                                           0.028
#
# mode_label
# approach_label                                       Best
# process   sensor_short
# process_1 autoclave_cooling_water_demand_kW         0.731
#           autoclave_steam_demand_kW                 1.894
#           bottling_power_kW                         0.128
#           destillation_cooling_demand_kW            3.262
#           destillation_steam_demand_kW              4.159
# ...                                                   ...
# process_5 temp_nach_Kuehlturmkuehler_(WT6)_5s       0.072
#           temp_nach_WR2,_vor_Druckerhoehungspumpe…  0.007
#           temp_nach_WR2_(WT2)_5s                    0.077
#           temp_vor_Vorwärmer_(WT_2)_1h              0.024
#           vor_Vorwärmer_(WT_2)_5s                   0.034
#
# [90 rows x 26 columns]

# %% [markdown]
# ### Aggregated ranking (complete-profile, one number per process x method)
#
# Same rollup as the Energy-Distribution ranking above, applied to the complete-profile
# metrics: median over sensors per process, then median over processes for `Overall`.
# Each row is one (mode, curve approach) combination. Rows sorted best-to-worst.

# %%
# -- Aggregated ranking: complete-profile W1 (time) / W1 (value), relative --
def _cc_ranking_table(metric_col, metric_label):
    if df_complete_curve.empty:
        print('Nothing to show -- df_complete_curve is empty.')
        return None
    dfc = df_complete_curve[df_complete_curve['approach'].isin(_cc_approach_labels)].copy()
    dfc['mode_label'] = dfc['mode'].map(display_mode)
    dfc['approach_label'] = dfc['approach'].map(_cc_approach_labels)
    dfc['method_label'] = dfc['mode_label'] + ' (' + dfc['approach_label'] + ')'

    rank_agg = dfc.groupby(['process', 'method_label'])[metric_col].median().reset_index()
    rank_pivot = rank_agg.pivot(index='method_label', columns='process', values=metric_col)
    rank_pivot['Overall'] = rank_pivot.median(axis=1)
    rank_pivot = rank_pivot.sort_values('Overall')

    str_table = pd.DataFrame(index=rank_pivot.index, columns=rank_pivot.columns, dtype=object)
    for col in rank_pivot.columns:
        vals = rank_pivot[col].dropna()
        if vals.empty:
            str_table[col] = ''
            continue
        best_val = vals.min()
        for idx in rank_pivot.index:
            val = rank_pivot.loc[idx, col]
            if pd.isna(val):
                str_table.loc[idx, col] = ''
                continue
            fmt = f'{val:.3f}'
            str_table.loc[idx, col] = (r'\textbf{' + fmt + r'}') if abs(val - best_val) < 1e-6 else fmt

    n_cols = len(rank_pivot.columns)
    col_format = 'l|' + '|'.join(['c'] * (n_cols - 1)) + '|c'
    rank_latex = str_table.to_latex(
        escape=False, column_format=col_format,
        caption=(
            f'Aggregated complete-profile ranking, experiment {EXPERIMENT} ({SPLIT} evaluation), {metric_label}. '
            r'Median relative distance over sensors per process, then median over processes for Overall. '
            r'Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:complete_profile_ranking_{metric_col}_{EXPERIMENT}_{SPLIT}',
        position='H',
    )
    print(rank_latex.replace('_', r'\_'))
    display(rank_pivot.round(3))
    return rank_pivot

_cc_time_rank = _cc_ranking_table('relative_wasserstein_time', 'W1 (time)')
# Out:
# \begin{table}[H]
# \caption{Aggregated complete-profile ranking, experiment 960 (test evaluation), W1 (time). Median relative distance over sensors per process, then median over processes for Overall. Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.}
# \label{tab:complete\_profile\_ranking\_relative\_wasserstein\_time\_960\_test}
# \begin{tabular}{l|c|c|c|c|c|c|c}
# \toprule
# process & process\_1 & process\_2 & process\_3 & process\_4\_1 & process\_4\_2 & process\_5 & Overall \\
# method\_label &  &  &  &  &  &  &  \\
# \midrule
# budget / ml\_local (Best) & \textbf{0.021} & 0.190 & 0.156 & \textbf{0.087} & 0.079 & 0.062 & \textbf{0.083} \\
# budget / ml\_local (Baseline) & 0.025 & 0.198 & 0.169 & 0.088 & 0.080 & 0.063 & 0.084 \\
# budget / ml\_global (Best) & 0.051 & 0.142 & 0.170 & 0.104 & \textbf{0.078} & \textbf{0.061} & 0.091 \\
# budget / ml\_global (Baseline) & 0.057 & \textbf{0.141} & \textbf{0.145} & 0.104 & 0.078 & 0.061 & 0.091 \\
# budget / baseline (Baseline) & 0.114 & 0.210 & 0.192 & 0.155 & 0.136 & 0.094 & 0.146 \\
# budget / baseline (Best) & 0.101 & 0.190 & 0.187 & 0.155 & 0.136 & 0.095 & 0.146 \\
# heuristic / ml\_local (Baseline) & 0.032 & 0.285 & 0.258 & 0.181 & 0.220 & 0.225 & 0.222 \\
# heuristic / ml\_local (Best) & 0.024 & 0.284 & 0.282 & 0.182 & 0.221 & 0.226 & 0.223 \\
# wip\_aware / ml\_local (Baseline) & 0.036 & 1.641 & 0.235 & 0.176 & 0.224 & 0.225 & 0.224 \\
# wip\_aware / ml\_local (Best) & 0.028 & 1.806 & 0.273 & 0.176 & 0.224 & 0.226 & 0.225 \\
# alpha / ml\_global (Baseline) & 0.165 & 0.216 & 0.712 & 0.284 & 0.229 & 0.242 & 0.236 \\
# alpha / ml\_global (Best) & 0.107 & 0.235 & 0.596 & 0.284 & 0.229 & 0.243 & 0.239 \\
# alpha / ml\_local (Baseline) & 0.135 & 0.235 & 0.314 & 0.276 & 0.224 & 0.371 & 0.255 \\
# heuristic / ml\_global (Baseline) & 0.060 & 0.297 & 0.368 & 0.167 & 0.223 & 0.336 & 0.260 \\
# wip\_aware / baseline (Baseline) & 0.105 & 1.235 & 0.263 & 0.260 & 0.244 & 0.429 & 0.261 \\
# heuristic / baseline (Best) & 0.114 & 0.231 & 0.297 & 0.255 & 0.269 & 0.431 & 0.262 \\
# alpha / ml\_local (Best) & 0.079 & 0.251 & 0.324 & 0.276 & 0.224 & 0.371 & 0.263 \\
# heuristic / baseline (Baseline) & 0.136 & 0.294 & 0.260 & 0.255 & 0.269 & 0.433 & 0.265 \\
# wip\_aware / ml\_global (Baseline) & 0.060 & 1.517 & 0.368 & 0.179 & 0.204 & 0.336 & 0.270 \\
# wip\_aware / ml\_global (Best) & 0.052 & 1.458 & 0.414 & 0.179 & 0.205 & 0.336 & 0.270 \\
# wip\_aware / baseline (Best) & 0.085 & 1.238 & 0.286 & 0.259 & 0.243 & 0.428 & 0.273 \\
# heuristic / ml\_global (Best) & 0.052 & 0.359 & 0.441 & 0.167 & 0.223 & 0.336 & 0.279 \\
# alpha / baseline (Baseline) & 0.179 & 0.274 & 0.537 & 0.248 & 0.325 & 0.388 & 0.299 \\
# alpha / baseline (Best) & 0.136 & 0.277 & 0.535 & 0.248 & 0.325 & 0.388 & 0.301 \\
# wip\_branching\_aware / baseline (Best) & 0.120 & 0.419 & 0.356 & 0.320 & 0.306 & 0.498 & 0.338 \\
# wip\_branching\_aware / baseline (Baseline) & 0.157 & 0.426 & 0.391 & 0.319 & 0.305 & 0.498 & 0.355 \\
# \bottomrule
# \end{tabular}
# \end{table}
# process                                    process_1  process_2  process_3  \
# method_label
# budget / ml_local (Best)                       0.021      0.190      0.156
# budget / ml_local (Baseline)                   0.025      0.198      0.169
# budget / ml_global (Best)                      0.051      0.142      0.170
# budget / ml_global (Baseline)                  0.057      0.141      0.145
# budget / baseline (Baseline)                   0.114      0.210      0.192
# budget / baseline (Best)                       0.101      0.190      0.187
# heuristic / ml_local (Baseline)                0.032      0.285      0.258
# heuristic / ml_local (Best)                    0.024      0.284      0.282
# wip_aware / ml_local (Baseline)                0.036      1.641      0.235
# wip_aware / ml_local (Best)                    0.028      1.806      0.273
# alpha / ml_global (Baseline)                   0.165      0.216      0.712
# alpha / ml_global (Best)                       0.107      0.235      0.596
# alpha / ml_local (Baseline)                    0.135      0.235      0.314
# heuristic / ml_global (Baseline)               0.060      0.297      0.368
# wip_aware / baseline (Baseline)                0.105      1.235      0.263
# heuristic / baseline (Best)                    0.114      0.231      0.297
# alpha / ml_local (Best)                        0.079      0.251      0.324
# heuristic / baseline (Baseline)                0.136      0.294      0.260
# wip_aware / ml_global (Baseline)               0.060      1.517      0.368
# wip_aware / ml_global (Best)                   0.052      1.458      0.414
# wip_aware / baseline (Best)                    0.085      1.238      0.286
# heuristic / ml_global (Best)                   0.052      0.359      0.441
# alpha / baseline (Baseline)                    0.179      0.274      0.537
# alpha / baseline (Best)                        0.136      0.277      0.535
# wip_branching_aware / baseline (Best)          0.120      0.419      0.356
# wip_branching_aware / baseline (Baseline)      0.157      0.426      0.391
#
# process                                    process_4_1  process_4_2  \
# method_label
# budget / ml_local (Best)                         0.087        0.079
# budget / ml_local (Baseline)                     0.088        0.080
# budget / ml_global (Best)                        0.104        0.078
# budget / ml_global (Baseline)                    0.104        0.078
# budget / baseline (Baseline)                     0.155        0.136
# budget / baseline (Best)                         0.155        0.136
# heuristic / ml_local (Baseline)                  0.181        0.220
# heuristic / ml_local (Best)                      0.182        0.221
# wip_aware / ml_local (Baseline)                  0.176        0.224
# wip_aware / ml_local (Best)                      0.176        0.224
# alpha / ml_global (Baseline)                     0.284        0.229
# alpha / ml_global (Best)                         0.284        0.229
# alpha / ml_local (Baseline)                      0.276        0.224
# heuristic / ml_global (Baseline)                 0.167        0.223
# wip_aware / baseline (Baseline)                  0.260        0.244
# heuristic / baseline (Best)                      0.255        0.269
# alpha / ml_local (Best)                          0.276        0.224
# heuristic / baseline (Baseline)                  0.255        0.269
# wip_aware / ml_global (Baseline)                 0.179        0.204
# wip_aware / ml_global (Best)                     0.179        0.205
# wip_aware / baseline (Best)                      0.259        0.243
# heuristic / ml_global (Best)                     0.167        0.223
# alpha / baseline (Baseline)                      0.248        0.325
# alpha / baseline (Best)                          0.248        0.325
# wip_branching_aware / baseline (Best)            0.320        0.306
# wip_branching_aware / baseline (Baseline)        0.319        0.305
#
# process                                    process_5  Overall
# method_label
# budget / ml_local (Best)                       0.062    0.083
# budget / ml_local (Baseline)                   0.063    0.084
# budget / ml_global (Best)                      0.061    0.091
# budget / ml_global (Baseline)                  0.061    0.091
# budget / baseline (Baseline)                   0.094    0.146
# budget / baseline (Best)                       0.095    0.146
# heuristic / ml_local (Baseline)                0.225    0.222
# heuristic / ml_local (Best)                    0.226    0.223
# wip_aware / ml_local (Baseline)                0.225    0.224
# wip_aware / ml_local (Best)                    0.226    0.225
# alpha / ml_global (Baseline)                   0.242    0.236
# alpha / ml_global (Best)                       0.243    0.239
# alpha / ml_local (Baseline)                    0.371    0.255
# heuristic / ml_global (Baseline)               0.336    0.260
# wip_aware / baseline (Baseline)                0.429    0.261
# heuristic / baseline (Best)                    0.431    0.262
# alpha / ml_local (Best)                        0.371    0.263
# heuristic / baseline (Baseline)                0.433    0.265
# wip_aware / ml_global (Baseline)               0.336    0.270
# wip_aware / ml_global (Best)                   0.336    0.270
# wip_aware / baseline (Best)                    0.428    0.273
# heuristic / ml_global (Best)                   0.336    0.279
# alpha / baseline (Baseline)                    0.388    0.299
# alpha / baseline (Best)                        0.388    0.301
# wip_branching_aware / baseline (Best)          0.498    0.338
# wip_branching_aware / baseline (Baseline)      0.498    0.355

# %%
_cc_value_rank = _cc_ranking_table('relative_wasserstein_value', 'W1 (value)')
# Out:
# \begin{table}[H]
# \caption{Aggregated complete-profile ranking, experiment 960 (test evaluation), W1 (value). Median relative distance over sensors per process, then median over processes for Overall. Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.}
# \label{tab:complete\_profile\_ranking\_relative\_wasserstein\_value\_960\_test}
# \begin{tabular}{l|c|c|c|c|c|c|c}
# \toprule
# process & process\_1 & process\_2 & process\_3 & process\_4\_1 & process\_4\_2 & process\_5 & Overall \\
# method\_label &  &  &  &  &  &  &  \\
# \midrule
# alpha / ml\_global (Baseline) & 2.201 & 0.136 & 0.154 & 0.085 & 0.272 & 0.086 & \textbf{0.145} \\
# heuristic / ml\_local (Baseline) & 1.442 & \textbf{0.112} & 0.195 & 0.084 & 0.266 & 0.095 & 0.153 \\
# wip\_aware / ml\_local (Baseline) & 1.442 & 0.115 & 0.195 & 0.084 & 0.266 & 0.095 & 0.155 \\
# heuristic / ml\_global (Baseline) & 1.424 & 0.131 & 0.181 & 0.084 & 0.266 & 0.096 & 0.156 \\
# wip\_aware / ml\_global (Baseline) & 1.424 & 0.131 & 0.181 & 0.084 & 0.266 & 0.096 & 0.156 \\
# budget / ml\_global (Baseline) & 1.513 & 0.157 & 0.173 & 0.084 & 0.266 & 0.090 & 0.165 \\
# heuristic / ml\_local (Best) & 0.981 & 0.134 & \textbf{0.144} & 0.337 & 0.220 & 0.115 & 0.182 \\
# wip\_aware / ml\_local (Best) & 0.972 & 0.137 & \textbf{0.144} & 0.337 & 0.220 & 0.115 & 0.182 \\
# alpha / ml\_global (Best) & 1.256 & 0.120 & 0.191 & 0.331 & 0.188 & 0.120 & 0.189 \\
# alpha / baseline (Baseline) & 2.075 & 0.183 & 0.202 & 0.081 & 0.278 & \textbf{0.085} & 0.193 \\
# heuristic / ml\_global (Best) & \textbf{0.970} & 0.130 & 0.177 & 0.333 & 0.217 & 0.107 & 0.197 \\
# wip\_aware / ml\_global (Best) & \textbf{0.970} & 0.130 & 0.177 & 0.334 & 0.218 & 0.107 & 0.197 \\
# alpha / baseline (Best) & 1.161 & 0.171 & 0.202 & 0.312 & 0.202 & 0.112 & 0.202 \\
# budget / ml\_global (Best) & 1.022 & 0.122 & 0.201 & 0.335 & 0.220 & 0.099 & 0.210 \\
# budget / baseline (Baseline) & 1.641 & 0.249 & 0.187 & 0.085 & 0.266 & 0.096 & 0.218 \\
# heuristic / baseline (Baseline) & 1.443 & 0.192 & 0.361 & 0.083 & 0.266 & 0.095 & 0.229 \\
# wip\_aware / baseline (Baseline) & 2.367 & 0.351 & 0.204 & \textbf{0.071} & 0.267 & 0.089 & 0.236 \\
# alpha / ml\_local (Best) & 1.176 & 0.201 & 0.274 & 0.332 & \textbf{0.181} & 0.124 & 0.238 \\
# alpha / ml\_local (Baseline) & 1.985 & 0.206 & 0.295 & 0.085 & 0.272 & 0.090 & 0.239 \\
# budget / baseline (Best) & 1.254 & 0.242 & 0.264 & 0.318 & 0.216 & 0.109 & 0.253 \\
# budget / ml\_local (Baseline) & 1.508 & 0.248 & 0.408 & 0.084 & 0.266 & 0.104 & 0.257 \\
# budget / ml\_local (Best) & 1.087 & 0.184 & 0.326 & 0.333 & 0.218 & 0.098 & 0.272 \\
# heuristic / baseline (Best) & 0.986 & 0.205 & 0.339 & 0.340 & 0.201 & 0.103 & 0.272 \\
# wip\_branching\_aware / baseline (Best) & 1.313 & 0.496 & 0.223 & 0.332 & 0.204 & 0.116 & 0.278 \\
# wip\_aware / baseline (Best) & 1.290 & 0.384 & 0.275 & 0.337 & 0.205 & 0.099 & 0.306 \\
# wip\_branching\_aware / baseline (Baseline) & 2.212 & 0.811 & 0.434 & 0.075 & 0.284 & 0.089 & 0.359 \\
# \bottomrule
# \end{tabular}
# \end{table}
# process                                    process_1  process_2  process_3  \
# method_label
# alpha / ml_global (Baseline)                   2.201      0.136      0.154
# heuristic / ml_local (Baseline)                1.442      0.112      0.195
# wip_aware / ml_local (Baseline)                1.442      0.115      0.195
# heuristic / ml_global (Baseline)               1.424      0.131      0.181
# wip_aware / ml_global (Baseline)               1.424      0.131      0.181
# budget / ml_global (Baseline)                  1.513      0.157      0.173
# heuristic / ml_local (Best)                    0.981      0.134      0.144
# wip_aware / ml_local (Best)                    0.972      0.137      0.144
# alpha / ml_global (Best)                       1.256      0.120      0.191
# alpha / baseline (Baseline)                    2.075      0.183      0.202
# heuristic / ml_global (Best)                   0.970      0.130      0.177
# wip_aware / ml_global (Best)                   0.970      0.130      0.177
# alpha / baseline (Best)                        1.161      0.171      0.202
# budget / ml_global (Best)                      1.022      0.122      0.201
# budget / baseline (Baseline)                   1.641      0.249      0.187
# heuristic / baseline (Baseline)                1.443      0.192      0.361
# wip_aware / baseline (Baseline)                2.367      0.351      0.204
# alpha / ml_local (Best)                        1.176      0.201      0.274
# alpha / ml_local (Baseline)                    1.985      0.206      0.295
# budget / baseline (Best)                       1.254      0.242      0.264
# budget / ml_local (Baseline)                   1.508      0.248      0.408
# budget / ml_local (Best)                       1.087      0.184      0.326
# heuristic / baseline (Best)                    0.986      0.205      0.339
# wip_branching_aware / baseline (Best)          1.313      0.496      0.223
# wip_aware / baseline (Best)                    1.290      0.384      0.275
# wip_branching_aware / baseline (Baseline)      2.212      0.811      0.434
#
# process                                    process_4_1  process_4_2  \
# method_label
# alpha / ml_global (Baseline)                     0.085        0.272
# heuristic / ml_local (Baseline)                  0.084        0.266
# wip_aware / ml_local (Baseline)                  0.084        0.266
# heuristic / ml_global (Baseline)                 0.084        0.266
# wip_aware / ml_global (Baseline)                 0.084        0.266
# budget / ml_global (Baseline)                    0.084        0.266
# heuristic / ml_local (Best)                      0.337        0.220
# wip_aware / ml_local (Best)                      0.337        0.220
# alpha / ml_global (Best)                         0.331        0.188
# alpha / baseline (Baseline)                      0.081        0.278
# heuristic / ml_global (Best)                     0.333        0.217
# wip_aware / ml_global (Best)                     0.334        0.218
# alpha / baseline (Best)                          0.312        0.202
# budget / ml_global (Best)                        0.335        0.220
# budget / baseline (Baseline)                     0.085        0.266
# heuristic / baseline (Baseline)                  0.083        0.266
# wip_aware / baseline (Baseline)                  0.071        0.267
# alpha / ml_local (Best)                          0.332        0.181
# alpha / ml_local (Baseline)                      0.085        0.272
# budget / baseline (Best)                         0.318        0.216
# budget / ml_local (Baseline)                     0.084        0.266
# budget / ml_local (Best)                         0.333        0.218
# heuristic / baseline (Best)                      0.340        0.201
# wip_branching_aware / baseline (Best)            0.332        0.204
# wip_aware / baseline (Best)                      0.337        0.205
# wip_branching_aware / baseline (Baseline)        0.075        0.284
#
# process                                    process_5  Overall
# method_label
# alpha / ml_global (Baseline)                   0.086    0.145
# heuristic / ml_local (Baseline)                0.095    0.153
# wip_aware / ml_local (Baseline)                0.095    0.155
# heuristic / ml_global (Baseline)               0.096    0.156
# wip_aware / ml_global (Baseline)               0.096    0.156
# budget / ml_global (Baseline)                  0.090    0.165
# heuristic / ml_local (Best)                    0.115    0.182
# wip_aware / ml_local (Best)                    0.115    0.182
# alpha / ml_global (Best)                       0.120    0.189
# alpha / baseline (Baseline)                    0.085    0.193
# heuristic / ml_global (Best)                   0.107    0.197
# wip_aware / ml_global (Best)                   0.107    0.197
# alpha / baseline (Best)                        0.112    0.202
# budget / ml_global (Best)                      0.099    0.210
# budget / baseline (Baseline)                   0.096    0.218
# heuristic / baseline (Baseline)                0.095    0.229
# wip_aware / baseline (Baseline)                0.089    0.236
# alpha / ml_local (Best)                        0.124    0.238
# alpha / ml_local (Baseline)                    0.090    0.239
# budget / baseline (Best)                       0.109    0.253
# budget / ml_local (Baseline)                   0.104    0.257
# budget / ml_local (Best)                       0.098    0.272
# heuristic / baseline (Best)                    0.103    0.272
# wip_branching_aware / baseline (Best)          0.116    0.278
# wip_aware / baseline (Best)                    0.099    0.306
# wip_branching_aware / baseline (Baseline)      0.089    0.359

# %% [markdown]
# ### Combined ranking (W1 time + W1 shape pooled into one score)
#
# The two rankings above keep timing and magnitude separate. This one pools both into a
# **single** median per method -- valid only because both are already the scale-free
# `relative_wasserstein_*` versions (unitless: divided by real median case duration / real
# per-case-mean median respectively), never the raw `wasserstein_time_median` (minutes) /
# `wasserstein_value_median` (raw sensor units), which live on completely different scales
# and could never be pooled directly. Median over (sensor x metric) per process, then
# median over processes for `Overall`. Rows sorted best-to-worst.

# %%
# -- Combined complete-profile ranking: W1 (time) + W1 (value), pooled into one score --
def _cc_combined_ranking_table():
    if df_complete_curve.empty:
        print('Nothing to show -- df_complete_curve is empty.')
        return None
    dfc = df_complete_curve[df_complete_curve['approach'].isin(_cc_approach_labels)].copy()
    dfc['mode_label'] = dfc['mode'].map(display_mode)
    dfc['approach_label'] = dfc['approach'].map(_cc_approach_labels)
    dfc['method_label'] = dfc['mode_label'] + ' (' + dfc['approach_label'] + ')'

    # Stack both scale-free metrics into one pooled column -- each row becomes
    # two rows (one per metric), then a single median combines "is timing
    # right" and "is magnitude right" into one standardized score.
    _long = pd.concat([
        dfc[['process', 'method_label', 'relative_wasserstein_time']]
            .rename(columns={'relative_wasserstein_time': 'value'}),
        dfc[['process', 'method_label', 'relative_wasserstein_value']]
            .rename(columns={'relative_wasserstein_value': 'value'}),
    ], ignore_index=True)

    rank_agg = _long.groupby(['process', 'method_label'])['value'].median().reset_index()
    rank_pivot = rank_agg.pivot(index='method_label', columns='process', values='value')
    rank_pivot['Overall'] = rank_pivot.median(axis=1)
    rank_pivot = rank_pivot.sort_values('Overall')

    str_table = pd.DataFrame(index=rank_pivot.index, columns=rank_pivot.columns, dtype=object)
    for col in rank_pivot.columns:
        vals = rank_pivot[col].dropna()
        if vals.empty:
            str_table[col] = ''
            continue
        best_val = vals.min()
        for idx in rank_pivot.index:
            val = rank_pivot.loc[idx, col]
            if pd.isna(val):
                str_table.loc[idx, col] = ''
                continue
            fmt = f'{val:.3f}'
            str_table.loc[idx, col] = (r'\textbf{' + fmt + r'}') if abs(val - best_val) < 1e-6 else fmt

    n_cols = len(rank_pivot.columns)
    col_format = 'l|' + '|'.join(['c'] * (n_cols - 1)) + '|c'
    rank_latex = str_table.to_latex(
        escape=False, column_format=col_format,
        caption=(
            f'Aggregated complete-profile ranking, experiment {EXPERIMENT} ({SPLIT} evaluation), '
            r'W1 (time) and W1 (value) pooled into one standardized score. '
            r'Median relative distance over sensors and both metrics per process, '
            r'then median over processes for Overall. '
            r'Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:complete_profile_ranking_combined_{EXPERIMENT}_{SPLIT}',
        position='H',
    )
    print(rank_latex.replace('_', r'\_'))
    display(rank_pivot.round(3))
    return rank_pivot

_cc_combined_rank = _cc_combined_ranking_table()
# Out:
# \begin{table}[H]
# \caption{Aggregated complete-profile ranking, experiment 960 (test evaluation), W1 (time) and W1 (value) pooled into one standardized score. Median relative distance over sensors and both metrics per process, then median over processes for Overall. Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.}
# \label{tab:complete\_profile\_ranking\_combined\_960\_test}
# \begin{tabular}{l|c|c|c|c|c|c|c}
# \toprule
# process & process\_1 & process\_2 & process\_3 & process\_4\_1 & process\_4\_2 & process\_5 & Overall \\
# method\_label &  &  &  &  &  &  &  \\
# \midrule
# budget / ml\_global (Best) & 0.211 & \textbf{0.141} & 0.180 & 0.105 & 0.083 & 0.065 & \textbf{0.123} \\
# budget / ml\_global (Baseline) & 0.195 & 0.155 & \textbf{0.167} & 0.104 & \textbf{0.080} & \textbf{0.062} & 0.130 \\
# budget / ml\_local (Best) & 0.263 & 0.188 & 0.210 & 0.089 & 0.087 & 0.066 & 0.138 \\
# budget / ml\_local (Baseline) & 0.334 & 0.244 & 0.210 & \textbf{0.088} & 0.082 & 0.064 & 0.149 \\
# budget / baseline (Best) & 0.251 & 0.216 & 0.188 & 0.155 & 0.137 & 0.095 & 0.172 \\
# budget / baseline (Baseline) & 0.269 & 0.248 & 0.190 & 0.155 & 0.136 & 0.094 & 0.172 \\
# heuristic / ml\_local (Best) & 0.147 & 0.241 & 0.244 & 0.183 & 0.220 & 0.224 & 0.222 \\
# wip\_aware / ml\_local (Best) & \textbf{0.143} & 0.803 & 0.244 & 0.177 & 0.223 & 0.224 & 0.223 \\
# wip\_aware / ml\_local (Baseline) & 0.280 & 0.877 & 0.233 & 0.176 & 0.225 & 0.224 & 0.229 \\
# heuristic / ml\_global (Best) & 0.148 & 0.238 & 0.282 & 0.168 & 0.223 & 0.333 & 0.230 \\
# heuristic / ml\_local (Baseline) & 0.285 & 0.285 & 0.244 & 0.180 & 0.220 & 0.224 & 0.234 \\
# alpha / ml\_global (Best) & 0.238 & 0.217 & 0.376 & 0.284 & 0.229 & 0.242 & 0.240 \\
# wip\_aware / ml\_global (Best) & 0.148 & 0.830 & 0.282 & 0.180 & 0.205 & 0.333 & 0.244 \\
# alpha / ml\_local (Best) & 0.236 & 0.234 & 0.321 & 0.276 & 0.222 & 0.363 & 0.256 \\
# heuristic / baseline (Best) & 0.167 & 0.223 & 0.303 & 0.255 & 0.268 & 0.426 & 0.261 \\
# alpha / ml\_global (Baseline) & 0.290 & 0.192 & 0.418 & 0.282 & 0.230 & 0.242 & 0.262 \\
# wip\_aware / baseline (Best) & 0.219 & 0.823 & 0.280 & 0.260 & 0.243 & 0.424 & 0.270 \\
# alpha / ml\_local (Baseline) & 0.271 & 0.235 & 0.304 & 0.274 & 0.227 & 0.364 & 0.273 \\
# heuristic / baseline (Baseline) & 0.282 & 0.290 & 0.273 & 0.254 & 0.269 & 0.426 & 0.278 \\
# alpha / baseline (Best) & 0.235 & 0.242 & 0.336 & 0.256 & 0.320 & 0.385 & 0.288 \\
# heuristic / ml\_global (Baseline) & 0.279 & 0.297 & 0.331 & 0.166 & 0.223 & 0.333 & 0.288 \\
# wip\_aware / baseline (Baseline) & 0.329 & 0.915 & 0.256 & 0.258 & 0.244 & 0.422 & 0.294 \\
# wip\_aware / ml\_global (Baseline) & 0.279 & 0.886 & 0.331 & 0.179 & 0.204 & 0.333 & 0.305 \\
# alpha / baseline (Baseline) & 0.301 & 0.274 & 0.370 & 0.247 & 0.324 & 0.386 & 0.312 \\
# wip\_branching\_aware / baseline (Best) & 0.251 & 0.429 & 0.353 & 0.326 & 0.304 & 0.476 & 0.339 \\
# wip\_branching\_aware / baseline (Baseline) & 0.242 & 0.514 & 0.434 & 0.318 & 0.305 & 0.455 & 0.376 \\
# \bottomrule
# \end{tabular}
# \end{table}
# process                                    process_1  process_2  process_3  \
# method_label
# budget / ml_global (Best)                      0.211      0.141      0.180
# budget / ml_global (Baseline)                  0.195      0.155      0.167
# budget / ml_local (Best)                       0.263      0.188      0.210
# budget / ml_local (Baseline)                   0.334      0.244      0.210
# budget / baseline (Best)                       0.251      0.216      0.188
# budget / baseline (Baseline)                   0.269      0.248      0.190
# heuristic / ml_local (Best)                    0.147      0.241      0.244
# wip_aware / ml_local (Best)                    0.143      0.803      0.244
# wip_aware / ml_local (Baseline)                0.280      0.877      0.233
# heuristic / ml_global (Best)                   0.148      0.238      0.282
# heuristic / ml_local (Baseline)                0.285      0.285      0.244
# alpha / ml_global (Best)                       0.238      0.217      0.376
# wip_aware / ml_global (Best)                   0.148      0.830      0.282
# alpha / ml_local (Best)                        0.236      0.234      0.321
# heuristic / baseline (Best)                    0.167      0.223      0.303
# alpha / ml_global (Baseline)                   0.290      0.192      0.418
# wip_aware / baseline (Best)                    0.219      0.823      0.280
# alpha / ml_local (Baseline)                    0.271      0.235      0.304
# heuristic / baseline (Baseline)                0.282      0.290      0.273
# alpha / baseline (Best)                        0.235      0.242      0.336
# heuristic / ml_global (Baseline)               0.279      0.297      0.331
# wip_aware / baseline (Baseline)                0.329      0.915      0.256
# wip_aware / ml_global (Baseline)               0.279      0.886      0.331
# alpha / baseline (Baseline)                    0.301      0.274      0.370
# wip_branching_aware / baseline (Best)          0.251      0.429      0.353
# wip_branching_aware / baseline (Baseline)      0.242      0.514      0.434
#
# process                                    process_4_1  process_4_2  \
# method_label
# budget / ml_global (Best)                        0.105        0.083
# budget / ml_global (Baseline)                    0.104        0.080
# budget / ml_local (Best)                         0.089        0.087
# budget / ml_local (Baseline)                     0.088        0.082
# budget / baseline (Best)                         0.155        0.137
# budget / baseline (Baseline)                     0.155        0.136
# heuristic / ml_local (Best)                      0.183        0.220
# wip_aware / ml_local (Best)                      0.177        0.223
# wip_aware / ml_local (Baseline)                  0.176        0.225
# heuristic / ml_global (Best)                     0.168        0.223
# heuristic / ml_local (Baseline)                  0.180        0.220
# alpha / ml_global (Best)                         0.284        0.229
# wip_aware / ml_global (Best)                     0.180        0.205
# alpha / ml_local (Best)                          0.276        0.222
# heuristic / baseline (Best)                      0.255        0.268
# alpha / ml_global (Baseline)                     0.282        0.230
# wip_aware / baseline (Best)                      0.260        0.243
# alpha / ml_local (Baseline)                      0.274        0.227
# heuristic / baseline (Baseline)                  0.254        0.269
# alpha / baseline (Best)                          0.256        0.320
# heuristic / ml_global (Baseline)                 0.166        0.223
# wip_aware / baseline (Baseline)                  0.258        0.244
# wip_aware / ml_global (Baseline)                 0.179        0.204
# alpha / baseline (Baseline)                      0.247        0.324
# wip_branching_aware / baseline (Best)            0.326        0.304
# wip_branching_aware / baseline (Baseline)        0.318        0.305
#
# process                                    process_5  Overall
# method_label
# budget / ml_global (Best)                      0.065    0.123
# budget / ml_global (Baseline)                  0.062    0.130
# budget / ml_local (Best)                       0.066    0.138
# budget / ml_local (Baseline)                   0.064    0.149
# budget / baseline (Best)                       0.095    0.172
# budget / baseline (Baseline)                   0.094    0.172
# heuristic / ml_local (Best)                    0.224    0.222
# wip_aware / ml_local (Best)                    0.224    0.223
# wip_aware / ml_local (Baseline)                0.224    0.229
# heuristic / ml_global (Best)                   0.333    0.230
# heuristic / ml_local (Baseline)                0.224    0.234
# alpha / ml_global (Best)                       0.242    0.240
# wip_aware / ml_global (Best)                   0.333    0.244
# alpha / ml_local (Best)                        0.363    0.256
# heuristic / baseline (Best)                    0.426    0.261
# alpha / ml_global (Baseline)                   0.242    0.262
# wip_aware / baseline (Best)                    0.424    0.270
# alpha / ml_local (Baseline)                    0.364    0.273
# heuristic / baseline (Baseline)                0.426    0.278
# alpha / baseline (Best)                        0.385    0.288
# heuristic / ml_global (Baseline)               0.333    0.288
# wip_aware / baseline (Baseline)                0.422    0.294
# wip_aware / ml_global (Baseline)               0.333    0.305
# alpha / baseline (Baseline)                    0.386    0.312
# wip_branching_aware / baseline (Best)          0.476    0.339
# wip_branching_aware / baseline (Baseline)      0.455    0.376

# %% [markdown]
# # Schedule Profile Evaluation -- Direct Method vs. Proposed (Process-Simulation) Approach
#
# Per process: compares three ways to get from "a case is about to run" to "predicted
# complete energy profile", all evaluated against the exact same real test cases:
#
# 1. **Schedule-direct** -- a case-level regression straight from schedule-only features
#    (recipe/case attributes, start time, external factors), no process simulation at all.
# 2. **Best, mine** -- the full proposed pipeline: process simulation (best-fidelity mode
#    for that process) + DTW + Ext. Factors + Prev. Activity curve prediction.
# 3. **Stochastic generator** -- a per-position Normal fit with no conditioning at all, the
#    floor everything else needs to beat.
#
# Source: `schedule_profile_eval_results/<process>/schedule_profile_eval_summary.csv`
# (requires `run_schedule_profile_eval: True` and `run_energy_modelling: True` in
# `pipeline.py`). The raw `*_wasserstein_time` (minutes) / `*_wasserstein_value` (raw
# sensor units) columns aren't comparable across sensors of different units, so -- same
# standardization as the Complete-Curve section above -- each is divided by a real,
# model-independent scale reference before aggregating:
#
# - `W1 (time), rel.` = `*_wasserstein_time` / real median case duration for that process.
# - `W1 (value), rel.` = `*_wasserstein_value` / real per-case-mean median for that sensor.
# - `Combined` = both standardized metrics pooled together, one median -- valid only
#   because both are already unitless.

# %%
# -- Standardize + aggregate the Schedule Profile Evaluation, per process --
# Per-case normalization: each case is normalized by its OWN real curve's
# scale (own real duration for time; own real mean/std -- z-score -- for
# value) BEFORE computing the Wasserstein distance, mirroring the per-
# instance sMAE normalization used in the individual energy-profile
# evaluation (evaluate_pipeline_on_test). This replaces the earlier version,
# which divided an aggregated (already medianed) raw W1 by one global
# process-wide / sensor-wide reference constant -- that's mathematically
# identical to normalizing-then-aggregating ONLY when every case shares the
# same reference value, which isn't true here: real case durations and real
# per-case magnitudes vary quite a bit. A single global constant lets cases
# with an unusually long/short real duration (or an unusually flat/active
# real curve) get over- or under-penalized purely because of their own
# scale, not prediction quality.
#
# Degenerate cases are excluded case-by-case (NaN) rather than blowing up the
# ratio -- mirroring the `_cv_ok` guard used for sMAE:
#   - time:  skip if this case's own real duration is ~0
#   - value: skip if this case's own real curve is ~constant (std ~0, or
#            coefficient of variation <= 1%) -- z-scoring a flat signal turns
#            noise-level wiggles into huge, meaningless z-scores.
_sp_series = {
    'Schedule-direct':          'schedule',
    'Best, mine':               'best',
    'Best, duration-corrected': 'best_duration_corrected',
    'Stochastic generator':     'stochastic',
    'Stochastic (bootstrap)':   'bootstrap',
}

def _load_schedule_profile_cases(proc):
    from scipy.stats import wasserstein_distance
    """Returns a long DataFrame [process, sensor, method, case_id, w1_time_rel,
    w1_value_rel] -- one row per individual case instance, no aggregation at
    all -- for one process, or an empty DataFrame if the data isn't available."""
    curves_path = run_dir / 'schedule_profile_eval_results' / proc / 'predicted_curves.parquet'
    if not curves_path.exists():
        return pd.DataFrame()
    df_curves = pd.read_parquet(curves_path)

    case_rows = []
    for sensor, sensor_g in df_curves.groupby('sensor'):
        real_by_case = {cid: g.sort_values('t_minutes')
                         for cid, g in sensor_g[sensor_g['series'] == 'real'].groupby('case_id')}
        for method, series_name in _sp_series.items():
            pred_by_case = {cid: g.sort_values('t_minutes')
                             for cid, g in sensor_g[sensor_g['series'] == series_name].groupby('case_id')}
            for case_id, real_g in real_by_case.items():
                pred_g = pred_by_case.get(case_id)
                if pred_g is None or pred_g.empty:
                    continue
                t_real = real_g['t_minutes'].to_numpy()
                v_real = real_g['value'].to_numpy()
                t_pred = pred_g['t_minutes'].to_numpy()
                v_pred = pred_g['value'].to_numpy()

                w_real = np.clip(v_real, 0, None)
                w_pred = np.clip(v_pred, 0, None)
                if w_real.sum() <= 0 or w_pred.sum() <= 0:
                    continue

                # -- Time: normalize by this case's own real duration --
                duration_real = float(t_real.max())
                t_rel = float('nan')
                if duration_real > 1e-6:
                    t_rel = float(wasserstein_distance(
                        t_real / duration_real, t_pred / duration_real,
                        u_weights=w_real, v_weights=w_pred))

                # -- Value: z-score by this case's own real mean/std --
                mu_real, sig_real = float(v_real.mean()), float(v_real.std())
                _cv_ok = sig_real > 1e-10 and (mu_real == 0 or (sig_real / abs(mu_real)) > 0.01)
                v_rel = float('nan')
                if _cv_ok:
                    z_real = (v_real - mu_real) / sig_real
                    z_pred = (v_pred - mu_real) / sig_real
                    v_rel = float(wasserstein_distance(z_real, z_pred))

                case_rows.append({'process': proc, 'sensor': sensor, 'method': method,
                                  'case_id': case_id, 'w1_time_rel': t_rel, 'w1_value_rel': v_rel})

    return pd.DataFrame(case_rows)


def _load_schedule_profile_relative(proc):
    """Returns a long DataFrame [process, sensor, method, w1_time_rel, w1_value_rel]
    for one process, or an empty DataFrame if the data isn't available. Median
    across cases, per (process, sensor, method) -- NaN (degenerate/excluded)
    cases are dropped automatically by .median()."""
    df_cases = _load_schedule_profile_cases(proc)
    if df_cases.empty:
        return pd.DataFrame()
    return df_cases.groupby(['process', 'sensor', 'method']).agg(
        w1_time_rel=('w1_time_rel', 'median'),
        w1_value_rel=('w1_value_rel', 'median'),
    ).reset_index()


def _bold_best_per_column(agg):
    str_table = agg.round(3).astype(object)
    for col in agg.columns:
        vals = agg[col].dropna()
        if vals.empty:
            continue
        best_val = vals.min()
        for idx in agg.index:
            val = agg.loc[idx, col]
            if pd.isna(val):
                str_table.loc[idx, col] = ''
                continue
            fmt = f'{val:.3f}'
            str_table.loc[idx, col] = (r'\textbf{' + fmt + r'}') if abs(val - best_val) < 1e-6 else fmt
    return str_table


_sp_all_processes = [
    p for p in sorted({d.name for d in (run_dir / 'schedule_profile_eval_results').iterdir()})
] if (run_dir / 'schedule_profile_eval_results').exists() else []
print(f'Processes with Schedule Profile Evaluation data: {_sp_all_processes}')

df_sp_relative_all = pd.concat(
    [_load_schedule_profile_relative(p) for p in _sp_all_processes], ignore_index=True
) if _sp_all_processes else pd.DataFrame()

# Fair comparison: only keep (process, sensor) pairs where ALL methods produced a
# valid (non-NaN) w1_time_rel and w1_value_rel. Otherwise a method that's missing a
# sensor entirely (e.g. no trained pipeline for it) gets a smaller, easier pool of
# sensors than the others, which silently biases its median up or down.
if not df_sp_relative_all.empty:
    _n_methods_expected = len(_sp_series)
    _complete_counts = (
        df_sp_relative_all.dropna(subset=['w1_time_rel', 'w1_value_rel'])
        .groupby(['process', 'sensor']).size()
    )
    _complete_keys = set(_complete_counts[_complete_counts == _n_methods_expected].index)
    _all_keys = set(zip(df_sp_relative_all['process'], df_sp_relative_all['sensor']))
    _dropped_keys = sorted(_all_keys - _complete_keys)
    if _dropped_keys:
        print(f'[Schedule Profile Eval] Dropping {len(_dropped_keys)} (process, sensor) pair(s) '
              f'lacking data for all {_n_methods_expected} methods, so every method is aggregated '
              f'over the same sensors:')
        for _proc_k, _sensor_k in _dropped_keys:
            print(f'    {_proc_k} / {_sensor_k}')
    df_sp_relative_all = df_sp_relative_all[
        df_sp_relative_all.set_index(['process', 'sensor']).index.isin(_complete_keys)
    ].reset_index(drop=True)

# Raw, case-level rows (no per-sensor or per-process aggregation at all),
# restricted to the same fair (process, sensor) set as above -- feeds the
# single flat median table below.
df_sp_cases_all = pd.concat(
    [_load_schedule_profile_cases(p) for p in _sp_all_processes], ignore_index=True
) if _sp_all_processes else pd.DataFrame()
if not df_sp_cases_all.empty:
    df_sp_cases_all = df_sp_cases_all[
        df_sp_cases_all.set_index(['process', 'sensor']).index.isin(_complete_keys)
    ].reset_index(drop=True)

for proc in _sp_all_processes:
    sub = df_sp_relative_all[df_sp_relative_all['process'] == proc]
    if sub.empty:
        print(f'{proc}: no data, skipping.')
        continue

    agg = sub.groupby('method').agg(
        **{'W1 (time), rel. median': ('w1_time_rel', 'median'),
           'W1 (value), rel. median': ('w1_value_rel', 'median')}
    )
    # Combined: give the two axes EQUAL weight. Raw-pooling w1_time (~0.1)
    # with w1_value (~1.4) lets value dominate ~10:1 and hides the timing
    # result, so instead express each axis relative to the stochastic floor
    # (the baseline every method must beat) and average -- both are then
    # O(1) and equally weighted. <1 == better than the stochastic floor.
    _floor_t = agg.loc['Stochastic generator', 'W1 (time), rel. median'] if 'Stochastic generator' in agg.index else np.nan
    _floor_v = agg.loc['Stochastic generator', 'W1 (value), rel. median'] if 'Stochastic generator' in agg.index else np.nan
    _rel_t = agg['W1 (time), rel. median'] / _floor_t if (_floor_t and _floor_t > 0) else agg['W1 (time), rel. median']
    _rel_v = agg['W1 (value), rel. median'] / _floor_v if (_floor_v and _floor_v > 0) else agg['W1 (value), rel. median']
    agg['Combined (floor-rel.)'] = 0.5 * (_rel_t + _rel_v)
    agg = agg.sort_values('Combined (floor-rel.)')

    str_table = _bold_best_per_column(agg)
    latex = str_table.to_latex(
        escape=False, column_format='l|c|c|c',
        caption=(
            f'Aggregated Schedule Profile Evaluation for {proc}, experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'One standardized (scale-free) number per method, median over sensors '
            r'(Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). '
            r'Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:schedule_profile_agg_{EXPERIMENT}_{SPLIT}_{proc}',
        position='H',
    )
    print(f'% === {proc} ===')
    print(latex.replace('_', r'\_'))
    display(agg.round(3))
    print()
# Out:
# Processes with Schedule Profile Evaluation data: ['process_1', 'process_2', 'process_3', 'process_4_1', 'process_4_2', 'process_5']
# [Schedule Profile Eval] Dropping 2 (process, sensor) pair(s) lacking data for all 5 methods, so every method is aggregated over the same sensors:
#     process_1 / water_supply_power_kW_energy_to_model
#     process_4_2 / (14)_filter_mas_kg/h_energy_to_model
# % === process_1 ===
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation for process\_1, experiment 960 (test evaluation). One standardized (scale-free) number per method, median over sensors (Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_960\_test\_process\_1}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined (floor-rel.) \\
# method &  &  &  \\
# \midrule
# Best, mine & \textbf{0.029} & 0.228 & \textbf{0.596} \\
# Schedule-direct & 0.088 & 0.133 & 0.637 \\
# Stochastic (bootstrap) & 0.112 & \textbf{0.122} & 0.711 \\
# Best, duration-corrected & 0.078 & 0.228 & 0.796 \\
# Stochastic generator & 0.123 & 0.239 & 1.000 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Best, mine                                 0.029                    0.228
# Schedule-direct                            0.088                    0.133
# Stochastic (bootstrap)                     0.112                    0.122
# Best, duration-corrected                   0.078                    0.228
# Stochastic generator                       0.123                    0.239
#
#                           Combined (floor-rel.)
# method
# Best, mine                                0.596
# Schedule-direct                           0.637
# Stochastic (bootstrap)                    0.711
# Best, duration-corrected                  0.796
# Stochastic generator                      1.000
# % === process_2 ===
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation for process\_2, experiment 960 (test evaluation). One standardized (scale-free) number per method, median over sensors (Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_960\_test\_process\_2}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined (floor-rel.) \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & 0.176 & \textbf{0.140} & \textbf{0.674} \\
# Best, mine & 0.165 & 0.237 & 0.768 \\
# Schedule-direct & \textbf{0.162} & 0.248 & 0.773 \\
# Best, duration-corrected & 0.171 & 0.237 & 0.785 \\
# Stochastic generator & 0.179 & 0.387 & 1.000 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Stochastic (bootstrap)                     0.176                    0.140
# Best, mine                                 0.165                    0.237
# Schedule-direct                            0.162                    0.248
# Best, duration-corrected                   0.171                    0.237
# Stochastic generator                       0.179                    0.387
#
#                           Combined (floor-rel.)
# method
# Stochastic (bootstrap)                    0.674
# Best, mine                                0.768
# Schedule-direct                           0.773
# Best, duration-corrected                  0.785
# Stochastic generator                      1.000
# % === process_3 ===
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation for process\_3, experiment 960 (test evaluation). One standardized (scale-free) number per method, median over sensors (Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_960\_test\_process\_3}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined (floor-rel.) \\
# method &  &  &  \\
# \midrule
# Best, mine & 0.157 & 0.293 & \textbf{0.823} \\
# Schedule-direct & 0.186 & 0.211 & 0.831 \\
# Stochastic (bootstrap) & 0.193 & \textbf{0.200} & 0.843 \\
# Best, duration-corrected & 0.197 & 0.293 & 0.955 \\
# Stochastic generator & \textbf{0.153} & 0.472 & 1.000 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Best, mine                                 0.157                    0.293
# Schedule-direct                            0.186                    0.211
# Stochastic (bootstrap)                     0.193                    0.200
# Best, duration-corrected                   0.197                    0.293
# Stochastic generator                       0.153                    0.472
#
#                           Combined (floor-rel.)
# method
# Best, mine                                0.823
# Schedule-direct                           0.831
# Stochastic (bootstrap)                    0.843
# Best, duration-corrected                  0.955
# Stochastic generator                      1.000
# % === process_4_1 ===
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation for process\_4\_1, experiment 960 (test evaluation). One standardized (scale-free) number per method, median over sensors (Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_960\_test\_process\_4\_1}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined (floor-rel.) \\
# method &  &  &  \\
# \midrule
# Schedule-direct & 0.019 & 1.301 & \textbf{0.924} \\
# Stochastic (bootstrap) & 0.020 & 1.413 & 0.983 \\
# Stochastic generator & \textbf{0.019} & 1.587 & 1.000 \\
# Best, duration-corrected & 0.073 & \textbf{1.130} & 2.303 \\
# Best, mine & 0.079 & \textbf{1.130} & 2.466 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Schedule-direct                            0.019                    1.301
# Stochastic (bootstrap)                     0.020                    1.413
# Stochastic generator                       0.019                    1.587
# Best, duration-corrected                   0.073                    1.130
# Best, mine                                 0.079                    1.130
#
#                           Combined (floor-rel.)
# method
# Schedule-direct                           0.924
# Stochastic (bootstrap)                    0.983
# Stochastic generator                      1.000
# Best, duration-corrected                  2.303
# Best, mine                                2.466
# % === process_4_2 ===
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation for process\_4\_2, experiment 960 (test evaluation). One standardized (scale-free) number per method, median over sensors (Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_960\_test\_process\_4\_2}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined (floor-rel.) \\
# method &  &  &  \\
# \midrule
# Schedule-direct & \textbf{0.016} & 2.032 & \textbf{0.839} \\
# Stochastic (bootstrap) & 0.018 & 1.909 & 0.903 \\
# Stochastic generator & 0.016 & 2.796 & 1.000 \\
# Best, duration-corrected & 0.067 & \textbf{1.908} & 2.367 \\
# Best, mine & 0.067 & \textbf{1.908} & 2.394 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Schedule-direct                            0.016                    2.032
# Stochastic (bootstrap)                     0.018                    1.909
# Stochastic generator                       0.016                    2.796
# Best, duration-corrected                   0.067                    1.908
# Best, mine                                 0.067                    1.908
#
#                           Combined (floor-rel.)
# method
# Schedule-direct                           0.839
# Stochastic (bootstrap)                    0.903
# Stochastic generator                      1.000
# Best, duration-corrected                  2.367
# Best, mine                                2.394
# % === process_5 ===
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation for process\_5, experiment 960 (test evaluation). One standardized (scale-free) number per method, median over sensors (Combined: each axis relative to the stochastic floor, then averaged with equal weight -- <1 beats the floor). Lower is better. Rows sorted best-to-worst by Combined. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_960\_test\_process\_5}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined (floor-rel.) \\
# method &  &  &  \\
# \midrule
# Schedule-direct & 0.062 & \textbf{1.568} & \textbf{0.803} \\
# Stochastic (bootstrap) & \textbf{0.062} & 2.031 & 0.892 \\
# Best, duration-corrected & 0.066 & 1.900 & 0.903 \\
# Stochastic generator & 0.063 & 2.534 & 1.000 \\
# Best, mine & 0.086 & 1.900 & 1.062 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Schedule-direct                            0.062                    1.568
# Stochastic (bootstrap)                     0.062                    2.031
# Best, duration-corrected                   0.066                    1.900
# Stochastic generator                       0.063                    2.534
# Best, mine                                 0.086                    1.900
#
#                           Combined (floor-rel.)
# method
# Schedule-direct                           0.803
# Stochastic (bootstrap)                    0.892
# Best, duration-corrected                  0.903
# Stochastic generator                      1.000
# Best, mine                                1.062

# %% [markdown]
# ## Population-Level (Unpaired) Distributional Evaluation
#
# The Schedule Profile Evaluation above pairs each method's prediction for a case with that SAME real case's curve -- the right test for a discriminative, case-conditioned predictor (schedule-direct), but the wrong test for a stochastic/generative method (the process simulation, the per-position stochastic generator, the empirical bootstrap): those methods aren't trying to reproduce any one specific real case, they're trying to produce a realistic POPULATION of cases. Scoring a generative method by how close one random draw lands to one specific real curve structurally punishes it for not being a point predictor.
#
# This section instead pools ALL real cases and ALL of a method's cases (no case_id pairing at all, strictly within one process/sensor at a time -- never pooled across sensors or processes) and asks how different those two populations are, on two sensor-type-agnostic axes:
#
# - **W1 (shape)** -- population-level generalization of the per-case W1-time metric above: pools every (relative-time, value) point from ALL real cases into one value-weighted distribution over relative time (0..1), does the same for the method's cases, and computes ONE Wasserstein distance between the two pooled distributions. Already scale-free (0..1 axis).
# - **W1 (magnitude)** -- pools every raw sensor reading (no per-case reduction at all) and compares the pooled real vs. method value distributions directly, via `compare_pooled_value_distributions` -- valid for any sensor type, including intensive quantities like temperature where a per-case sum/total would be meaningless.
#
# See `compare_population_shape` and `compare_pooled_value_distributions` in sim_extractor.py.

# %%
# -- Population-Level (unpaired) Distributional Evaluation, per process --
# Same scale-free-relative / floor-normalized / bold-best-per-column conventions
# as the per-case Schedule Profile Evaluation above, reusing _sp_series (so
# 'Best, budget' stays excluded here too -- it's the per-process overall_error
# winner's own family and would just duplicate 'Best, mine' wherever it wins).

def _load_population_eval(proc):
    """Returns a DataFrame [process, sensor, method, w1_shape_rel,
    w1_magnitude_rel] -- one row per (sensor, method), already relative to
    the REAL population's own scale for that sensor -- or an empty
    DataFrame if the data isn't available for this process."""
    pop_path = run_dir / 'schedule_profile_eval_results' / proc / 'population_distribution_eval.csv'
    if not pop_path.exists():
        return pd.DataFrame()
    df_pop = pd.read_csv(pop_path)

    rows = []
    for method, series_name in _sp_series.items():
        sub = df_pop[df_pop['method'] == series_name]
        for _, r in sub.iterrows():
            shape_rel = (r['w1_shape'] / r['real_shape_scale']
                         if r['real_shape_scale'] > 1e-9 else float('nan'))
            mag_rel = (r['w1_magnitude'] / r['real_magnitude_scale']
                       if r['real_magnitude_scale'] > 1e-9 else float('nan'))
            rows.append({'process': proc, 'sensor': r['sensor'], 'method': method,
                        'w1_shape_rel': shape_rel, 'w1_magnitude_rel': mag_rel})
    return pd.DataFrame(rows)


df_pop_relative_all = pd.concat(
    [_load_population_eval(p) for p in _sp_all_processes], ignore_index=True
) if _sp_all_processes else pd.DataFrame()

# Same fairness guard as the per-case table: only keep (process, sensor) pairs
# where every method produced a valid number for both axes.
if not df_pop_relative_all.empty:
    _n_methods_expected_pop = len(_sp_series)
    _complete_counts_pop = (
        df_pop_relative_all.dropna(subset=['w1_shape_rel', 'w1_magnitude_rel'])
        .groupby(['process', 'sensor']).size()
    )
    _complete_keys_pop = set(_complete_counts_pop[_complete_counts_pop == _n_methods_expected_pop].index)
    _all_keys_pop = set(zip(df_pop_relative_all['process'], df_pop_relative_all['sensor']))
    _dropped_keys_pop = sorted(_all_keys_pop - _complete_keys_pop)
    if _dropped_keys_pop:
        print(f'[Population Eval] Dropping {len(_dropped_keys_pop)} (process, sensor) pair(s) '
              f'lacking data for all {_n_methods_expected_pop} methods:')
        for _proc_k, _sensor_k in _dropped_keys_pop:
            print(f'    {_proc_k} / {_sensor_k}')
    df_pop_relative_all = df_pop_relative_all[
        df_pop_relative_all.set_index(['process', 'sensor']).index.isin(_complete_keys_pop)
    ].reset_index(drop=True)

for proc in _sp_all_processes:
    sub = df_pop_relative_all[df_pop_relative_all['process'] == proc] if not df_pop_relative_all.empty else pd.DataFrame()
    if sub.empty:
        print(f'{proc}: no population-eval data, skipping.')
        continue

    agg = sub.groupby('method').agg(
        **{'W1 (shape, population), rel. median':     ('w1_shape_rel', 'median'),
           'W1 (magnitude, population), rel. median': ('w1_magnitude_rel', 'median')}
    )
    agg = agg.sort_values('W1 (shape, population), rel. median')

    str_table = _bold_best_per_column(agg)
    latex = str_table.to_latex(
        escape=False, column_format='l|c|c',
        caption=(
            f'Aggregated Population-Level (unpaired) Distributional Evaluation for {proc}, '
            f'experiment {EXPERIMENT} ({SPLIT} evaluation). Real and method cases pooled per '
            r'sensor (no case-to-case pairing), median over sensors. Shape: population '
            r'generalization of the per-case W1-time metric (already scale-free). Magnitude: '
            r'pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative '
            r'to the real population\'s own value std. Lower is better. Rows sorted best-to-worst '
            r'by shape. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:population_eval_agg_{EXPERIMENT}_{SPLIT}_{proc}',
        position='H',
    )
    print(f'% === {proc} ===')
    print(latex.replace('_', r'\_'))
    display(agg.round(3))
    print()
# Out:
# [Population Eval] Dropping 2 (process, sensor) pair(s) lacking data for all 5 methods:
#     process_1 / water_supply_power_kW_energy_to_model
#     process_4_2 / (14)_filter_mas_kg/h_energy_to_model
# % === process_1 ===
# \begin{table}[H]
# \caption{Aggregated Population-Level (unpaired) Distributional Evaluation for process\_1, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. Shape: population generalization of the per-case W1-time metric (already scale-free). Magnitude: pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative to the real population\'s own value std. Lower is better. Rows sorted best-to-worst by shape. \textbf{Bold} = best method per column.}
# \label{tab:population\_eval\_agg\_960\_test\_process\_1}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (shape, population), rel. median & W1 (magnitude, population), rel. median \\
# method &  &  \\
# \midrule
# Stochastic generator & \textbf{0.015} & 0.200 \\
# Stochastic (bootstrap) & 0.017 & \textbf{0.011} \\
# Best, mine & 0.059 & 0.191 \\
# Best, duration-corrected & 0.059 & 0.191 \\
# Schedule-direct & 0.060 & 0.064 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (shape, population), rel. median  \
# method
# Stochastic generator                                    0.015
# Stochastic (bootstrap)                                  0.017
# Best, mine                                              0.059
# Best, duration-corrected                                0.059
# Schedule-direct                                         0.060
#
#                           W1 (magnitude, population), rel. median
# method
# Stochastic generator                                        0.200
# Stochastic (bootstrap)                                      0.011
# Best, mine                                                  0.191
# Best, duration-corrected                                    0.191
# Schedule-direct                                             0.064
# % === process_2 ===
# \begin{table}[H]
# \caption{Aggregated Population-Level (unpaired) Distributional Evaluation for process\_2, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. Shape: population generalization of the per-case W1-time metric (already scale-free). Magnitude: pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative to the real population\'s own value std. Lower is better. Rows sorted best-to-worst by shape. \textbf{Bold} = best method per column.}
# \label{tab:population\_eval\_agg\_960\_test\_process\_2}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (shape, population), rel. median & W1 (magnitude, population), rel. median \\
# method &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.036} & \textbf{0.074} \\
# Stochastic generator & 0.047 & 0.443 \\
# Best, mine & 0.070 & 0.258 \\
# Best, duration-corrected & 0.070 & 0.258 \\
# Schedule-direct & 0.092 & 0.187 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (shape, population), rel. median  \
# method
# Stochastic (bootstrap)                                  0.036
# Stochastic generator                                    0.047
# Best, mine                                              0.070
# Best, duration-corrected                                0.070
# Schedule-direct                                         0.092
#
#                           W1 (magnitude, population), rel. median
# method
# Stochastic (bootstrap)                                      0.074
# Stochastic generator                                        0.443
# Best, mine                                                  0.258
# Best, duration-corrected                                    0.258
# Schedule-direct                                             0.187
# % === process_3 ===
# \begin{table}[H]
# \caption{Aggregated Population-Level (unpaired) Distributional Evaluation for process\_3, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. Shape: population generalization of the per-case W1-time metric (already scale-free). Magnitude: pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative to the real population\'s own value std. Lower is better. Rows sorted best-to-worst by shape. \textbf{Bold} = best method per column.}
# \label{tab:population\_eval\_agg\_960\_test\_process\_3}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (shape, population), rel. median & W1 (magnitude, population), rel. median \\
# method &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.038} & \textbf{0.065} \\
# Best, duration-corrected & 0.056 & 0.265 \\
# Best, mine & 0.056 & 0.265 \\
# Stochastic generator & 0.065 & 0.402 \\
# Schedule-direct & 0.089 & 0.172 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (shape, population), rel. median  \
# method
# Stochastic (bootstrap)                                  0.038
# Best, duration-corrected                                0.056
# Best, mine                                              0.056
# Stochastic generator                                    0.065
# Schedule-direct                                         0.089
#
#                           W1 (magnitude, population), rel. median
# method
# Stochastic (bootstrap)                                      0.065
# Best, duration-corrected                                    0.265
# Best, mine                                                  0.265
# Stochastic generator                                        0.402
# Schedule-direct                                             0.172
# % === process_4_1 ===
# \begin{table}[H]
# \caption{Aggregated Population-Level (unpaired) Distributional Evaluation for process\_4\_1, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. Shape: population generalization of the per-case W1-time metric (already scale-free). Magnitude: pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative to the real population\'s own value std. Lower is better. Rows sorted best-to-worst by shape. \textbf{Bold} = best method per column.}
# \label{tab:population\_eval\_agg\_960\_test\_process\_4\_1}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (shape, population), rel. median & W1 (magnitude, population), rel. median \\
# method &  &  \\
# \midrule
# Stochastic generator & \textbf{0.001} & \textbf{0.516} \\
# Schedule-direct & 0.002 & 0.855 \\
# Stochastic (bootstrap) & 0.002 & 0.561 \\
# Best, mine & 0.058 & 1.028 \\
# Best, duration-corrected & 0.058 & 1.028 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (shape, population), rel. median  \
# method
# Stochastic generator                                    0.001
# Schedule-direct                                         0.002
# Stochastic (bootstrap)                                  0.002
# Best, mine                                              0.058
# Best, duration-corrected                                0.058
#
#                           W1 (magnitude, population), rel. median
# method
# Stochastic generator                                        0.516
# Schedule-direct                                             0.855
# Stochastic (bootstrap)                                      0.561
# Best, mine                                                  1.028
# Best, duration-corrected                                    1.028
# % === process_4_2 ===
# \begin{table}[H]
# \caption{Aggregated Population-Level (unpaired) Distributional Evaluation for process\_4\_2, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. Shape: population generalization of the per-case W1-time metric (already scale-free). Magnitude: pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative to the real population\'s own value std. Lower is better. Rows sorted best-to-worst by shape. \textbf{Bold} = best method per column.}
# \label{tab:population\_eval\_agg\_960\_test\_process\_4\_2}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (shape, population), rel. median & W1 (magnitude, population), rel. median \\
# method &  &  \\
# \midrule
# Stochastic generator & \textbf{0.001} & 0.910 \\
# Stochastic (bootstrap) & 0.002 & 1.067 \\
# Schedule-direct & 0.002 & 1.023 \\
# Best, mine & 0.050 & \textbf{0.855} \\
# Best, duration-corrected & 0.050 & \textbf{0.855} \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (shape, population), rel. median  \
# method
# Stochastic generator                                    0.001
# Stochastic (bootstrap)                                  0.002
# Schedule-direct                                         0.002
# Best, mine                                              0.050
# Best, duration-corrected                                0.050
#
#                           W1 (magnitude, population), rel. median
# method
# Stochastic generator                                        0.910
# Stochastic (bootstrap)                                      1.067
# Schedule-direct                                             1.023
# Best, mine                                                  0.855
# Best, duration-corrected                                    0.855
# % === process_5 ===
# \begin{table}[H]
# \caption{Aggregated Population-Level (unpaired) Distributional Evaluation for process\_5, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. Shape: population generalization of the per-case W1-time metric (already scale-free). Magnitude: pooled raw-value W1 (sensor-type-agnostic, works for temperature too), relative to the real population\'s own value std. Lower is better. Rows sorted best-to-worst by shape. \textbf{Bold} = best method per column.}
# \label{tab:population\_eval\_agg\_960\_test\_process\_5}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (shape, population), rel. median & W1 (magnitude, population), rel. median \\
# method &  &  \\
# \midrule
# Schedule-direct & \textbf{0.003} & 0.688 \\
# Best, duration-corrected & 0.003 & 0.665 \\
# Best, mine & 0.003 & 0.665 \\
# Stochastic (bootstrap) & 0.003 & \textbf{0.402} \\
# Stochastic generator & 0.003 & 0.600 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (shape, population), rel. median  \
# method
# Schedule-direct                                         0.003
# Best, duration-corrected                                0.003
# Best, mine                                              0.003
# Stochastic (bootstrap)                                  0.003
# Stochastic generator                                    0.003
#
#                           W1 (magnitude, population), rel. median
# method
# Schedule-direct                                             0.688
# Best, duration-corrected                                    0.665
# Best, mine                                                  0.665
# Stochastic (bootstrap)                                      0.402
# Stochastic generator                                        0.600

# %% [markdown]
# ## Coper

# %%
# -- Aggregated across all processes: one row per method, one column per process + Overall --
if df_sp_relative_all.empty:
    print('Nothing to show -- df_sp_relative_all is empty.')
else:
    # Fair equal-weight rollup: per process, express each axis relative to the
    # stochastic floor and average the two (raw-pooling let the ~10x-larger
    # value scale dominate and hid the timing result). Then median across
    # processes. Keep the two raw axes' Overall too, so the timing win is
    # visible at a glance.
    _t = df_sp_relative_all.pivot_table(index='method', columns='process', values='w1_time_rel', aggfunc='median')
    _v = df_sp_relative_all.pivot_table(index='method', columns='process', values='w1_value_rel', aggfunc='median')
    _ft = _t.loc['Stochastic generator']; _fv = _v.loc['Stochastic generator']
    _comb = 0.5 * (_t.div(_ft, axis=1) + _v.div(_fv, axis=1))
    _rank_pivot = _comb.copy()
    _rank_pivot['W1(time) Overall']  = _t.median(axis=1)
    _rank_pivot['W1(value) Overall'] = _v.median(axis=1)
    _rank_pivot['Overall'] = _comb.median(axis=1)
    _rank_pivot = _rank_pivot.sort_values('Overall')

    _str_table = _bold_best_per_column(_rank_pivot)
    n_cols = len(_rank_pivot.columns)
    col_format = 'l|' + '|'.join(['c'] * (n_cols - 1)) + '|c'
    _rank_latex = _str_table.to_latex(
        escape=False, column_format=col_format,
        caption=(
            f'Aggregated Schedule Profile Evaluation across all processes, experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'Each case normalized by its own real curve scale (own duration for time, own mean/std for value); '
            r'each axis relative to the stochastic floor and averaged (equal weight) per process, then median over processes for Overall; W1(time)/W1(value) Overall are the raw per-axis medians. '
            r'Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:schedule_profile_agg_overall_{EXPERIMENT}_{SPLIT}',
        position='H',
    )
    print(_rank_latex.replace('_', r'\_'))
    display(_rank_pivot.round(3))
# Out:
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation across all processes, experiment 960 (test evaluation). Each case normalized by its own real curve scale (own duration for time, own mean/std for value); each axis relative to the stochastic floor and averaged (equal weight) per process, then median over processes for Overall; W1(time)/W1(value) Overall are the raw per-axis medians. Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_overall\_960\_test}
# \begin{tabular}{l|c|c|c|c|c|c|c|c|c}
# \toprule
# process & process\_1 & process\_2 & process\_3 & process\_4\_1 & process\_4\_2 & process\_5 & W1(time) Overall & W1(value) Overall & Overall \\
# method &  &  &  &  &  &  &  &  &  \\
# \midrule
# Schedule-direct & 0.637 & 0.773 & 0.831 & \textbf{0.924} & \textbf{0.839} & \textbf{0.803} & \textbf{0.075} & 0.775 & \textbf{0.817} \\
# Stochastic (bootstrap) & 0.711 & \textbf{0.674} & 0.843 & 0.983 & 0.903 & 0.892 & 0.087 & 0.807 & 0.868 \\
# Best, duration-corrected & 0.796 & 0.785 & 0.955 & 2.303 & 2.367 & 0.903 & 0.076 & \textbf{0.711} & 0.929 \\
# Best, mine & \textbf{0.596} & 0.768 & \textbf{0.823} & 2.466 & 2.394 & 1.062 & 0.083 & \textbf{0.711} & 0.942 \\
# Stochastic generator & 1.000 & 1.000 & 1.000 & 1.000 & 1.000 & 1.000 & 0.093 & 1.029 & 1.000 \\
# \bottomrule
# \end{tabular}
# \end{table}
# process                   process_1  process_2  process_3  process_4_1  \
# method
# Schedule-direct               0.637      0.773      0.831        0.924
# Stochastic (bootstrap)        0.711      0.674      0.843        0.983
# Best, duration-corrected      0.796      0.785      0.955        2.303
# Best, mine                    0.596      0.768      0.823        2.466
# Stochastic generator          1.000      1.000      1.000        1.000
#
# process                   process_4_2  process_5  W1(time) Overall  \
# method
# Schedule-direct                 0.839      0.803             0.075
# Stochastic (bootstrap)          0.903      0.892             0.087
# Best, duration-corrected        2.367      0.903             0.076
# Best, mine                      2.394      1.062             0.083
# Stochastic generator            1.000      1.000             0.093
#
# process                   W1(value) Overall  Overall
# method
# Schedule-direct                       0.775    0.817
# Stochastic (bootstrap)                0.807    0.868
# Best, duration-corrected              0.711    0.929
# Best, mine                            0.711    0.942
# Stochastic generator                  1.029    1.000

# %% [markdown]
# ## Aggregated across all processes
#
# Same three methods, one row each, now rolled up across every process: median over
# sensors within a process (as above), then median over processes for `Overall`. Rows
# sorted best-to-worst by `Overall`.

# %%
# -- Aggregated across all processes: one row per method, one column per process + Overall --
if df_sp_relative_all.empty:
    print('Nothing to show -- df_sp_relative_all is empty.')
else:
    _pooled_all = pd.concat([
        df_sp_relative_all[['process', 'method', 'w1_time_rel']].rename(columns={'w1_time_rel': 'v'}),
        df_sp_relative_all[['process', 'method', 'w1_value_rel']].rename(columns={'w1_value_rel': 'v'}),
    ], ignore_index=True)

    _rank_agg = _pooled_all.groupby(['process', 'method'])['v'].median().reset_index()
    _rank_pivot = _rank_agg.pivot(index='method', columns='process', values='v')
    _rank_pivot['Overall'] = _rank_pivot.median(axis=1)
    _rank_pivot = _rank_pivot.sort_values('Overall')

    _str_table = _bold_best_per_column(_rank_pivot)
    n_cols = len(_rank_pivot.columns)
    col_format = 'l|' + '|'.join(['c'] * (n_cols - 1)) + '|c'
    _rank_latex = _str_table.to_latex(
        escape=False, column_format=col_format,
        caption=(
            f'Aggregated Schedule Profile Evaluation across all processes, experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'Each case normalized by its own real curve scale (own duration for time, own mean/std for value); '
            r'both standardized metrics (W1 time, W1 value) pooled per process, then median over processes for Overall. '
            r'Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:schedule_profile_agg_overall_{EXPERIMENT}_{SPLIT}',
        position='H',
    )
    print(_rank_latex.replace('_', r'\_'))
    display(_rank_pivot.round(3))
# Out:
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation across all processes, experiment 960 (test evaluation). Each case normalized by its own real curve scale (own duration for time, own mean/std for value); both standardized metrics (W1 time, W1 value) pooled per process, then median over processes for Overall. Lower is better. Rows sorted best-to-worst by Overall. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_overall\_960\_test}
# \begin{tabular}{l|c|c|c|c|c|c|c}
# \toprule
# process & process\_1 & process\_2 & process\_3 & process\_4\_1 & process\_4\_2 & process\_5 & Overall \\
# method &  &  &  &  &  &  &  \\
# \midrule
# Stochastic (bootstrap) & 0.117 & \textbf{0.140} & \textbf{0.195} & 0.379 & 0.243 & \textbf{0.321} & \textbf{0.219} \\
# Schedule-direct & \textbf{0.105} & 0.198 & 0.204 & 0.407 & 0.340 & 0.554 & 0.272 \\
# Best, mine & 0.128 & 0.196 & 0.211 & 0.392 & 0.344 & 0.461 & 0.277 \\
# Best, duration-corrected & 0.147 & 0.197 & 0.224 & 0.377 & 0.332 & 0.483 & 0.278 \\
# Stochastic generator & 0.169 & 0.294 & 0.281 & \textbf{0.311} & \textbf{0.236} & 0.394 & 0.288 \\
# \bottomrule
# \end{tabular}
# \end{table}
# process                   process_1  process_2  process_3  process_4_1  \
# method
# Stochastic (bootstrap)        0.117      0.140      0.195        0.379
# Schedule-direct               0.105      0.198      0.204        0.407
# Best, mine                    0.128      0.196      0.211        0.392
# Best, duration-corrected      0.147      0.197      0.224        0.377
# Stochastic generator          0.169      0.294      0.281        0.311
#
# process                   process_4_2  process_5  Overall
# method
# Stochastic (bootstrap)          0.243      0.321    0.219
# Schedule-direct                 0.340      0.554    0.272
# Best, mine                      0.344      0.461    0.277
# Best, duration-corrected        0.332      0.483    0.278
# Stochastic generator            0.236      0.394    0.288

# %% [markdown]
# ### Aggregated across all processes -- both W1 metrics kept separate
#
# Same idea as the table above, but instead of pooling W1 (time) and W1 (value) into one 'Combined'/'Overall' number, this keeps them as two separate columns: the median of `w1_time_rel` and the median of `w1_value_rel`, each taken over every (process, sensor) pair (using the same common-sensor filtering as above, so all methods are compared over the same sensors).

# %%
# -- Aggregated across all processes: both W1 metrics as separate columns (no pooling) --
if df_sp_relative_all.empty:
    print('Nothing to show -- df_sp_relative_all is empty.')
else:
    _both_agg = df_sp_relative_all.groupby('method').agg(
        **{'W1 (time), rel. median': ('w1_time_rel', 'median'),
           'W1 (value), rel. median': ('w1_value_rel', 'median')}
    )
    _both_agg = _both_agg.sort_values('W1 (time), rel. median')

    _both_str = _bold_best_per_column(_both_agg)
    _both_latex = _both_str.to_latex(
        escape=False, column_format='l|c|c',
        caption=(
            f'Aggregated Schedule Profile Evaluation across all processes, experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'Each case normalized by its own real curve scale (own duration for time, own mean/std for value). '
            r'W1 (time) and W1 (value), rel. -- each column is the median over every (process, sensor) pair, kept separate '
            r'(not pooled into a single score). Lower is better. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:schedule_profile_agg_both_w1_{EXPERIMENT}_{SPLIT}',
        position='H',
    )
    print(_both_latex.replace('_', r'\_'))
    display(_both_agg.round(3))
# Out:
# \begin{table}[H]
# \caption{Aggregated Schedule Profile Evaluation across all processes, experiment 960 (test evaluation). Each case normalized by its own real curve scale (own duration for time, own mean/std for value). W1 (time) and W1 (value), rel. -- each column is the median over every (process, sensor) pair, kept separate (not pooled into a single score). Lower is better. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_agg\_both\_w1\_960\_test}
# \begin{tabular}{l|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median \\
# method &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.061} & 1.573 \\
# Stochastic generator & 0.061 & 1.839 \\
# Schedule-direct & 0.061 & \textbf{1.276} \\
# Best, duration-corrected & 0.071 & 1.443 \\
# Best, mine & 0.084 & 1.443 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median
# method
# Stochastic (bootstrap)                     0.061                    1.573
# Stochastic generator                       0.061                    1.839
# Schedule-direct                            0.061                    1.276
# Best, duration-corrected                   0.071                    1.443
# Best, mine                                 0.084                    1.443

# %% [markdown]
# ### Single flat median -- every case, every sensor, every process pooled together
#
# No per-sensor or per-process grouping at all: every individual case instance (across all 6 processes and all their sensors) is thrown into one pool per method, and a single median is taken directly -- unlike the tables above, which take a median-of-medians (cases -> sensors -> processes, each level weighted equally regardless of how many cases/sensors it contains). Here, a process/sensor with more test cases contributes proportionally more to the result.

# %%
# -- Single flat median: pool every (process, sensor, case) instance together, no grouping --
if df_sp_cases_all.empty:
    print('Nothing to show -- df_sp_cases_all is empty.')
else:
    _flat = df_sp_cases_all.groupby('method').agg(
        **{'W1 (time), rel. median': ('w1_time_rel', 'median'),
           'W1 (value), rel. median': ('w1_value_rel', 'median'),
           'n_time': ('w1_time_rel', 'count'),
           'n_value': ('w1_value_rel', 'count')}
    )
    _flat_pooled = pd.concat([
        df_sp_cases_all[['method', 'w1_time_rel']].rename(columns={'w1_time_rel': 'v'}),
        df_sp_cases_all[['method', 'w1_value_rel']].rename(columns={'w1_value_rel': 'v'}),
    ], ignore_index=True)
    _flat['Combined, rel. median'] = _flat_pooled.groupby('method')['v'].median()
    _flat = _flat.sort_values('Combined, rel. median')

    _flat_display = _flat[['W1 (time), rel. median', 'W1 (value), rel. median', 'Combined, rel. median']]
    _flat_str = _bold_best_per_column(_flat_display)
    _flat_latex = _flat_str.to_latex(
        escape=False, column_format='l|c|c|c',
        caption=(
            f'Schedule Profile Evaluation, experiment {EXPERIMENT} ({SPLIT} evaluation), pooled flat across '
            r'every case instance from every sensor and every process (no per-sensor or per-process '
            r'grouping). Each case normalized by its own real curve scale (own duration for time, own '
            r'mean/std for value). Lower is better. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:schedule_profile_flat_{EXPERIMENT}_{SPLIT}',
        position='H',
    )
    print(_flat_latex.replace('_', r'\_'))
    display(_flat.round(3))
# Out:
# \begin{table}[H]
# \caption{Schedule Profile Evaluation, experiment 960 (test evaluation), pooled flat across every case instance from every sensor and every process (no per-sensor or per-process grouping). Each case normalized by its own real curve scale (own duration for time, own mean/std for value). Lower is better. \textbf{Bold} = best method per column.}
# \label{tab:schedule\_profile\_flat\_960\_test}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (time), rel. median & W1 (value), rel. median & Combined, rel. median \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & 0.048 & 1.094 & \textbf{0.152} \\
# Schedule-direct & 0.050 & \textbf{1.043} & 0.174 \\
# Best, duration-corrected & 0.081 & 1.166 & 0.205 \\
# Stochastic generator & \textbf{0.047} & 1.319 & 0.211 \\
# Best, mine & 0.082 & 1.166 & 0.255 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (time), rel. median  W1 (value), rel. median  \
# method
# Stochastic (bootstrap)                     0.048                    1.094
# Schedule-direct                            0.050                    1.043
# Best, duration-corrected                   0.081                    1.166
# Stochastic generator                       0.047                    1.319
# Best, mine                                 0.082                    1.166
#
#                           n_time  n_value  Combined, rel. median
# method
# Stochastic (bootstrap)      3125     2706                  0.152
# Schedule-direct             3196     2776                  0.174
# Best, duration-corrected    3199     2779                  0.205
# Stochastic generator        3199     2779                  0.211
# Best, mine                  3199     2779                  0.255

# %% [markdown]
# ## Additional Population-Level Metrics
#
# Three more axes, same real-vs-method pooled populations (no case pairing, strictly per process/sensor) as the shape/magnitude table above -- read `population_distribution_eval.csv` the same way, just different columns:
#
# - **W1 (variability)** -- population W1 of per-case within-case std. Different from magnitude (which pools every raw reading with no notion of case at all): this catches methods that flatten real case-to-case volatility (regression-to-the-mean).
# - **W1 (peak)** -- population W1 of per-case peak (max) value. Catches methods that get the average right but never reach real extremes.
# - **Coverage** -- NOT a Wasserstein distance, a different kind of check: what fraction of real readings fall inside the method's own [5th, 95th] percentile band, pooled per sensor. **Higher is better** here (1.0 = every real reading is inside the method's plausible range) -- the opposite convention from every W1 column, which is lower-is-better.

# %%
# -- Additional Population-Level metrics: variability, peak, coverage --
# Same relative / floor-normalized / fairness-filter conventions as the shape+magnitude
# table above, reusing _sp_series and _sp_all_processes.

def _bold_best_per_column_dir(agg, higher_is_better_cols=()):
    """Like _bold_best_per_column, but a column can be marked higher-is-better
    (e.g. Coverage) instead of the default lower-is-better (every W1 metric)."""
    str_table = agg.round(3).astype(object)
    for col in agg.columns:
        vals = agg[col].dropna()
        if vals.empty:
            continue
        best_val = vals.max() if col in higher_is_better_cols else vals.min()
        for idx in agg.index:
            val = agg.loc[idx, col]
            if pd.isna(val):
                str_table.loc[idx, col] = ''
                continue
            fmt = f'{val:.3f}'
            str_table.loc[idx, col] = (r'\textbf{' + fmt + r'}') if abs(val - best_val) < 1e-6 else fmt
    return str_table


def _load_extra_population_eval(proc):
    """Returns [process, sensor, method, w1_variability_rel, w1_peak_rel, coverage]
    -- W1 axes relative to the real population's own scale for that sensor;
    coverage is already a 0..1 fraction, no scaling needed."""
    pop_path = run_dir / 'schedule_profile_eval_results' / proc / 'population_distribution_eval.csv'
    if not pop_path.exists():
        return pd.DataFrame()
    df_pop = pd.read_csv(pop_path)
    if 'w1_variability' not in df_pop.columns:
        return pd.DataFrame()

    rows = []
    for method, series_name in _sp_series.items():
        sub = df_pop[df_pop['method'] == series_name]
        for _, r in sub.iterrows():
            var_rel = (r['w1_variability'] / r['real_variability_scale']
                       if r['real_variability_scale'] > 1e-9 else float('nan'))
            peak_rel = (r['w1_peak'] / r['real_peak_scale']
                        if r['real_peak_scale'] > 1e-9 else float('nan'))
            rows.append({'process': proc, 'sensor': r['sensor'], 'method': method,
                        'w1_variability_rel': var_rel, 'w1_peak_rel': peak_rel,
                        'coverage': r.get('coverage', float('nan'))})
    return pd.DataFrame(rows)


df_extra_pop_all = pd.concat(
    [_load_extra_population_eval(p) for p in _sp_all_processes], ignore_index=True
) if _sp_all_processes else pd.DataFrame()

if not df_extra_pop_all.empty:
    _n_methods_expected_ep = len(_sp_series)
    _complete_counts_ep = (
        df_extra_pop_all.dropna(subset=['w1_variability_rel', 'w1_peak_rel', 'coverage'])
        .groupby(['process', 'sensor']).size()
    )
    _complete_keys_ep = set(_complete_counts_ep[_complete_counts_ep == _n_methods_expected_ep].index)
    _all_keys_ep = set(zip(df_extra_pop_all['process'], df_extra_pop_all['sensor']))
    _dropped_keys_ep = sorted(_all_keys_ep - _complete_keys_ep)
    if _dropped_keys_ep:
        print(f'[Extra Population Eval] Dropping {len(_dropped_keys_ep)} (process, sensor) pair(s) '
              f'lacking data for all {_n_methods_expected_ep} methods:')
        for _proc_k, _sensor_k in _dropped_keys_ep:
            print(f'    {_proc_k} / {_sensor_k}')
    df_extra_pop_all = df_extra_pop_all[
        df_extra_pop_all.set_index(['process', 'sensor']).index.isin(_complete_keys_ep)
    ].reset_index(drop=True)

for proc in _sp_all_processes:
    sub = df_extra_pop_all[df_extra_pop_all['process'] == proc] if not df_extra_pop_all.empty else pd.DataFrame()
    if sub.empty:
        print(f'{proc}: no additional population-eval data, skipping.')
        continue

    agg = sub.groupby('method').agg(
        **{'W1 (variability), rel. median': ('w1_variability_rel', 'median'),
           'W1 (peak), rel. median':        ('w1_peak_rel', 'median'),
           'Coverage, median':              ('coverage', 'median')}
    )
    agg = agg.sort_values('W1 (variability), rel. median')

    str_table = _bold_best_per_column_dir(agg, higher_is_better_cols=('Coverage, median',))
    latex = str_table.to_latex(
        escape=False, column_format='l|c|c|c',
        caption=(
            f'Additional Population-Level metrics for {proc}, experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. '
            r'W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own '
            r'5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.'
        ),
        label=f'tab:extra_population_eval_{EXPERIMENT}_{SPLIT}_{proc}',
        position='H',
    )
    print(f'% === {proc} ===')
    print(latex.replace('_', r'\_'))
    display(agg.round(3))
    print()
# Out:
# [Extra Population Eval] Dropping 2 (process, sensor) pair(s) lacking data for all 5 methods:
#     process_1 / water_supply_power_kW_energy_to_model
#     process_4_2 / (14)_filter_mas_kg/h_energy_to_model
# % === process_1 ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics for process\_1, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own 5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.}
# \label{tab:extra\_population\_eval\_960\_test\_process\_1}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.185} & \textbf{0.475} & 0.950 \\
# Stochastic generator & 0.683 & 3.220 & \textbf{0.964} \\
# Best, mine & 0.701 & 2.055 & 0.951 \\
# Best, duration-corrected & 0.701 & 2.055 & 0.951 \\
# Schedule-direct & 0.906 & 1.209 & 0.915 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (variability), rel. median  \
# method
# Stochastic (bootstrap)                            0.185
# Stochastic generator                              0.683
# Best, mine                                        0.701
# Best, duration-corrected                          0.701
# Schedule-direct                                   0.906
#
#                           W1 (peak), rel. median  Coverage, median
# method
# Stochastic (bootstrap)                     0.475             0.950
# Stochastic generator                       3.220             0.964
# Best, mine                                 2.055             0.951
# Best, duration-corrected                   2.055             0.951
# Schedule-direct                            1.209             0.915
# % === process_2 ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics for process\_2, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own 5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.}
# \label{tab:extra\_population\_eval\_960\_test\_process\_2}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.277} & \textbf{0.291} & \textbf{0.958} \\
# Best, duration-corrected & 0.561 & 0.819 & 0.881 \\
# Best, mine & 0.561 & 0.819 & 0.881 \\
# Stochastic generator & 0.906 & 0.803 & 0.930 \\
# Schedule-direct & 1.521 & 0.874 & 0.912 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (variability), rel. median  \
# method
# Stochastic (bootstrap)                            0.277
# Best, duration-corrected                          0.561
# Best, mine                                        0.561
# Stochastic generator                              0.906
# Schedule-direct                                   1.521
#
#                           W1 (peak), rel. median  Coverage, median
# method
# Stochastic (bootstrap)                     0.291             0.958
# Best, duration-corrected                   0.819             0.881
# Best, mine                                 0.819             0.881
# Stochastic generator                       0.803             0.930
# Schedule-direct                            0.874             0.912
# % === process_3 ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics for process\_3, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own 5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.}
# \label{tab:extra\_population\_eval\_960\_test\_process\_3}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Best, duration-corrected & \textbf{0.469} & 0.937 & \textbf{0.952} \\
# Best, mine & \textbf{0.469} & 0.937 & \textbf{0.952} \\
# Stochastic (bootstrap) & 0.483 & \textbf{0.698} & 0.950 \\
# Stochastic generator & 0.791 & 0.838 & 0.946 \\
# Schedule-direct & 1.356 & 0.835 & 0.924 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (variability), rel. median  \
# method
# Best, duration-corrected                          0.469
# Best, mine                                        0.469
# Stochastic (bootstrap)                            0.483
# Stochastic generator                              0.791
# Schedule-direct                                   1.356
#
#                           W1 (peak), rel. median  Coverage, median
# method
# Best, duration-corrected                   0.937             0.952
# Best, mine                                 0.937             0.952
# Stochastic (bootstrap)                     0.698             0.950
# Stochastic generator                       0.838             0.946
# Schedule-direct                            0.835             0.924
# % === process_4_1 ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics for process\_4\_1, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own 5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.}
# \label{tab:extra\_population\_eval\_960\_test\_process\_4\_1}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.539} & \textbf{0.837} & 0.926 \\
# Schedule-direct & 1.372 & 0.994 & 0.230 \\
# Best, mine & 1.534 & 1.164 & 0.072 \\
# Best, duration-corrected & 1.534 & 1.164 & 0.072 \\
# Stochastic generator & 2.958 & 3.768 & \textbf{0.956} \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (variability), rel. median  \
# method
# Stochastic (bootstrap)                            0.539
# Schedule-direct                                   1.372
# Best, mine                                        1.534
# Best, duration-corrected                          1.534
# Stochastic generator                              2.958
#
#                           W1 (peak), rel. median  Coverage, median
# method
# Stochastic (bootstrap)                     0.837             0.926
# Schedule-direct                            0.994             0.230
# Best, mine                                 1.164             0.072
# Best, duration-corrected                   1.164             0.072
# Stochastic generator                       3.768             0.956
# % === process_4_2 ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics for process\_4\_2, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own 5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.}
# \label{tab:extra\_population\_eval\_960\_test\_process\_4\_2}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.221} & 0.963 & 0.576 \\
# Schedule-direct & 0.475 & \textbf{0.954} & 0.279 \\
# Best, mine & 0.538 & 1.648 & 0.072 \\
# Best, duration-corrected & 0.538 & 1.648 & 0.072 \\
# Stochastic generator & 0.926 & 1.491 & \textbf{0.830} \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (variability), rel. median  \
# method
# Stochastic (bootstrap)                            0.221
# Schedule-direct                                   0.475
# Best, mine                                        0.538
# Best, duration-corrected                          0.538
# Stochastic generator                              0.926
#
#                           W1 (peak), rel. median  Coverage, median
# method
# Stochastic (bootstrap)                     0.963             0.576
# Schedule-direct                            0.954             0.279
# Best, mine                                 1.648             0.072
# Best, duration-corrected                   1.648             0.072
# Stochastic generator                       1.491             0.830
# % === process_5 ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics for process\_5, experiment 960 (test evaluation). Real and method cases pooled per sensor (no case-to-case pairing), median over sensors. W1 columns: lower is better. Coverage: fraction of real readings inside the method\'s own 5-95th percentile band -- HIGHER is better. \textbf{Bold} = best method per column.}
# \label{tab:extra\_population\_eval\_960\_test\_process\_5}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Stochastic (bootstrap) & \textbf{0.635} & \textbf{0.634} & 0.799 \\
# Best, duration-corrected & 0.838 & 0.884 & 0.459 \\
# Best, mine & 0.838 & 0.884 & 0.459 \\
# Schedule-direct & 0.966 & 0.680 & 0.288 \\
# Stochastic generator & 3.166 & 2.971 & \textbf{0.972} \\
# \bottomrule
# \end{tabular}
# \end{table}
#                           W1 (variability), rel. median  \
# method
# Stochastic (bootstrap)                            0.635
# Best, duration-corrected                          0.838
# Best, mine                                        0.838
# Schedule-direct                                   0.966
# Stochastic generator                              3.166
#
#                           W1 (peak), rel. median  Coverage, median
# method
# Stochastic (bootstrap)                     0.634             0.799
# Best, duration-corrected                   0.884             0.459
# Best, mine                                 0.884             0.459
# Schedule-direct                            0.680             0.288
# Stochastic generator                       2.971             0.972

# %%
# Remove unwanted methods
_methods_to_remove = {
    'Stochastic (bootstrap)',
    'Best, duration-corrected',
}

df_extra_pop_all_agg = df_extra_pop_all[
    ~df_extra_pop_all['method'].isin(_methods_to_remove)
].copy()

if df_extra_pop_all_agg.empty:
    print('No additional population-eval data available after filtering.')
else:
    agg_all_processes = (
        df_extra_pop_all_agg
        .groupby('method')
        .agg(
            **{
                'W1 (variability), rel. median': (
                    'w1_variability_rel', 'median'
                ),
                'W1 (peak), rel. median': (
                    'w1_peak_rel', 'median'
                ),
                'Coverage, median': (
                    'coverage', 'median'
                ),
            }
        )
        .sort_values('W1 (variability), rel. median')
    )

    # Three decimal places and bold the best value in each metric column:
    # lower is better for W1 metrics; higher is better for coverage
    str_table_all_processes = _bold_best_per_column_dir(
        agg_all_processes,
        higher_is_better_cols=('Coverage, median',),
    )

    latex_all_processes = str_table_all_processes.to_latex(
        escape=False,
        column_format='l|c|c|c',
        caption=(
            f'Additional Population-Level metrics aggregated across all processes, '
            f'experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'Metrics are reported as medians across all process--sensor pairs. '
            r'Lower values are better for W1 metrics, while higher values are '
            r'better for coverage. \textbf{Bold} indicates the best value.'
        ),
        label=f'tab:extra_population_eval_{EXPERIMENT}_{SPLIT}_all_processes',
        position='H',
    )

    print('% === All processes ===')
    print(latex_all_processes.replace('_', r'\_'))
    display(agg_all_processes.round(3))
# Out:
# % === All processes ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics aggregated across all processes, experiment 960 (test evaluation). Metrics are reported as medians across all process--sensor pairs. Lower values are better for W1 metrics, while higher values are better for coverage. \textbf{Bold} indicates the best value.}
# \label{tab:extra\_population\_eval\_960\_test\_all\_processes}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & Coverage, median \\
# method &  &  &  \\
# \midrule
# Best, mine & \textbf{0.802} & 1.043 & 0.275 \\
# Schedule-direct & 1.106 & \textbf{0.820} & 0.345 \\
# Stochastic generator & 1.401 & 2.422 & \textbf{0.947} \\
# \bottomrule
# \end{tabular}
# \end{table}
#                       W1 (variability), rel. median  W1 (peak), rel. median  \
# method
# Best, mine                                    0.802                   1.043
# Schedule-direct                               1.106                   0.820
# Stochastic generator                          1.401                   2.422
#
#                       Coverage, median
# method
# Best, mine                       0.275
# Schedule-direct                  0.345
# Stochastic generator             0.947

# %%
# Remove unwanted methods
_methods_to_remove = {
    'Stochastic (bootstrap)',
    'Best, duration-corrected',
}

# ------------------------------------------------------------------
# Population-level metrics across all process--sensor pairs
# ------------------------------------------------------------------
df_extra_pop_all_agg = df_extra_pop_all[
    ~df_extra_pop_all['method'].isin(_methods_to_remove)
].copy()

if df_extra_pop_all_agg.empty:
    print('No additional population-eval data available after filtering.')

else:
    agg_all_processes = (
        df_extra_pop_all_agg
        .groupby('method')
        .agg(
            **{
                'W1 (variability), rel. median': (
                    'w1_variability_rel', 'median'
                ),
                'W1 (peak), rel. median': (
                    'w1_peak_rel', 'median'
                ),
            }
        )
    )

    # ------------------------------------------------------------------
    # Add flat W1(value), relative median from df_sp_cases_all
    # pooled across every process--sensor--case instance
    # ------------------------------------------------------------------
    df_sp_cases_all_agg = df_sp_cases_all[
        ~df_sp_cases_all['method'].isin(_methods_to_remove)
    ].copy()

    value_by_method = (
        df_sp_cases_all_agg
        .groupby('method')['w1_value_rel']
        .median()
        .rename('W1 (value), rel. median')
    )

    # Add W1(value) to the population-level table
    agg_all_processes = agg_all_processes.join(
        value_by_method,
        how='left'
    )

    # Keep the three desired metrics
    agg_all_processes = agg_all_processes[
        [
            'W1 (variability), rel. median',
            'W1 (peak), rel. median',
            'W1 (value), rel. median',
        ]
    ].sort_values('W1 (variability), rel. median')

    # Bold the best value in each column.
    # Lower is better for all three W1 metrics.
    str_table_all_processes = _bold_best_per_column_dir(
        agg_all_processes,
        higher_is_better_cols=(),
    )

    latex_all_processes = str_table_all_processes.to_latex(
        escape=False,
        column_format='l|c|c|c',
        caption=(
            f'Additional Population-Level metrics aggregated across all processes, '
            f'experiment {EXPERIMENT} ({SPLIT} evaluation). '
            r'Variability and peak are reported as medians across all '
            r'process--sensor pairs. W1(value) is pooled flat across every '
            r'process--sensor--case instance. Lower values are better. '
            r'\textbf{Bold} indicates the best value.'
        ),
        label=f'tab:extra_population_eval_{EXPERIMENT}_{SPLIT}_all_processes',
        position='H',
    )

    print('% === All processes ===')
    print(latex_all_processes.replace('_', r'\_'))
    display(agg_all_processes.round(3))
# Out:
# % === All processes ===
# \begin{table}[H]
# \caption{Additional Population-Level metrics aggregated across all processes, experiment 960 (test evaluation). Variability and peak are reported as medians across all process--sensor pairs. W1(value) is pooled flat across every process--sensor--case instance. Lower values are better. \textbf{Bold} indicates the best value.}
# \label{tab:extra\_population\_eval\_960\_test\_all\_processes}
# \begin{tabular}{l|c|c|c}
# \toprule
#  & W1 (variability), rel. median & W1 (peak), rel. median & W1 (value), rel. median \\
# method &  &  &  \\
# \midrule
# Best, mine & \textbf{0.802} & 1.043 & 1.166 \\
# Schedule-direct & 1.106 & \textbf{0.820} & \textbf{1.043} \\
# Stochastic generator & 1.401 & 2.422 & 1.319 \\
# \bottomrule
# \end{tabular}
# \end{table}
#                       W1 (variability), rel. median  W1 (peak), rel. median  \
# method
# Best, mine                                    0.802                   1.043
# Schedule-direct                               1.106                   0.820
# Stochastic generator                          1.401                   2.422
#
#                       W1 (value), rel. median
# method
# Best, mine                              1.166
# Schedule-direct                         1.043
# Stochastic generator                    1.319
