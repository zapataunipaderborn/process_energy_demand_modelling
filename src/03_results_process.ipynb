# %% [markdown]
# # Process Discovery Quality — Fitness, Precision, Generalization, Simplicity
#
# A copy of `results_process` restructured around the four **classic process-discovery
# dimensions**, followed by the **time metrics** (activity duration and case span).
#
# Column order:
# 1. **Fitness · Precision · Generalization · Simplicity** — quality of the *discovered
#    model* (higher = better).
# 2. **Evt-Ratio Err · Dur WAPE · Dur MAE · Span WAPE · Span MAE** — timing errors of the *simulation*
#    (lower = better).
#
# **Edge-F1 is deliberately not shown.**
#
# Same row structure as `results_process`: three **process methods** × three
# **time-approach** methods.
#
# - **Alpha** — the alpha-miner net (naive process-discovery baseline).
# - **Combined-best** — best discovered model per process (selection unchanged from
#   `results_process`, so the two notebooks agree).
# - **Budget** — best model + total-duration budgeting (`petri_net_budget`).
# - Time approaches: **baseline** · **ml_global** (`_ml_plus_global`) ·
#   **ml_local** (`_ml_plus_per_act`).
#
# > **Read the first four columns as model-level, not simulation-level.** They are
# > computed by replaying the **real** log against the discovered net
# > (`02_modelling.py`, section 6), per station and averaged — Simplicity looks only at
# > the net. They therefore do **not** depend on the simulation policy, so
# > Combined-best and Budget (which share the same heuristic net) and all three
# > time-prediction variants report *identical* values. Only the Alpha row differs.
# > The time columns are where the nine rows actually separate.
#
# Aggregation across processes = **median**.

# %%
# ── Config ────────────────────────────────────────────────────────────────────
EXPERIMENT = 1000
SPLIT      = 'test'
AGG        = 'median'      # aggregation across processes for the combined table

PROCESS_METHODS = {
    'Alpha':         True,
    'Combined-best': True,
    'Budget':        True,
}
TIME_PREDICTIONS = {
    'baseline':  True,
    'ml_global': True,
    'ml_local':  True,
}

# Combined-best selection metric — kept identical to `results_process` on purpose,
# so both notebooks always resolve to the same model. These are exactly the four
# columns this notebook displays first.
# Model selection ALWAYS happens on TRAIN, independently of SPLIT (which only
# controls what the tables report). Selecting on the split being reported would
# let a model be chosen for fitting the evaluation data.
SELECTION_SPLIT = 'train'

SELECTION_METRIC_BASES = [
    'conformance_metrics_fitness',
    'conformance_metrics_precision',
    'conformance_metrics_generalization',
    'conformance_metrics_simplicity',
]
# The four selection metrics are QUALITY scores (higher = better), so the best
# model is the argmax of their average -- not the argmin used when the criterion
# was expressed as errors.
SELECTION_HIGHER_IS_BETTER = True
SHOW_EVENT_RATIO = True    # Evt-Ratio Err sits after Simplicity, before the time metrics
SAVE_LATEX     = True
COMPACT_LATEX  = True      # \scriptsize + tight tabcolsep + 2-line row labels/headers

# %%
import pandas as pd
from pathlib import Path
from IPython.display import display, Markdown

results_root = Path('..') / 'results'
runs = sorted([d for d in results_root.iterdir()
               if d.is_dir() and d.name.startswith(f'experiment_{EXPERIMENT}_')])
assert runs, f'No runs found for experiment {EXPERIMENT}'
run_dir = runs[-1]
print(f'Loading: {run_dir.name}')

df = pd.read_parquet(run_dir / 'process_eval_results.parquet')
sp = SPLIT.lower() + '_'
assert any(c.startswith(sp) for c in df.columns), f'No {sp}* columns found'

def parse_mode(m):
    r = str(m)
    if not r.startswith('petri_net_'):
        return r, 'baseline'
    r = r[len('petri_net_'):]
    if r.endswith('_ml_plus_global'):
        return r[:-len('_ml_plus_global')], 'ml_global'
    if r.endswith('_ml_plus_per_act'):
        return r[:-len('_ml_plus_per_act')], 'ml_local'
    return r, 'baseline'

df['model'], df['time_pred'] = zip(*df['mode'].map(parse_mode))
df = df.copy()
print(f'{len(df)} rows | processes: {sorted(df["process"].unique())} | '
      f'models: {sorted(df["model"].unique())}')
# Out:
# Loading: experiment_1000_20260729_201444
# 60 rows | processes: ['process_1', 'process_2', 'process_3', 'process_4_1', 'process_4_2', 'process_5'] | models: ['alpha', 'budget', 'combined', 'heuristic']

# %%
# ── Metrics: discovery quality FIRST (higher = better), then timing (lower) ──
# Unlike `results_process` (all-errors), this table mixes directions, so every
# metric carries an explicit 'max'/'min' so highlighting and LaTeX bolding pick
# the right end.
_wape_ok   = (sp + 'duration_metrics_activity_duration_wape') in df.columns
_dur_base  = ('duration_metrics_activity_duration_wape' if _wape_ok
              else 'duration_metrics_activity_duration_error')
_span_base = ('duration_metrics_case_span_wape'
              if (sp + 'duration_metrics_case_span_wape') in df.columns
              else 'duration_metrics_case_span_error')

# Columns: (parquet base, display label, LaTeX header, decimals, direction)
# ── Change column headers / decimals HERE ───────────────────────────────────
METRICS = [
    ('conformance_metrics_fitness',           'Fitness',        r'Fitness',                      3, 'max'),
    ('conformance_metrics_precision',         'Precision',      r'Precision',                    3, 'max'),
    ('conformance_metrics_generalization',    'Generalization', r'\makecell{General-\\ization}', 3, 'max'),
    ('conformance_metrics_simplicity',        'Simplicity',     r'Simplicity',                   3, 'max'),
]
if SHOW_EVENT_RATIO:
    METRICS.append(
        ('basic_metrics_event_count_error',   'Evt-Ratio Err',  r'\makecell{Evt-Ratio\\Err}',    3, 'min'))
METRICS += [
    (_dur_base,                               'Dur WAPE (%)',   r'\makecell{Dur\\WAPE (\%)}',    1, 'min'),
    ('duration_metrics_activity_duration_mae','Dur MAE (min)',  r'\makecell{Dur MAE\\(min)}',    1, 'min'),
    (_span_base,                              'Span WAPE (%)',  r'\makecell{Span\\WAPE (\%)}',   1, 'min'),
    ('duration_metrics_case_span_mae',        'Span MAE (min)', r'\makecell{Span MAE\\(min)}',   1, 'min'),
]

METRICS   = [m for m in METRICS if (sp + m[0]) in df.columns]
COL_OF    = {lbl: sp + b for (b, lbl, tex, dp, d) in METRICS}
LABELS    = [lbl for (b, lbl, tex, dp, d) in METRICS]
TEX_HDR   = {lbl: tex for (b, lbl, tex, dp, d) in METRICS}
DECIMALS  = {lbl: dp  for (b, lbl, tex, dp, d) in METRICS}   # used by HTML *and* LaTeX
DIRECTION = {lbl: d   for (b, lbl, tex, dp, d) in METRICS}

def best_of(series, lbl):
    # Direction-aware best value of a column slice; None when nothing is finite.
    v = series.dropna()
    if v.empty:
        return None
    return v.max() if DIRECTION[lbl] == 'max' else v.min()

print('Discovery :', [l for l in LABELS if DIRECTION[l] == 'max'])
print('Timing    :', [l for l in LABELS if DIRECTION[l] == 'min'])
# Out:
# Discovery : ['Fitness', 'Precision', 'Generalization', 'Simplicity']
# Timing    : ['Evt-Ratio Err', 'Dur WAPE (%)', 'Dur MAE (min)', 'Span WAPE (%)', 'Span MAE (min)']

# %%
# ── Combined-best process model per process ──────────────────────────────────
# The pipeline now makes this choice during TRAINING (02_modelling.py,
# _combined_selection_score) and records it as the 'petri_net_combined' mode
# with a 'selected_mining_algorithm' column. Prefer that recorded verdict so
# the notebook *reports* the decision instead of re-deriving it. Experiments
# run before petri_net_combined was enabled carry no such rows, so the
# identical rule is kept here as a fallback.
_sel_prefix = SELECTION_SPLIT.lower() + '_'          # selection on TRAIN
_sel_cols = [_sel_prefix + b for b in SELECTION_METRIC_BASES
             if (_sel_prefix + b) in df.columns]
assert _sel_cols, f'no {_sel_prefix}* selection columns found'

# 'combined' is the pipeline's verdict, not a miner — it must never compete
# against the miners it was itself selected from.
_candidates = sorted(set(df['model'].unique())
                     - {'alpha', 'budget', 'combined'})

_pipeline_choice = {}
if 'selected_mining_algorithm' in df.columns:
    _cmb = df[(df['model'] == 'combined') & df['selected_mining_algorithm'].notna()]
    _pipeline_choice = (_cmb.groupby('process')['selected_mining_algorithm']
                            .first().to_dict())

best_miner = {}
for proc, g in df.groupby('process'):
    if proc in _pipeline_choice:
        best_miner[proc] = _pipeline_choice[proc]
        continue
    gc = g[g['model'].isin(_candidates)]
    if gc.empty:
        best_miner[proc] = None
        continue
    score = gc.groupby('model')[_sel_cols].mean().mean(axis=1)   # avg of the 4 dimensions
    best_miner[proc] = score.idxmax() if SELECTION_HIGHER_IS_BETTER else score.idxmin()

_src = ('pipeline, on TRAIN' if _pipeline_choice
        else f'notebook fallback, on {SELECTION_SPLIT.upper()}')
print(f'Combined-best selected by {_src} | miner candidates: {_candidates}')
if len(_candidates) < 2 and not _pipeline_choice:
    print('  ⚠️  fewer than two miners in this run — no selection actually took place')
for p, m in best_miner.items():
    print(f'  {p}: {m}')

def model_for(proc, pm_label):
    if pm_label == 'Alpha':         return 'alpha'
    if pm_label == 'Budget':        return 'budget'
    if pm_label == 'Combined-best': return best_miner.get(proc)
    return None
# Out:
# Combined-best selected by pipeline, on TRAIN | miner candidates: ['heuristic']
#   process_1: heuristic
#   process_2: heuristic
#   process_3: heuristic
#   process_4_1: heuristic
#   process_4_2: heuristic
#   process_5: heuristic

# %%
# ── Assemble the long table (one row per process × method × time approach) ───
PM_ORDER   = [k for k in ['Alpha', 'Combined-best', 'Budget'] if PROCESS_METHODS.get(k)]
TIME_ORDER = [k for k in ['baseline', 'ml_global', 'ml_local'] if TIME_PREDICTIONS.get(k)]

records = []
for proc, g in df.groupby('process'):
    for pm in PM_ORDER:
        mdl = model_for(proc, pm)
        if mdl is None:
            continue
        for _, row in g[g['model'] == mdl].iterrows():
            if row['time_pred'] not in TIME_ORDER:
                continue
            rec = {'process': proc, 'Process method': pm, 'Time approach': row['time_pred']}
            for lbl, col in COL_OF.items():
                rec[lbl] = row[col]
            records.append(rec)

long_df = pd.DataFrame(records)
print(f'long_df: {len(long_df)} rows | '
      f'{long_df["process"].nunique()} processes × {len(PM_ORDER)} process methods '
      f'× {len(TIME_ORDER)} time approaches')
# Out:
# long_df: 54 rows | 6 processes × 3 process methods × 3 time approaches

# %% [markdown]
# ## Evaluations per method — counted before any result
#
# How many evaluations each row of the tables below is a median over. The numbers are
# only comparable if every method is scored on the **same population**; any row that
# falls short is flagged.

# %%
# ── Evaluations behind every number below ────────────────────────────────────
# Every cell of every table that follows is a median over PROCESSES: `long_df`
# carries exactly one row per (process, process method, time approach). Those
# medians are only comparable if each row of the tables aggregates the SAME
# population, so it is counted here, before any result is shown.
#   processes   -- how many processes that (method, time approach) row spans
#   <metric>    -- non-NaN values of that metric actually entering the median
#                  (a NaN silently shrinks the population for that column only)
def eval_counts_table(ldf):
    g = ldf.groupby(['Process method', 'Time approach'])
    out = pd.DataFrame({'processes': g['process'].nunique()})
    for lbl in LABELS:
        out[lbl] = g[lbl].count()
    idx = pd.MultiIndex.from_tuples(
        [(pm, tp) for pm in PM_ORDER for tp in TIME_ORDER if (pm, tp) in out.index],
        names=['Process method', 'Time approach'])
    return out.reindex(idx).astype(int)


def report_count_discrepancies(counts, unit):
    # Equal counts in every row = every method scored on the same population.
    bad = [c for c in counts.columns if counts[c].nunique(dropna=False) > 1]
    if not bad:
        print(f'✅ like-for-like: every method below is scored on the same '
              f'{int(counts.iloc[0, 0])} {unit}')
        return bad
    print('⚠️ counts differ across methods — the medians below are NOT taken over '
          'the same population, so the comparison is not like-for-like:')
    for c in bad:
        hi = counts[c].max()
        print(f'   {c}: max {hi}, short rows -> ' +
              ', '.join(f'{i}={v}' for i, v in counts[c].items() if v != hi))
    return bad


eval_counts = eval_counts_table(long_df)
display(Markdown('### Evaluation counts per method — the population of every median below'))
display(eval_counts)
_bad_counts = report_count_discrepancies(eval_counts, 'processes')

# Coverage matrix — a 0 pinpoints the (method, process) the run never produced.
_cover = (long_df.assign(_n=1)
                 .pivot_table(index=['Process method', 'Time approach'], columns='process',
                              values='_n', aggfunc='sum', fill_value=0)
                 .astype(int).reindex(eval_counts.index))
display(Markdown('**Rows per process** — a 0 means that method has no result for that process'))
display(_cover)
# Out:
# ### Evaluation counts per method — the population of every median below
#                               processes  Fitness  Precision  Generalization  \
# Process method Time approach
# Alpha          baseline               6        6          6               6
#                ml_global              6        6          6               6
#                ml_local               6        6          6               6
# Combined-best  baseline               6        6          6               6
#                ml_global              6        6          6               6
#                ml_local               6        6          6               6
# Budget         baseline               6        6          6               6
#                ml_global              6        6          6               6
#                ml_local               6        6          6               6
#
#                               Simplicity  Evt-Ratio Err  Dur WAPE (%)  \
# Process method Time approach
# Alpha          baseline                6              6             6
#                ml_global               6              6             6
#                ml_local                6              6             6
# Combined-best  baseline                6              6             6
#                ml_global               6              6             6
#                ml_local                6              6             6
# Budget         baseline                6              6             6
#                ml_global               6              6             6
#                ml_local                6              6             6
#
#                               Dur MAE (min)  Span WAPE (%)  Span MAE (min)
# Process method Time approach
# Alpha          baseline                   6              6               6
#                ml_global                  6              6               6
#                ml_local                   6              6               6
# Combined-best  baseline                   6              6               6
#                ml_global                  6              6               6
#                ml_local                   6              6               6
# Budget         baseline                   6              6               6
#                ml_global                  6              6               6
#                ml_local                   6              6               6
# ✅ like-for-like: every method below is scored on the same 6 processes
# **Rows per process** — a 0 means that method has no result for that process
# process                       process_1  process_2  process_3  process_4_1  \
# Process method Time approach
# Alpha          baseline               1          1          1            1
#                ml_global              1          1          1            1
#                ml_local               1          1          1            1
# Combined-best  baseline               1          1          1            1
#                ml_global              1          1          1            1
#                ml_local               1          1          1            1
# Budget         baseline               1          1          1            1
#                ml_global              1          1          1            1
#                ml_local               1          1          1            1
#
# process                       process_4_2  process_5
# Process method Time approach
# Alpha          baseline                 1          1
#                ml_global                1          1
#                ml_local                 1          1
# Combined-best  baseline                 1          1
#                ml_global                1          1
#                ml_local                 1          1
# Budget         baseline                 1          1
#                ml_global                1          1
#                ml_local                 1          1

# %%
# ── Aggregate across processes ───────────────────────────────────────────────
def build_combined(long_df, agg='median'):
    t = long_df.groupby(['Process method', 'Time approach'])[LABELS].agg(agg)
    idx = pd.MultiIndex.from_tuples(
        [(pm, tp) for pm in PM_ORDER for tp in TIME_ORDER if (pm, tp) in t.index],
        names=['Process method', 'Time approach'])
    return t.reindex(idx)

combined = build_combined(long_df, agg=AGG)

def _fmt(v, lbl):
    return '' if pd.isna(v) else f'{v:.{DECIMALS[lbl]}f}'

def style_table(tbl):
    best = {c: best_of(tbl[c], c) for c in tbl.columns}
    def _styler(_):
        out = pd.DataFrame('', index=tbl.index, columns=tbl.columns)
        for col in tbl.columns:
            b = best[col]
            if b is None:
                continue
            for idx in tbl.index:
                v = tbl.loc[idx, col]
                if pd.notna(v) and abs(v - b) < 1e-9:
                    out.loc[idx, col] = 'font-weight:700;background-color:#d6ecff;'
        return out
    fmt = {lbl: (lambda v, l=lbl: _fmt(v, l)) for lbl in tbl.columns}
    return (tbl.style.format(fmt).apply(_styler, axis=None)
              .set_caption(f'Discovery quality (higher = better) + timing errors '
                           f'(lower = better) — {AGG} across processes'))

display(Markdown(f'### Discovery quality + timing — all processes ({AGG})'))
display(style_table(combined))
# Out:
# ### Discovery quality + timing — all processes (median)
# <style type="text/css">
# #T_1692e_row3_col0, #T_1692e_row3_col1, #T_1692e_row3_col2, #T_1692e_row3_col3, #T_1692e_row4_col0, #T_1692e_row4_col1, #T_1692e_row4_col2, #T_1692e_row4_col3, #T_1692e_row5_col0, #T_1692e_row5_col1, #T_1692e_row5_col2, #T_1692e_row5_col3, #T_1692e_row5_col5, #T_1692e_row5_col6, #T_1692e_row6_col0, #T_1692e_row6_col1, #T_1692e_row6_col2, #T_1692e_row6_col3, #T_1692e_row7_col0, #T_1692e_row7_col1, #T_1692e_row7_col2, #T_1692e_row7_col3, #T_1692e_row8_col0, #T_1692e_row8_col1, #T_1692e_row8_col2, #T_1692e_row8_col3, #T_1692e_row8_col4, #T_1692e_row8_col7, #T_1692e_row8_col8 {
#   font-weight: 700;
#   background-color: #d6ecff;
# }
# </style>
# <table id="T_1692e">
#   <caption>Discovery quality (higher = better) + timing errors (lower = better) — median across processes</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1692e_level0_col0" class="col_heading level0 col0" >Fitness</th>
#       <th id="T_1692e_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_1692e_level0_col2" class="col_heading level0 col2" >Generalization</th>
#       <th id="T_1692e_level0_col3" class="col_heading level0 col3" >Simplicity</th>
#       <th id="T_1692e_level0_col4" class="col_heading level0 col4" >Evt-Ratio Err</th>
#       <th id="T_1692e_level0_col5" class="col_heading level0 col5" >Dur WAPE (%)</th>
#       <th id="T_1692e_level0_col6" class="col_heading level0 col6" >Dur MAE (min)</th>
#       <th id="T_1692e_level0_col7" class="col_heading level0 col7" >Span WAPE (%)</th>
#       <th id="T_1692e_level0_col8" class="col_heading level0 col8" >Span MAE (min)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Process method</th>
#       <th class="index_name level1" >Time approach</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1692e_level0_row0" class="row_heading level0 row0" rowspan="3">Alpha</th>
#       <th id="T_1692e_level1_row0" class="row_heading level1 row0" >baseline</th>
#       <td id="T_1692e_row0_col0" class="data row0 col0" >0.636</td>
#       <td id="T_1692e_row0_col1" class="data row0 col1" >0.396</td>
#       <td id="T_1692e_row0_col2" class="data row0 col2" >0.545</td>
#       <td id="T_1692e_row0_col3" class="data row0 col3" >0.489</td>
#       <td id="T_1692e_row0_col4" class="data row0 col4" >0.542</td>
#       <td id="T_1692e_row0_col5" class="data row0 col5" >63.2</td>
#       <td id="T_1692e_row0_col6" class="data row0 col6" >7.3</td>
#       <td id="T_1692e_row0_col7" class="data row0 col7" >69.1</td>
#       <td id="T_1692e_row0_col8" class="data row0 col8" >321.8</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level1_row1" class="row_heading level1 row1" >ml_global</th>
#       <td id="T_1692e_row1_col0" class="data row1 col0" >0.636</td>
#       <td id="T_1692e_row1_col1" class="data row1 col1" >0.396</td>
#       <td id="T_1692e_row1_col2" class="data row1 col2" >0.545</td>
#       <td id="T_1692e_row1_col3" class="data row1 col3" >0.489</td>
#       <td id="T_1692e_row1_col4" class="data row1 col4" >0.542</td>
#       <td id="T_1692e_row1_col5" class="data row1 col5" >62.5</td>
#       <td id="T_1692e_row1_col6" class="data row1 col6" >10.0</td>
#       <td id="T_1692e_row1_col7" class="data row1 col7" >63.3</td>
#       <td id="T_1692e_row1_col8" class="data row1 col8" >351.2</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level1_row2" class="row_heading level1 row2" >ml_local</th>
#       <td id="T_1692e_row2_col0" class="data row2 col0" >0.636</td>
#       <td id="T_1692e_row2_col1" class="data row2 col1" >0.396</td>
#       <td id="T_1692e_row2_col2" class="data row2 col2" >0.545</td>
#       <td id="T_1692e_row2_col3" class="data row2 col3" >0.489</td>
#       <td id="T_1692e_row2_col4" class="data row2 col4" >0.542</td>
#       <td id="T_1692e_row2_col5" class="data row2 col5" >52.6</td>
#       <td id="T_1692e_row2_col6" class="data row2 col6" >6.7</td>
#       <td id="T_1692e_row2_col7" class="data row2 col7" >58.5</td>
#       <td id="T_1692e_row2_col8" class="data row2 col8" >269.5</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level0_row3" class="row_heading level0 row3" rowspan="3">Combined-best</th>
#       <th id="T_1692e_level1_row3" class="row_heading level1 row3" >baseline</th>
#       <td id="T_1692e_row3_col0" class="data row3 col0" >0.994</td>
#       <td id="T_1692e_row3_col1" class="data row3 col1" >0.728</td>
#       <td id="T_1692e_row3_col2" class="data row3 col2" >0.664</td>
#       <td id="T_1692e_row3_col3" class="data row3 col3" >0.660</td>
#       <td id="T_1692e_row3_col4" class="data row3 col4" >0.257</td>
#       <td id="T_1692e_row3_col5" class="data row3 col5" >51.1</td>
#       <td id="T_1692e_row3_col6" class="data row3 col6" >7.0</td>
#       <td id="T_1692e_row3_col7" class="data row3 col7" >79.3</td>
#       <td id="T_1692e_row3_col8" class="data row3 col8" >398.2</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level1_row4" class="row_heading level1 row4" >ml_global</th>
#       <td id="T_1692e_row4_col0" class="data row4 col0" >0.994</td>
#       <td id="T_1692e_row4_col1" class="data row4 col1" >0.728</td>
#       <td id="T_1692e_row4_col2" class="data row4 col2" >0.664</td>
#       <td id="T_1692e_row4_col3" class="data row4 col3" >0.660</td>
#       <td id="T_1692e_row4_col4" class="data row4 col4" >0.257</td>
#       <td id="T_1692e_row4_col5" class="data row4 col5" >64.9</td>
#       <td id="T_1692e_row4_col6" class="data row4 col6" >10.2</td>
#       <td id="T_1692e_row4_col7" class="data row4 col7" >67.3</td>
#       <td id="T_1692e_row4_col8" class="data row4 col8" >402.8</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level1_row5" class="row_heading level1 row5" >ml_local</th>
#       <td id="T_1692e_row5_col0" class="data row5 col0" >0.994</td>
#       <td id="T_1692e_row5_col1" class="data row5 col1" >0.728</td>
#       <td id="T_1692e_row5_col2" class="data row5 col2" >0.664</td>
#       <td id="T_1692e_row5_col3" class="data row5 col3" >0.660</td>
#       <td id="T_1692e_row5_col4" class="data row5 col4" >0.257</td>
#       <td id="T_1692e_row5_col5" class="data row5 col5" >38.7</td>
#       <td id="T_1692e_row5_col6" class="data row5 col6" >5.6</td>
#       <td id="T_1692e_row5_col7" class="data row5 col7" >71.7</td>
#       <td id="T_1692e_row5_col8" class="data row5 col8" >424.5</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level0_row6" class="row_heading level0 row6" rowspan="3">Budget</th>
#       <th id="T_1692e_level1_row6" class="row_heading level1 row6" >baseline</th>
#       <td id="T_1692e_row6_col0" class="data row6 col0" >0.994</td>
#       <td id="T_1692e_row6_col1" class="data row6 col1" >0.728</td>
#       <td id="T_1692e_row6_col2" class="data row6 col2" >0.664</td>
#       <td id="T_1692e_row6_col3" class="data row6 col3" >0.660</td>
#       <td id="T_1692e_row6_col4" class="data row6 col4" >0.071</td>
#       <td id="T_1692e_row6_col5" class="data row6 col5" >49.4</td>
#       <td id="T_1692e_row6_col6" class="data row6 col6" >9.4</td>
#       <td id="T_1692e_row6_col7" class="data row6 col7" >31.7</td>
#       <td id="T_1692e_row6_col8" class="data row6 col8" >210.0</td>
#     </tr>
#     <tr>
#       <th id="T_1692e_level1_row7" class="row_heading level1 row7" >ml_global</th>
#       <td id="T_1692e_row7_col0" class="data row7 col0" >0.994</td>
#       <td id="T_1692e_row7_col1" class="data row7 col1" >0.728</td>
#       <td id="T_1692e_row7_col2" class="data row7 col2" >0.664</td>
#       <td id="T_1692e_row7_col3" class="data row7 col3" >0.660</td>
#       <td id="T_1692e_row7_col4" class="data row7 col4" >0.137</td>
#       <td id="T_1692e_row7_col5" class="data row7 col5" >67.5</td>
#       <td id="T_1692e_row7_col6" class="d

# %% [markdown]
# ## Per process — one large combined table
#
# Every process shown **individually**. Best value per column **within each process**
# is highlighted / bolded — direction-aware (max for the four discovery dimensions,
# min for the timing errors).

# %%
# ── Large per-process table: MultiIndex (Process, method, time prediction) ────
def build_per_process(long_df):
    t = long_df.groupby(['process', 'Process method', 'Time approach'])[LABELS].median()
    procs = sorted(long_df['process'].unique())
    idx = pd.MultiIndex.from_tuples(
        [(p, pm, tp) for p in procs for pm in PM_ORDER for tp in TIME_ORDER
         if (p, pm, tp) in t.index],
        names=['Process', 'Process method', 'Time approach'])
    return t.reindex(idx)

per_process = build_per_process(long_df)

def _best_within_process(tbl):
    best = {}
    for proc, sub in tbl.groupby(level=0):
        for col in tbl.columns:
            best[(proc, col)] = best_of(sub[col], col)
    return best

def style_per_process(tbl):
    best = _best_within_process(tbl)
    def _styler(_):
        out = pd.DataFrame('', index=tbl.index, columns=tbl.columns)
        for idx in tbl.index:
            for col in tbl.columns:
                v = tbl.loc[idx, col]
                b = best.get((idx[0], col))
                if b is not None and pd.notna(v) and abs(v - b) < 1e-9:
                    out.loc[idx, col] = 'font-weight:700;background-color:#d6ecff;'
        return out
    fmt = {lbl: (lambda v, l=lbl: _fmt(v, l)) for lbl in tbl.columns}
    return (tbl.style.format(fmt).apply(_styler, axis=None)
              .set_caption('Per-process — best per column within each process '
                           '(discovery: higher; timing: lower)'))

display(Markdown('### Discovery quality + timing — per process (large table)'))
display(style_per_process(per_process))
# Out:
# ### Discovery quality + timing — per process (large table)
# <style type="text/css">
# #T_8e6a1_row3_col0, #T_8e6a1_row3_col1, #T_8e6a1_row3_col2, #T_8e6a1_row3_col3, #T_8e6a1_row3_col4, #T_8e6a1_row4_col0, #T_8e6a1_row4_col1, #T_8e6a1_row4_col2, #T_8e6a1_row4_col3, #T_8e6a1_row4_col4, #T_8e6a1_row5_col0, #T_8e6a1_row5_col1, #T_8e6a1_row5_col2, #T_8e6a1_row5_col3, #T_8e6a1_row5_col4, #T_8e6a1_row6_col0, #T_8e6a1_row6_col1, #T_8e6a1_row6_col2, #T_8e6a1_row6_col3, #T_8e6a1_row7_col0, #T_8e6a1_row7_col1, #T_8e6a1_row7_col2, #T_8e6a1_row7_col3, #T_8e6a1_row7_col7, #T_8e6a1_row7_col8, #T_8e6a1_row8_col0, #T_8e6a1_row8_col1, #T_8e6a1_row8_col2, #T_8e6a1_row8_col3, #T_8e6a1_row8_col5, #T_8e6a1_row8_col6, #T_8e6a1_row12_col0, #T_8e6a1_row12_col1, #T_8e6a1_row12_col2, #T_8e6a1_row12_col3, #T_8e6a1_row13_col0, #T_8e6a1_row13_col1, #T_8e6a1_row13_col2, #T_8e6a1_row13_col3, #T_8e6a1_row14_col0, #T_8e6a1_row14_col1, #T_8e6a1_row14_col2, #T_8e6a1_row14_col3, #T_8e6a1_row15_col0, #T_8e6a1_row15_col1, #T_8e6a1_row15_col2, #T_8e6a1_row15_col3, #T_8e6a1_row15_col4, #T_8e6a1_row16_col0, #T_8e6a1_row16_col1, #T_8e6a1_row16_col2, #T_8e6a1_row16_col3, #T_8e6a1_row16_col7, #T_8e6a1_row16_col8, #T_8e6a1_row17_col0, #T_8e6a1_row17_col1, #T_8e6a1_row17_col2, #T_8e6a1_row17_col3, #T_8e6a1_row17_col5, #T_8e6a1_row17_col6, #T_8e6a1_row21_col0, #T_8e6a1_row21_col1, #T_8e6a1_row21_col2, #T_8e6a1_row21_col3, #T_8e6a1_row22_col0, #T_8e6a1_row22_col1, #T_8e6a1_row22_col2, #T_8e6a1_row22_col3, #T_8e6a1_row23_col0, #T_8e6a1_row23_col1, #T_8e6a1_row23_col2, #T_8e6a1_row23_col3, #T_8e6a1_row23_col5, #T_8e6a1_row23_col6, #T_8e6a1_row24_col0, #T_8e6a1_row24_col1, #T_8e6a1_row24_col2, #T_8e6a1_row24_col3, #T_8e6a1_row24_col4, #T_8e6a1_row25_col0, #T_8e6a1_row25_col1, #T_8e6a1_row25_col2, #T_8e6a1_row25_col3, #T_8e6a1_row25_col7, #T_8e6a1_row25_col8, #T_8e6a1_row26_col0, #T_8e6a1_row26_col1, #T_8e6a1_row26_col2, #T_8e6a1_row26_col3, #T_8e6a1_row27_col2, #T_8e6a1_row28_col2, #T_8e6a1_row29_col2, #T_8e6a1_row30_col0, #T_8e6a1_row30_col1, #T_8e6a1_row30_col3, #T_8e6a1_row31_col0, #T_8e6a1_row31_col1, #T_8e6a1_row31_col3, #T_8e6a1_row32_col0, #T_8e6a1_row32_col1, #T_8e6a1_row32_col3, #T_8e6a1_row33_col0, #T_8e6a1_row33_col1, #T_8e6a1_row33_col3, #T_8e6a1_row34_col0, #T_8e6a1_row34_col1, #T_8e6a1_row34_col3, #T_8e6a1_row34_col4, #T_8e6a1_row34_col5, #T_8e6a1_row34_col6, #T_8e6a1_row35_col0, #T_8e6a1_row35_col1, #T_8e6a1_row35_col3, #T_8e6a1_row35_col7, #T_8e6a1_row35_col8, #T_8e6a1_row36_col6, #T_8e6a1_row39_col0, #T_8e6a1_row39_col1, #T_8e6a1_row39_col2, #T_8e6a1_row39_col3, #T_8e6a1_row40_col0, #T_8e6a1_row40_col1, #T_8e6a1_row40_col2, #T_8e6a1_row40_col3, #T_8e6a1_row41_col0, #T_8e6a1_row41_col1, #T_8e6a1_row41_col2, #T_8e6a1_row41_col3, #T_8e6a1_row42_col0, #T_8e6a1_row42_col1, #T_8e6a1_row42_col2, #T_8e6a1_row42_col3, #T_8e6a1_row42_col4, #T_8e6a1_row42_col5, #T_8e6a1_row43_col0, #T_8e6a1_row43_col1, #T_8e6a1_row43_col2, #T_8e6a1_row43_col3, #T_8e6a1_row44_col0, #T_8e6a1_row44_col1, #T_8e6a1_row44_col2, #T_8e6a1_row44_col3, #T_8e6a1_row44_col7, #T_8e6a1_row44_col8, #T_8e6a1_row48_col0, #T_8e6a1_row48_col1, #T_8e6a1_row48_col2, #T_8e6a1_row48_col3, #T_8e6a1_row49_col0, #T_8e6a1_row49_col1, #T_8e6a1_row49_col2, #T_8e6a1_row49_col3, #T_8e6a1_row50_col0, #T_8e6a1_row50_col1, #T_8e6a1_row50_col2, #T_8e6a1_row50_col3, #T_8e6a1_row50_col6, #T_8e6a1_row51_col0, #T_8e6a1_row51_col1, #T_8e6a1_row51_col2, #T_8e6a1_row51_col3, #T_8e6a1_row52_col0, #T_8e6a1_row52_col1, #T_8e6a1_row52_col2, #T_8e6a1_row52_col3, #T_8e6a1_row52_col7, #T_8e6a1_row52_col8, #T_8e6a1_row53_col0, #T_8e6a1_row53_col1, #T_8e6a1_row53_col2, #T_8e6a1_row53_col3, #T_8e6a1_row53_col4, #T_8e6a1_row53_col5 {
#   font-weight: 700;
#   background-color: #d6ecff;
# }
# </style>
# <table id="T_8e6a1">
#   <caption>Per-process — best per column within each process (discovery: higher; timing: lower)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e6a1_level0_col0" class="col_heading level0 col0" >Fitness</th>
#       <th id="T_8e6a1_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_8e6a1_level0_col2" class="col_heading level0 col2" >Generalization</th>
#       <th id="T_8e6a1_level0_col3" class="col_heading level0 col3" >Simplicity</th>
#       <th id="T_8e6a1_level0_col4" class="col_heading level0 col4" >Evt-Ratio Err</th>
#       <th id="T_8e6a1_level0_col5" class="col_heading level0 col5" >Dur WAPE (%)</th>
#       <th id="T_8e6a1_level0_col6" class="col_heading level0 col6" >Dur MAE (min)</th>
#       <th id="T_8e6a1_level0_col7" class="col_heading level0 col7" >Span WAPE (%)</th>
#       <th id="T_8e6a1_level0_col8" class="col_heading level0 col8" >Span MAE (min)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Process</th>
#       <th class="index_name level1" >Process method</th>
#       <th class="index_name level2" >Time approach</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e6a1_level0_row0" class="row_heading level0 row0" rowspan="9">process_1</th>
#       <th id="T_8e6a1_level1_row0" class="row_heading level1 row0" rowspan="3">Alpha</th>
#       <th id="T_8e6a1_level2_row0" class="row_heading level2 row0" >baseline</th>
#       <td id="T_8e6a1_row0_col0" class="data row0 col0" >0.829</td>
#       <td id="T_8e6a1_row0_col1" class="data row0 col1" >0.310</td>
#       <td id="T_8e6a1_row0_col2" class="data row0 col2" >0.594</td>
#       <td id="T_8e6a1_row0_col3" class="data row0 col3" >0.590</td>
#       <td id="T_8e6a1_row0_col4" class="data row0 col4" >0.064</td>
#       <td id="T_8e6a1_row0_col5" class="data row0 col5" >26.1</td>
#       <td id="T_8e6a1_row0_col6" class="data row0 col6" >1.8</td>
#       <td id="T_8e6a1_row0_col7" class="data row0 col7" >31.1</td>
#       <td id="T_8e6a1_row0_col8" class="data row0 col8" >34.2</td>
#     </tr>
#     <tr>
#       <th id="T_8e6a1_level2_row1" class="row_heading level2 row1" >ml_global</th>
#       <td id="T_8e6a1_row1_col0" class="data row1 col0" >0.829</td>
#       <td id="T_8e6a1_row1_col1" class="data row1 col1" >0.310</td>
#       <td id="T_8e6a1_row1_col2" class="data row1 col2" >0.594</td>
#       <td id="T_8e6a1_row1_col3" class="data row1 col3" >0.590</td>
#       <td id="T_8e6a1_row1_col4" class="data row1 col4" >0.064</td>
#       <td id="T_8e6a1_row1_col5" class="data row1 col5" >11.3</td>
#       <td id="T_8e6a1_row1_col6" class="data row1 col6" >0.8</td>
#       <td id="T_8e6a1_row1_col7" class="data row1 col7" >29.7</td>
#       <td id="T_8e6a1_row1_col8" class="data row1 col8" >27.2</td>
#     </tr>
#     <tr>
#       <th id="T_8e6a1_level2_row2" class="row_heading level2 row2" >ml_local</th>
#       <td id="T_8e6a1_row2_col0" class="data row2 col0" >0.829</td>
#       <td id="T_8e6a1_row2_col1" class="data row2 col1" >0.310</td>
#       <td id="T_8e6a1_row2_col2" class="data row2 col2" >0.594</td>
#       <td id="T_8e6a1_row2_col3" class="data row2 col3" >0.590</td>
#       <td id="T_8e6a1_row2_col4" class="data row2 col4" >0.064</td>
#       <td id="T_8e6a1_row2_col5" class="data row2 col5" >6.4</td>
#       <td id="T_8e6a1_row2_col6" class="data row2 col6" >0.4</td>
#       <td id="T_8e6a1_row2_col7" class="data row2 col7" >32.7</td>
#       <td id="T_8e6a1_row2_col8" class="data row2 col8" >32.4</td>
#     </tr>
#     <tr>
#       <th id="T_8e6a1_level1_row3" class="row_heading level1 row3" rowspan="3">Combined-best</th>
#       <th id="T_8e6a1_level2_row3" class="row_heading level2 row3" >baseline</th>
#       <td id="T_8e6a1_row3_col0" class="data row3 col0" >1.000</td>
#       <td id="T_8e6a1_row3_col1" class="data row3 col1" >0.993</td>
#       <td id="T_8e6a1_row3_col2" class="data row3 col2

# %% [markdown]
# ## Discovery dimensions alone — Alpha vs the discovered model
#
# Because Fitness / Precision / Generalization / Simplicity are model-level, the nine
# rows above collapse to **two distinct values per process**. This compact table drops
# the redundant rows and shows the discovery comparison on its own — one row per
# (process, miner).

# %%
DISC = [l for l in LABELS if DIRECTION[l] == 'max']
_disc_rows = (df[df['model'].isin(['alpha'] + _candidates)]
                .groupby(['process', 'model'])[[COL_OF[l] for l in DISC]].first())
_disc_rows.columns = DISC
_disc_rows.index.names = ['Process', 'Miner']

def style_disc(tbl):
    best = {}
    for proc, sub in tbl.groupby(level=0):
        for col in tbl.columns:
            best[(proc, col)] = best_of(sub[col], col)
    def _styler(_):
        out = pd.DataFrame('', index=tbl.index, columns=tbl.columns)
        for idx in tbl.index:
            for col in tbl.columns:
                v = tbl.loc[idx, col]; b = best.get((idx[0], col))
                if b is not None and pd.notna(v) and abs(v - b) < 1e-9:
                    out.loc[idx, col] = 'font-weight:700;background-color:#d6ecff;'
        return out
    return (tbl.style.format({c: '{:.3f}' for c in tbl.columns}, na_rep='—')
              .apply(_styler, axis=None)
              .set_caption('Process discovery quality — higher = better'))

display(style_disc(_disc_rows))
display(Markdown(f'**Mean across processes**'))
display(_disc_rows.groupby('Miner').mean().round(3))
# Out:
# <style type="text/css">
# #T_5b866_row1_col0, #T_5b866_row1_col1, #T_5b866_row1_col2, #T_5b866_row1_col3, #T_5b866_row3_col0, #T_5b866_row3_col1, #T_5b866_row3_col2, #T_5b866_row3_col3, #T_5b866_row5_col0, #T_5b866_row5_col1, #T_5b866_row5_col2, #T_5b866_row5_col3, #T_5b866_row6_col2, #T_5b866_row7_col0, #T_5b866_row7_col1, #T_5b866_row7_col3, #T_5b866_row9_col0, #T_5b866_row9_col1, #T_5b866_row9_col2, #T_5b866_row9_col3, #T_5b866_row11_col0, #T_5b866_row11_col1, #T_5b866_row11_col2, #T_5b866_row11_col3 {
#   font-weight: 700;
#   background-color: #d6ecff;
# }
# </style>
# <table id="T_5b866">
#   <caption>Process discovery quality — higher = better</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b866_level0_col0" class="col_heading level0 col0" >Fitness</th>
#       <th id="T_5b866_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_5b866_level0_col2" class="col_heading level0 col2" >Generalization</th>
#       <th id="T_5b866_level0_col3" class="col_heading level0 col3" >Simplicity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Process</th>
#       <th class="index_name level1" >Miner</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b866_level0_row0" class="row_heading level0 row0" rowspan="2">process_1</th>
#       <th id="T_5b866_level1_row0" class="row_heading level1 row0" >alpha</th>
#       <td id="T_5b866_row0_col0" class="data row0 col0" >0.829</td>
#       <td id="T_5b866_row0_col1" class="data row0 col1" >0.310</td>
#       <td id="T_5b866_row0_col2" class="data row0 col2" >0.594</td>
#       <td id="T_5b866_row0_col3" class="data row0 col3" >0.590</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level1_row1" class="row_heading level1 row1" >heuristic</th>
#       <td id="T_5b866_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_5b866_row1_col1" class="data row1 col1" >0.993</td>
#       <td id="T_5b866_row1_col2" class="data row1 col2" >0.797</td>
#       <td id="T_5b866_row1_col3" class="data row1 col3" >0.810</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level0_row2" class="row_heading level0 row2" rowspan="2">process_2</th>
#       <th id="T_5b866_level1_row2" class="row_heading level1 row2" >alpha</th>
#       <td id="T_5b866_row2_col0" class="data row2 col0" >0.557</td>
#       <td id="T_5b866_row2_col1" class="data row2 col1" >0.450</td>
#       <td id="T_5b866_row2_col2" class="data row2 col2" >0.496</td>
#       <td id="T_5b866_row2_col3" class="data row2 col3" >0.404</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level1_row3" class="row_heading level1 row3" >heuristic</th>
#       <td id="T_5b866_row3_col0" class="data row3 col0" >0.996</td>
#       <td id="T_5b866_row3_col1" class="data row3 col1" >0.566</td>
#       <td id="T_5b866_row3_col2" class="data row3 col2" >0.583</td>
#       <td id="T_5b866_row3_col3" class="data row3 col3" >0.623</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level0_row4" class="row_heading level0 row4" rowspan="2">process_3</th>
#       <th id="T_5b866_level1_row4" class="row_heading level1 row4" >alpha</th>
#       <td id="T_5b866_row4_col0" class="data row4 col0" >0.564</td>
#       <td id="T_5b866_row4_col1" class="data row4 col1" >0.275</td>
#       <td id="T_5b866_row4_col2" class="data row4 col2" >0.496</td>
#       <td id="T_5b866_row4_col3" class="data row4 col3" >0.407</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level1_row5" class="row_heading level1 row5" >heuristic</th>
#       <td id="T_5b866_row5_col0" class="data row5 col0" >0.992</td>
#       <td id="T_5b866_row5_col1" class="data row5 col1" >0.521</td>
#       <td id="T_5b866_row5_col2" class="data row5 col2" >0.572</td>
#       <td id="T_5b866_row5_col3" class="data row5 col3" >0.622</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level0_row6" class="row_heading level0 row6" rowspan="2">process_4_1</th>
#       <th id="T_5b866_level1_row6" class="row_heading level1 row6" >alpha</th>
#       <td id="T_5b866_row6_col0" class="data row6 col0" >0.707</td>
#       <td id="T_5b866_row6_col1" class="data row6 col1" >0.811</td>
#       <td id="T_5b866_row6_col2" class="data row6 col2" >0.866</td>
#       <td id="T_5b866_row6_col3" class="data row6 col3" >0.571</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level1_row7" class="row_heading level1 row7" >heuristic</th>
#       <td id="T_5b866_row7_col0" class="data row7 col0" >0.996</td>
#       <td id="T_5b866_row7_col1" class="data row7 col1" >0.961</td>
#       <td id="T_5b866_row7_col2" class="data row7 col2" >0.825</td>
#       <td id="T_5b866_row7_col3" class="data row7 col3" >0.714</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level0_row8" class="row_heading level0 row8" rowspan="2">process_4_2</th>
#       <th id="T_5b866_level1_row8" class="row_heading level1 row8" >alpha</th>
#       <td id="T_5b866_row8_col0" class="data row8 col0" >0.741</td>
#       <td id="T_5b866_row8_col1" class="data row8 col1" >0.488</td>
#       <td id="T_5b866_row8_col2" class="data row8 col2" >0.695</td>
#       <td id="T_5b866_row8_col3" class="data row8 col3" >0.615</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level1_row9" class="row_heading level1 row9" >heuristic</th>
#       <td id="T_5b866_row9_col0" class="data row9 col0" >0.992</td>
#       <td id="T_5b866_row9_col1" class="data row9 col1" >0.890</td>
#       <td id="T_5b866_row9_col2" class="data row9 col2" >0.746</td>
#       <td id="T_5b866_row9_col3" class="data row9 col3" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level0_row10" class="row_heading level0 row10" rowspan="2">process_5</th>
#       <th id="T_5b866_level1_row10" class="row_heading level1 row10" >alpha</th>
#       <td id="T_5b866_row10_col0" class="data row10 col0" >0.408</td>
#       <td id="T_5b866_row10_col1" class="data row10 col1" >0.342</td>
#       <td id="T_5b866_row10_col2" class="data row10 col2" >0.429</td>
#       <td id="T_5b866_row10_col3" class="data row10 col3" >0.391</td>
#     </tr>
#     <tr>
#       <th id="T_5b866_level1_row11" class="row_heading level1 row11" >heuristic</th>
#       <td id="T_5b866_row11_col0" class="data row11 col0" >0.969</td>
#       <td id="T_5b866_row11_col1" class="data row11 col1" >0.559</td>
#       <td id="T_5b866_row11_col2" class="data row11 col2" >0.547</td>
#       <td id="T_5b866_row11_col3" class="data row11 col3" >0.600</td>
#     </tr>
#   </tbody>
# </table>
# **Mean across processes**
#            Fitness  Precision  Generalization  Simplicity
# Miner
# alpha        0.634      0.446           0.596       0.497
# heuristic    0.991      0.748           0.678       0.678

# %% [markdown]
# ## LaTeX
#
# MultiIndex rows, best value per column bolded (globally for the aggregated table,
# within each process for the per-process tables), direction-aware. Preamble needs
# `\usepackage{makecell}` and `\usepackage{booktabs}`.

# %%
# ── LaTeX layout knobs — change these if the table doesn't fit ──────────────
LATEX_FONT        = r'\footnotesize'  # \small > \footnotesize > \scriptsize > \tiny
LATEX_TABCOLSEP   = '4pt'             # column padding (LaTeX default 6pt); lower = narrower
LATEX_STRETCH     = '1.0'             # row height multiplier; lower = shorter rows
SHORT_PROCESS_IDS = True              # process_4_1 -> P4.1 in the per-process table

# Paper table (aggregated) knobs — the two-column `table*` float used in the paper.
PAPER_STRETCH = '1.3'
PAPER_FONT    = r'\footnotesize'
# Row labels of the aggregated paper table (level-0 index -> LaTeX).
PAPER_ROW = {
    'Alpha':         r'\makecell[c]{Alpha \\ (Baseline)}',
    'Combined-best': r'\makecell[c]{Best \\ Petri Net}',
    'Budget':        r'\makecell[c]{Best \\ Petri Net \\ + Budget}',
}
# Decimals used ONLY by the paper table. Substring rules first (so a renamed
# column still matches), then exact-label overrides, then DECIMALS.
PAPER_DECIMALS_RULES = [('WAPE', 3)]      # any column whose label contains 'WAPE'
PAPER_DECIMALS       = {}                 # exact-label overrides, e.g. {'Simplicity': 2}
# Column headers of the aggregated paper table (falls back to TEX_HDR).
PAPER_HDR = {
    'Fitness':        r'Fitness',
    'Precision':      r'Precision',
    'Generalization': r'\makecell{Generalization}',
    'Simplicity':     r'Simplicity',
    'Evt-Ratio Err':  r'\makecell{Evt-Ratio\\Error}',
    'Dur WAPE (%)':   r'\makecell{Dur-act\\WAPE (\%)}',
    'Dur MAE (min)':  r'\makecell{Dur-act\\MAE (min)}',
    'Span WAPE (%)':  r'\makecell{Case \\span\\WAPE (\%)}',
    'Span MAE (min)': r'\makecell{Case \\span MAE\\(min)}',
}

# Only labels that genuinely need it are split over two lines.
TEX_ROW = {
    'Combined-best': r'\makecell[l]{Combined-\\best}',
}
# Index level names as they appear in the LaTeX header row.
TEX_IDX_NAME = {'Process method': 'Method', 'Time approach': r'\makecell[l]{Time\\approach}'}

def _tex_esc(s):
    return str(s).replace('_', r'\_')

def _tex_proc(p):
    # process_4_1 -> P4.1 ; process_2 -> P2
    if not SHORT_PROCESS_IDS:
        return str(p)
    return 'P' + str(p).replace('process_', '').replace('_', '.')

def _tex_idx(tbl):
    # Map index values through TEX_ROW / _tex_proc and rename the level headers.
    lv = []
    for i, name in enumerate(tbl.index.names):
        vals = tbl.index.get_level_values(i)
        lv.append([_tex_proc(v) for v in vals] if name == 'Process'
                  else [TEX_ROW.get(v, str(v)) for v in vals])
    out = tbl.copy()
    out.index = pd.MultiIndex.from_arrays(
        lv, names=[TEX_IDX_NAME.get(n, n) for n in tbl.index.names])
    return out

def to_latex_table(tbl, caption, label, best_map=None, n_index=2):
    # best_map: dict[(group_key, col)] -> best value, group_key = row-index level 0.
    # None -> best computed globally per column. Direction comes from DIRECTION.
    if best_map is None:
        best_map = {('__global__', c): best_of(tbl[c], c) for c in tbl.columns}
        key_of = lambda idx: '__global__'
    else:
        key_of = lambda idx: idx[0]
    str_df = pd.DataFrame(index=tbl.index, columns=tbl.columns, dtype=object)
    for col in tbl.columns:
        for idx in tbl.index:
            v = tbl.loc[idx, col]
            if pd.isna(v):
                str_df.loc[idx, col] = ''
            else:
                b = best_map.get((key_of(idx), col))
                s = _fmt(v, col)
                str_df.loc[idx, col] = ((r'\textbf{' + s + '}')
                                        if (b is not None and abs(v - b) < 1e-9) else s)
    str_df = _tex_idx(str_df)
    str_df.columns = [TEX_HDR[c] for c in tbl.columns]
    latex = str_df.to_latex(
        escape=False, multirow=True,
        column_format=('l' * n_index) + '|' + '|'.join(['c'] * len(tbl.columns)),
        caption=caption, label=label, position='H',
    )
    if COMPACT_LATEX:
        latex = latex.replace(
            r'\begin{tabular}',
            f'\\centering\n\\setlength{{\\tabcolsep}}{{{LATEX_TABCOLSEP}}}\n'
            f'\\renewcommand{{\\arraystretch}}{{{LATEX_STRETCH}}}\n{LATEX_FONT}\n'
            r'\begin{tabular}', 1)
    return latex.replace('_', r'\_')

def _paper_dp(lbl):
    # Decimals for one column of the paper table.
    if lbl in PAPER_DECIMALS:
        return PAPER_DECIMALS[lbl]
    for pat, dp in PAPER_DECIMALS_RULES:
        if pat.lower() in str(lbl).lower():
            return dp
    return DECIMALS[lbl]

def _fmt_paper(v, lbl):
    # Same as _fmt but honours PAPER_DECIMALS_RULES / PAPER_DECIMALS.
    return '' if pd.isna(v) else f'{v:.{_paper_dp(lbl)}f}'

def to_paper_table(tbl, caption, label, description):
    # Hand-rolled `table*` float in the exact paper layout: caption on top,
    # booktabs rules, one \multirow block per process method separated by \cline,
    # and a \footnotesize description paragraph under the tabular.
    # Bolding is global per column and direction-aware (DIRECTION).
    n_idx = tbl.index.nlevels
    ncol  = n_idx + len(tbl.columns)
    best  = {c: best_of(tbl[c], c) for c in tbl.columns}

    def cell(v, col):
        if pd.isna(v):
            return ''
        s, b = _fmt_paper(v, col), best[col]
        return (r'\textbf{' + s + '}') if (b is not None and abs(v - b) < 1e-9) else s

    hdr = ([TEX_IDX_NAME.get(n, str(n)) for n in tbl.index.names]
           + [PAPER_HDR.get(c, TEX_HDR[c]) for c in tbl.columns])

    L = [r'\begin{table*}[t]',
         r'\centering',
         rf'\caption{{{caption}}}',
         rf'\label{{{label}}}',
         r'\vspace{-0.5em}',
         rf'\setlength{{\tabcolsep}}{{{LATEX_TABCOLSEP}}}',
         rf'\renewcommand{{\arraystretch}}{{{PAPER_STRETCH}}}',
         PAPER_FONT,
         r'\begin{tabular}{' + 'l' * n_idx + '|'
             + '|'.join(['c'] * len(tbl.columns)) + '}',
         r'\toprule',
         ' & '.join(hdr) + r' \\',
         r'\midrule']

    for pm in dict.fromkeys(tbl.index.get_level_values(0)):      # keeps PM_ORDER
        sub = tbl.xs(pm, level=0, drop_level=False)
        head = rf'\multirow{{{len(sub)}}}{{*}}{{{PAPER_ROW.get(pm, _tex_esc(pm))}}}'
        for idx, row in sub.iterrows():
            L.append(' & '.join([head, _tex_esc(idx[-1])]
                                + [cell(row[c], c) for c in tbl.columns]) + r' \\')
            head = ''                                            # only the first row
        L.append(rf'\cline{{1-{ncol}}}')

    L += [r'\bottomrule',
          r'\end{tabular}',
          r'\vspace{0.5em}',
          r'\noindent\raggedright\footnotesize',
          '',
          description,
          '',
          r'\end{table*}']
    return '\n'.join(L)

# LaTeX is printed only — no process_metrics_tables/ folder is written.

_dir_note = (r'Fitness, Precision, Generalization and Simplicity are discovery quality '
             r'(higher is better); Evt-Ratio Err and the Dur/Span columns are errors '
             r'(lower is better). \textbf{Bold} = best per column')

# ── Aggregated table, paper layout ──────────────────────────────────────────
_paper_desc = (
    r'Description: Process discovery methods are Alpha (naive miner baseline), '
    r'Best Petri Net (best discovered Petri Net), Best Petri Net + Budget (best Petri '
    r'Net + duration budgeting at simulation time), each crossed with the three '
    r'activity-duration predictors (baseline is the median, ml\_local is a ML model '
    r'per activity and ml\_global is a ML model for all activities). Fitness, '
    r'Precision, Generalization and Simplicity are discovery quality (higher is '
    r'better); Evt-Ratio Error is the relation between total simulated events/number '
    r'of real events, lower is better; and the Dur-act are the difference of the '
    r'individual activities durations vs the observed in test set and Span are the '
    r'same but for the trace length (lower is better). \textbf{Bold} = best per column.')

print('paper-table decimals:', {c: _paper_dp(c) for c in combined.columns})

tex_agg = to_paper_table(
    combined,
    caption=(f'Process modelling and timing accuracy ({SPLIT} set results, {AGG} '
             r'across processes and cases)'),
    label=_tex_esc(f'tab:process_results'),
    description=_paper_desc)

tex_pp = to_latex_table(
    per_process,
    caption=(f'Process discovery quality and timing accuracy per process ({SPLIT} set). '
             r'Same structure as Table~\ref{tab:process_discovery_' + str(EXPERIMENT) +
             r'} but every process shown individually. ' + _dir_note + ' within each process.'),
    label=f'tab:process_results',
    best_map=_best_within_process(per_process), n_index=3)

_disc_tbl = _disc_rows.copy()
tex_disc = to_latex_table(
    _disc_tbl,
    caption=(f'Process discovery quality per process ({SPLIT} set): Fitness, Precision, '
             r'Generalization and Simplicity of the discovered Petri net, obtained by '
             r'replaying the real log against the net (per station, averaged). Higher is '
             r'better; \textbf{bold} = best miner per metric within each process.'),
    label=f'tab:process_results',
    best_map={(p, c): best_of(s[c], c) for p, s in _disc_tbl.groupby(level=0)
              for c in _disc_tbl.columns},
    n_index=2)


print('% ===== AGGREGATED =====');       print(tex_agg)
print('\n% ===== PER PROCESS =====');    print(tex_pp)
print('\n% ===== DISCOVERY ONLY ====='); print(tex_disc)
# Out:
# paper-table decimals: {'Fitness': 3, 'Precision': 3, 'Generalization': 3, 'Simplicity': 3, 'Evt-Ratio Err': 3, 'Dur WAPE (%)': 3, 'Dur MAE (min)': 1, 'Span WAPE (%)': 3, 'Span MAE (min)': 1}
# % ===== AGGREGATED =====
# \begin{table*}[t]
# \centering
# \caption{Process modelling and timing accuracy (test set results, median across processes and cases)}
# \label{tab:process\_results}
# \vspace{-0.5em}
# \setlength{\tabcolsep}{4pt}
# \renewcommand{\arraystretch}{1.3}
# \footnotesize
# \begin{tabular}{ll|c|c|c|c|c|c|c|c|c}
# \toprule
# Method & \makecell[l]{Time\\approach} & Fitness & Precision & \makecell{Generalization} & Simplicity & \makecell{Evt-Ratio\\Error} & \makecell{Dur-act\\WAPE (\%)} & \makecell{Dur-act\\MAE (min)} & \makecell{Case \\span\\WAPE (\%)} & \makecell{Case \\span MAE\\(min)} \\
# \midrule
# \multirow{3}{*}{\makecell[c]{Alpha \\ (Baseline)}} & baseline & 0.636 & 0.396 & 0.545 & 0.489 & 0.542 & 63.214 & 7.3 & 69.084 & 321.8 \\
#  & ml\_global & 0.636 & 0.396 & 0.545 & 0.489 & 0.542 & 62.466 & 10.0 & 63.318 & 351.2 \\
#  & ml\_local & 0.636 & 0.396 & 0.545 & 0.489 & 0.542 & 52.611 & 6.7 & 58.550 & 269.5 \\
# \cline{1-11}
# \multirow{3}{*}{\makecell[c]{Best \\ Petri Net}} & baseline & \textbf{0.994} & \textbf{0.728} & \textbf{0.664} & \textbf{0.660} & 0.257 & 51.056 & 7.0 & 79.280 & 398.2 \\
#  & ml\_global & \textbf{0.994} & \textbf{0.728} & \textbf{0.664} & \textbf{0.660} & 0.257 & 64.884 & 10.2 & 67.280 & 402.8 \\
#  & ml\_local & \textbf{0.994} & \textbf{0.728} & \textbf{0.664} & \textbf{0.660} & 0.257 & \textbf{38.697} & \textbf{5.6} & 71.706 & 424.5 \\
# \cline{1-11}
# \multirow{3}{*}{\makecell[c]{Best \\ Petri Net \\ + Budget}} & baseline & \textbf{0.994} & \textbf{0.728} & \textbf{0.664} & \textbf{0.660} & 0.071 & 49.418 & 9.4 & 31.688 & 210.0 \\
#  & ml\_global & \textbf{0.994} & \textbf{0.728} & \textbf{0.664} & \textbf{0.660} & 0.137 & 67.490 & 9.7 & 19.549 & 108.6 \\
#  & ml\_local & \textbf{0.994} & \textbf{0.728} & \textbf{0.664} & \textbf{0.660} & \textbf{0.067} & 40.644 & 6.7 & \textbf{19.246} & \textbf{106.4} \\
# \cline{1-11}
# \bottomrule
# \end{tabular}
# \vspace{0.5em}
# \noindent\raggedright\footnotesize
#
# Description: Process discovery methods are Alpha (naive miner baseline), Best Petri Net (best discovered Petri Net), Best Petri Net + Budget (best Petri Net + duration budgeting at simulation time), each crossed with the three activity-duration predictors (baseline is the median, ml\_local is a ML model per activity and ml\_global is a ML model for all activities). Fitness, Precision, Generalization and Simplicity are discovery quality (higher is better); Evt-Ratio Error is the relation between total simulated events/number of real events, lower is better; and the Dur-act are the difference of the individual activities durations vs the observed in test set and Span are the same but for the trace length (lower is better). \textbf{Bold} = best per column.
#
# \end{table*}
#
# % ===== PER PROCESS =====
# \begin{table}[H]
# \caption{Process discovery quality and timing accuracy per process (test set). Same structure as Table~\ref{tab:process\_discovery\_1000} but every process shown individually. Fitness, Precision, Generalization and Simplicity are discovery quality (higher is better); Evt-Ratio Err and the Dur/Span columns are errors (lower is better). \textbf{Bold} = best per column within each process.}
# \label{tab:process\_results}
# \centering
# \setlength{\tabcolsep}{4pt}
# \renewcommand{\arraystretch}{1.0}
# \footnotesize
# \begin{tabular}{lll|c|c|c|c|c|c|c|c|c}
# \toprule
#  &  &  & Fitness & Precision & \makecell{General-\\ization} & Simplicity & \makecell{Evt-Ratio\\Err} & \makecell{Dur\\WAPE (\%)} & \makecell{Dur MAE\\(min)} & \makecell{Span\\WAPE (\%)} & \makecell{Span MAE\\(min)} \\
# Process & Method & \makecell[l]{Time\\approach} &  &  &  &  &  &  &  &  &  \\
# \midrule
# \multirow[t]{9}{*}{P1} & \multirow[t]{3}{*}{Alpha} & baseline & 0.829 & 0.310 & 0.594 & 0.590 & 0.064 & 26.1 & 1.8 & 31.1 & 34.2 \\
#  &  & ml\_global & 0.829 & 0.310 & 0.594 & 0.590 & 0.064 & 11.3 & 0.8 & 29.7 & 27.2 \\
#  &  & ml\_local & 0.829 & 0.310 & 0.594 & 0.590 & 0.064 & 6.4 & 0.4 & 32.7 & 32.4 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{\makecell[l]{Combined-\\best}} & baseline & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} & \textbf{0.000} & 28.0 & 1.5 & 33.9 & 37.4 \\
#  &  & ml\_global & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} & \textbf{0.000} & 8.1 & 0.5 & 27.2 & 26.4 \\
#  &  & ml\_local & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} & \textbf{0.000} & 4.2 & 0.3 & 25.5 & 22.0 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{Budget} & baseline & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} & 0.079 & 28.3 & 1.5 & 18.6 & 20.0 \\
#  &  & ml\_global & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} & 0.039 & 8.2 & 0.5 & \textbf{17.7} & \textbf{18.4} \\
#  &  & ml\_local & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} & 0.034 & \textbf{4.1} & \textbf{0.3} & 17.8 & 19.2 \\
# \cline{1-12} \cline{2-12}
# \multirow[t]{9}{*}{P2} & \multirow[t]{3}{*}{Alpha} & baseline & 0.557 & 0.450 & 0.496 & 0.404 & 0.514 & 82.4 & 7.8 & 74.0 & 323.7 \\
#  &  & ml\_global & 0.557 & 0.450 & 0.496 & 0.404 & 0.514 & 67.7 & 9.4 & 64.6 & 198.8 \\
#  &  & ml\_local & 0.557 & 0.450 & 0.496 & 0.404 & 0.514 & 37.1 & 4.6 & 76.4 & 278.4 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{\makecell[l]{Combined-\\best}} & baseline & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} & 0.288 & 48.0 & 6.3 & 76.9 & 305.9 \\
#  &  & ml\_global & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} & 0.288 & 70.1 & 10.3 & 63.4 & 263.1 \\
#  &  & ml\_local & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} & 0.288 & 34.8 & 4.6 & 76.9 & 419.4 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{Budget} & baseline & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} & \textbf{0.050} & 47.9 & 5.7 & 65.7 & 172.5 \\
#  &  & ml\_global & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} & 0.192 & 73.3 & 9.0 & \textbf{54.4} & \textbf{135.0} \\
#  &  & ml\_local & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} & 0.099 & \textbf{34.7} & \textbf{4.5} & 60.1 & 214.0 \\
# \cline{1-12} \cline{2-12}
# \multirow[t]{9}{*}{P3} & \multirow[t]{3}{*}{Alpha} & baseline & 0.564 & 0.275 & 0.496 & 0.407 & 0.505 & 42.7 & 6.0 & 65.0 & 247.7 \\
#  &  & ml\_global & 0.564 & 0.275 & 0.496 & 0.407 & 0.505 & 75.6 & 9.5 & 66.3 & 435.9 \\
#  &  & ml\_local & 0.564 & 0.275 & 0.496 & 0.407 & 0.505 & 45.9 & 5.7 & 65.7 & 260.7 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{\makecell[l]{Combined-\\best}} & baseline & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} & 0.278 & 43.7 & 6.5 & 86.7 & 490.4 \\
#  &  & ml\_global & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} & 0.278 & 79.6 & 9.6 & 96.5 & 614.9 \\
#  &  & ml\_local & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} & 0.278 & \textbf{30.0} & \textbf{5.0} & 95.1 & 429.6 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{Budget} & baseline & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} & \textbf{0.034} & 41.6 & 7.5 & 64.6 & 273.6 \\
#  &  & ml\_global & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} & 0.337 & 74.8 & 9.7 & \textbf{60.3} & \textbf{98.8} \\
#  &  & ml\_local & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} & 0.165 & 37.1 & 6.2 & 63.3 & 342.7 \\
# \cline{1-12} \cline{2-12}
# \multirow[t]{9}{*}{P4.1} & \multirow[t]{3}{*}{Alpha} & baseline & 0.707 & 0.811 & \textbf{0.866} & 0.571 & 0.604 & 81.0 & 38.3 & 63.0 & 801.1 \\
#  &  & ml\_global & 0.707 & 0.811 & \textbf{0.866} & 0.571 & 0.604 & 51.1 & 31.4 & 62.0 & 857.9 \\
#  &  & ml\_local & 0.707 & 0.811 & \textbf{0.866} & 0.571 & 0.604 & 60.9 & 41.1 & 60.0 & 826.5 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{\makecell[l]{Combined-\\best}} & baseline & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} & 0.527 & 54.1 & 36.7 & 62.3 & 731.9 \\
#  &  & ml\_global & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} & 0.527 & 40.8 & 31.7 & 46.7 & 542.4 \\
#  &  & ml\_local & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} & 0.527 & 42.6 & 35.4 & 43.8 & 506.3 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{Budget} & baseline & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} & 0.111 & 50.9 & 37.6 & 28.6 & 247.4 \\
#  &  & ml\_global & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} & \textbf{0.027} & \textbf{35.9} & \textbf{22.1} & 13.0 & 118.6 \\
#  &  & ml\_local & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} & 0.063 & 44.1 & 25.5 & \textbf{12.8} & \textbf{112.7} \\
# \cline{1-12} \cline{2-12}
# \multirow[t]{9}{*}{P4.2} & \multirow[t]{3}{*}{Alpha} & baseline & 0.741 & 0.488 & 0.695 & 0.615 & 0.570 & 57.7 & \textbf{30.2} & 75.6 & 843.5 \\
#  &  & ml\_global & 0.741 & 0.488 & 0.695 & 0.615 & 0.570 & 57.2 & 75.0 & 53.0 & 434.8 \\
#  &  & ml\_local & 0.741 & 0.488 & 0.695 & 0.615 & 0.570 & 59.4 & 69.9 & 54.4 & 460.7 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{\makecell[l]{Combined-\\best}} & baseline & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} & 0.235 & 69.8 & 84.8 & 92.9 & 930.4 \\
#  &  & ml\_global & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} & 0.235 & 59.7 & 71.5 & 71.2 & 636.0 \\
#  &  & ml\_local & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} & 0.235 & 61.9 & 65.7 & 70.4 & 622.0 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{Budget} & baseline & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} & \textbf{0.063} & \textbf{55.3} & 68.0 & 34.8 & 266.3 \\
#  &  & ml\_global & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} & 0.081 & 64.7 & 51.1 & 20.6 & 118.5 \\
#  &  & ml\_local & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} & 0.071 & 63.5 & 51.9 & \textbf{19.2} & \textbf{100.0} \\
# \cline{1-12} \cline{2-12}
# \multirow[t]{9}{*}{P5} & \multirow[t]{3}{*}{Alpha} & baseline & 0.408 & 0.342 & 0.429 & 0.391 & 0.574 & 68.7 & 6.8 & 73.2 & 319.9 \\
#  &  & ml\_global & 0.408 & 0.342 & 0.429 & 0.391 & 0.574 & 86.2 & 10.4 & 68.4 & 267.7 \\
#  &  & ml\_local & 0.408 & 0.342 & 0.429 & 0.391 & 0.574 & 76.5 & 7.8 & 57.1 & 207.4 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{\makecell[l]{Combined-\\best}} & baseline & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} & 0.222 & 65.6 & 7.6 & 81.6 & 305.8 \\
#  &  & ml\_global & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} & 0.222 & 70.7 & 10.2 & 72.9 & 256.8 \\
#  &  & ml\_local & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} & 0.222 & 64.6 & \textbf{6.1} & 73.0 & 261.5 \\
# \cline{2-12}
#  & \multirow[t]{3}{*}{Budget} & baseline & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} & 0.499 & 59.9 & 11.3 & 22.0 & 59.3 \\
#  &  & ml\_global & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} & 0.754 & 70.3 & 9.7 & \textbf{18.5} & \textbf{47.3} \\
#  &  & ml\_local & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} & \textbf{0.020} & \textbf{48.1} & 7.3 & 19.3 & 53.8 \\
# \cline{1-12} \cline{2-12}
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# % ===== DISCOVERY ONLY =====
# \begin{table}[H]
# \caption{Process discovery quality per process (test set): Fitness, Precision, Generalization and Simplicity of the discovered Petri net, obtained by replaying the real log against the net (per station, averaged). Higher is better; \textbf{bold} = best miner per metric within each process.}
# \label{tab:process\_results}
# \centering
# \setlength{\tabcolsep}{4pt}
# \renewcommand{\arraystretch}{1.0}
# \footnotesize
# \begin{tabular}{ll|c|c|c|c}
# \toprule
#  &  & Fitness & Precision & \makecell{General-\\ization} & Simplicity \\
# Process & Miner &  &  &  &  \\
# \midrule
# \multirow[t]{2}{*}{P1} & alpha & 0.829 & 0.310 & 0.594 & 0.590 \\
#  & heuristic & \textbf{1.000} & \textbf{0.993} & \textbf{0.797} & \textbf{0.810} \\
# \cline{1-6}
# \multirow[t]{2}{*}{P2} & alpha & 0.557 & 0.450 & 0.496 & 0.404 \\
#  & heuristic & \textbf{0.996} & \textbf{0.566} & \textbf{0.583} & \textbf{0.623} \\
# \cline{1-6}
# \multirow[t]{2}{*}{P3} & alpha & 0.564 & 0.275 & 0.496 & 0.407 \\
#  & heuristic & \textbf{0.992} & \textbf{0.521} & \textbf{0.572} & \textbf{0.622} \\
# \cline{1-6}
# \multirow[t]{2}{*}{P4.1} & alpha & 0.707 & 0.811 & \textbf{0.866} & 0.571 \\
#  & heuristic & \textbf{0.996} & \textbf{0.961} & 0.825 & \textbf{0.714} \\
# \cline{1-6}
# \multirow[t]{2}{*}{P4.2} & alpha & 0.741 & 0.488 & 0.695 & 0.615 \\
#  & heuristic & \textbf{0.992} & \textbf{0.890} & \textbf{0.746} & \textbf{0.697} \\
# \cline{1-6}
# \multirow[t]{2}{*}{P5} & alpha & 0.408 & 0.342 & 0.429 & 0.391 \\
#  & heuristic & \textbf{0.969} & \textbf{0.559} & \textbf{0.547} & \textbf{0.600} \\
# \cline{1-6}
# \bottomrule
# \end{tabular}
# \end{table}
